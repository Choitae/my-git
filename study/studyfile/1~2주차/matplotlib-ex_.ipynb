# %% [markdown]
# 문) 카페 매출에 대한 막대 그래프를 그려보자.

# %%
# 파이썬 입문/연습문제 12-1
import csv
import matplotlib.pyplot as plt
import sys
sys.path.append('../../library')
import hangul_lib

f = open('cafe_2year.csv', 'r', encoding='utf-8')
lines = csv.reader(f)

header = next(lines)

xdata = []
ydata = []
count = 1

for line in lines:
    if count%3 == 0 :
        xdata.append(line[0])
        ydata.append(line[1])

    count += 1
    
font1 = {'size':18, 'color':'green'}
plt.title('전국의 월별 카페수', fontdict = font1)
plt.bar(xdata,ydata)


plt.ylabel('카페수')

plt.show()

# %%
# 막대 그래프를 그리시오.
# 교재 p390 참조

# %% [markdown]
# 문) 종합병원 의사수 데이터를 이용해 꺽은선 그래프를 그려보자.

# %%
# 파이썬 입문/연습문제 12-4
import csv
import matplotlib.pyplot as plt
import sys
sys.path.append('../../library')
import hangul_lib


f = open('doctor2.csv', 'r', encoding='utf-8')
lines = csv.reader(f)

header = next(lines)

xdata = []
ydata = []

for line in lines:
    xdata.append(line[0])
    ydata.append(int(line[4]))

# %%
# 파이썬 입문/연습문제 12-4
import csv
import matplotlib.pyplot as plt
import sys
sys.path.append('../../library')
import hangul_lib


f = open('doctor2.csv', 'r', encoding='utf-8')
lines = csv.reader(f)

header = next(lines)

xdata = []
y1data = []
y2data = []
y3data = []
y4data = []
for line in lines:
    xdata.append(line[0])
    y1data.append(int(line[4])) #전문의수
    y2data.append(int(line[3])) #레지던트 수
    y3data.append(int(line[2])) #인턴 수
    y4data.append(int(line[1])) #일반의 수

plt.plot(xdata, y1data, label = '전문의 수', color = 'red', linestyle = '-', marker='o')
plt.plot(xdata, y2data, label = '레지턴트 수', color = '#00ffff', linestyle = '--', marker='x')
plt.plot(xdata, y3data, label = '인턴의 수', color = 'magenta', linestyle = '-', marker='s')
plt.plot(xdata, y4data, label = '일반의 수', color = '#444444', linestyle = ':', marker='d')

font1 = {'size':18, 'color':'green'}
plt.title('서울 및 광역시 종합병운 의사 수', fontdict=font1)
plt.legend(loc='best')

plt.show()

# %%
ydata, xdata
# Out:
# ([9375, 2211, 1436, 1518, 1006, 1006, 467],
#  ['서울', '부산', '대구', '인천', '대전', '광주', '울산'])

# %%
# 산포도 그래프를 그려보자.
# 교재 p392 참조
import csv
import matplotlib.pyplot as plt
import sys
sys.path.append('../../library')
import hangul_lib
f = open('doctor2.csv', 'r', encoding='utf-8')
lines = csv.reader(f)

xdata =[ ]
ydata =[ ]
header = next(lines)

for line in lines:
    xdata.append(line[0])
    ydata.append(int(line[4])) #전문의수

plt.title('서울 및 광역시 종합병원 전문의 수')
plt.scatter(xdata,ydata)
plt.xlabel("시")
plt.ylabel('의사 수')
plt.show()

# 라벨: x-시, y - 의사 수
# 타이틀: 서울 및 광역시 종합병원 전문의 수

# %% [markdown]
# 문) 앞의 doctor2.csv 파일을 사용해서 일반의, 인턴, 레지던트, 전문의 의사수를 꺽은선 그래프로 그려보자.

# %%
# 파이썬입문/연습문제 12-5
import csv

f = open('doctor2.csv', 'r', encoding='utf-8')
lines = csv.reader(f)

header = next(lines)

xdata = []
ydata1 = []
ydata2 = []
ydata3 = []
ydata4 = []

for line in lines:
    xdata.append(line[0])
    ydata1.append(int(line[1]))
    ydata2.append(int(line[2]))
    ydata3.append(int(line[3]))
    ydata4.append(int(line[4]))

# %%
# 일반의, 인턴, 레지던트, 전문의 의사수를 꺽은선 그래프로 그려보자.
# 교재 p385 참조

import csv
import matplotlib.pyplot as plt
import sys
sys.path.append('../../library')
import hangul_lib


f = open('doctor2.csv', 'r', encoding='utf-8')
lines = csv.reader(f)

header = next(lines)

xdata = []
y1data = []
y2data = []
y3data = []
y4data = []
for line in lines:
    xdata.append(line[0])
    y1data.append(int(line[4])) #전문의수
    y2data.append(int(line[3])) #레지던트 수
    y3data.append(int(line[2])) #인턴 수
    y4data.append(int(line[1])) #일반의 수

plt.plot(xdata, y1data, label = '전문의 수', color = 'red', linestyle = '-', marker='o')
plt.plot(xdata, y2data, label = '레지턴트 수', color = '#00ffff', linestyle = '--', marker='x')
plt.plot(xdata, y3data, label = '인턴의 수', color = 'magenta', linestyle = '-', marker='*')
plt.plot(xdata, y4data, label = '일반의 수', color = '#444444', linestyle = ':', marker='d')

font1 = {'size':18, 'color':'green'}
plt.title('서울 및 광역시 종합병운 의사 수', fontdict=font1)
plt.legend(loc='best')

plt.show()

# %% [markdown]
# 문) doctor2.csv 파일을 사용해서 의사수 분포를 파이 그래프로 그려보자.

# %%
# 연습문제 12-6
import csv

f = open('doctor2.csv', 'r', encoding='utf-8')
lines = csv.reader(f)

header = next(lines)

kind = ['일반의', '인턴', '레지던트', '전문의']

numbers = []
seoul = next(lines)

total = 0
for i in range(4) :
    total += int(seoul[i+1])
    
for i in range(4) :
    persent = int(seoul[i+1])/total;
    numbers.append(persent)

# %%
# 의사수 분포를 파이 그래프로 그려보자.
# 교재 p393 참조

import matplotlib.pyplot as plt
from matplotlib import rc
