# %% [markdown]
# # 취업 관련 강의
#   - 김수인 강사님 : dandellion_career@naver.com / 인스타그램 : suincoach
#
#   - 과제(미션)이 많을 것

# %% [markdown]
#   - 취업을 위해 준비해야 되는 것
#      - 서류 작성하는 법 등

# %% [markdown]
# ## 2021년 취업시장 문 좁아질 예정
#   - 본질 직무영역
#   - 활용 직무영역
#   - 직무 적합도 : 본인의 적성, 흥미가 자신이 하는 일과 얼마나 맞는가?
#   - 조직 역량(소프트스킬)
#   - 직무 역량(하드  스킬)
#      - 직무 역량을 기준으로 취업을 시키면, 퇴사를 하는 경우가 많았다
#        --> 조직의 이해 / 일에 대한 의미
#          --> (책임감)이 약하다.
#        -->>> 직무 역량이 기본이 되고 조직 역량 여부를 추가하는 경우가 많을 것이다.(2021년)

# %% [markdown]
#   1) 서면면접 : 자기소개서
#
#   2) 대면면접 : AI면접 1차 면접, 2차 면접
#
#      - 지원동기 : 내가 이 회사에 들어가기 위해 이 회사를 지원했다 (past)
#                  기업과 나, 직무와 나를 연관시켜 지원 동기를 찾아라(future)

# %% [markdown]
# ## 오늘 스케쥴
#
#   1) 직무분석(워크넷, ncs 등 에서 검색)
#
#       ncs : https://ncs.go.kr/index.do
#
#     - 원하는 과업의 지식 (과목) , 기술 (자격증), 태도 (역량)를 갖추어 면접 때 드러내라
#     - 하고자 하는 과업 -> AI or 자율 주행 연구
#
#   2) 기업탐색 + 분석방법
#
#   3) 자소서 작성(=면접 준비)

# %% [markdown]
# # 1) 직무 분석
#         - 직무 선정  #중요하다는 키워드와 관계성이 있는 단어에 체크
#
#             - 직무 서치 진행
#
#                - 직무명 : 인공지능 모델링 or 인공지능 엔지니어
#
#                - 직무 하는 일 :
#
#                - 직무와 관련된 역량 :
#
#                       지식 :  요구공학지식, 다양한 요구사항 모델 유형 사례 지식,
#                              단계적, 합리적 문제에 대한 목표 설정 방법론과 도식화 방법론
#                              최적화 탐색 방법론에 대한 지식
#
#                       기술 : 기능, 비기능적 요구사항을 도출하는 기술
#                              모델 유형별 장/단점을 고려하여 최적화 모델을 선별하는 기술
#                              인공지능 문제를 정의하고 목표를 설정할 수 있는 능력
#                              인공지능 문제의 특징을 명확히 분리할 수 있는 기술
#
#                       태도 : 목표 설정을 위한 체계적인 사고
#                              목표 설정을 위해 다수의 의견을 수용하는 자세
#                              문제표현 구성요소를 기반으로 정확히 도식화하려는 자세
#                              새로운 인공지능 모델 사례들을 배우려는 적극적인 자세
#                              요구사항을 수용하고자 하는 태도
#                              요구사항의 명확성을 찾고 정확성과 안정성을 확보하려는 자세
#                              인공지능 문제 특징에 다라 해결방법을 다각도로 검토하는 태도
#
#             - 직무와 나의 매칭도(+근거)
#             이 직무는 분속력이 필요
#
#             - 직무에 대한 정의 :
#               요구사항(문제)에 대해 단계적, 합리적으로 생각하여(어떠한 관점으로 - 경험에 의해 이야기하는 것이 가장 좋다)
#               목표를 설정하는 방법과 도식화 하려는 자세 가져야한다.

# %% [markdown]
#     - 역랑 기술서
#        - 직무에 대한 이해 + 역량도출 + 경험
#
#     - 직무 기술서
#        - 직무의 과업에 따라 본인이 해왔던 경력

# %% [markdown]
# # 2) 기업분석 탐색
#     - 기업이 추구하는 방향!
#
#         (면접을 위한)
#
#     - 업무 환경이 어떤지?
#
#         (나를 위한)
#
#   - 기업 핵심 중심
#     - 핵심가치, 인재상, 경영철학, 합격한 사람들 인터뷰
#         - > 기술 스타트업은 무조건 해외 지향적이어야한다
#             -- 국내 대기업은 한국 스타트업이 할 수 있으면, 회사에서도 할 수 있겠다는 마인드지만,
#                해외 대기업은 내가 못하는 건 최대한 빨리 라이센스를 받아서 개발하는 시간을 아껴 시장을 빠르게 치고 나가겠다.
#
#
#         - > 기술력은 충분히 뛰어나며 삼성과 LG도 배출한 나라이다, 때문에 우리도 가능하다
#         - > 대부분이 한국인이지만, 영어만 사용하는 회사.
#            -- 영어에서 오는 수평적으로 오는 대화를 추구. 독특하고 다양한 사람을 원함
#            -- 다름은 이상한 것이 아니라 다양한 것이다.
#            -- 일을하면 전적으로 믿고 맡긴다.
#         ex) 스타트업 대표, 관련 인터뷰 / 신년사, 홈페이지
#
#   - 기업 방향성
#     - 사업 (해당 관련 직무에 연관되는 사업의 2020년, 21~이후 흐름)
#      : 3D 센서용 AI 엔진 (머신러닝 + 3D 데이터)
#     - 사업이 흘러온 방향
#      : 라이다계의 윈도우가 되는 것이 목표. 현재 기술은 세계적으로 1위지만 내년에 시장점유율 1위를 탈환할 것을 준비하고 있다.
#          -- 세계 1, 2위의 회사 직원들이 회사로 넘어왔기 떄문에 내년에는 탈환할 수 있다.
#      : 2017년 8월 4일 설립, 현재 파트너로 메르세데츠 벤츠, 볼보, BMW, 카이스트, NVIDIA 등의 파트너가 있다.
#     - 산업의 트렌드(공부!!) 뉴스스크랩 + @(세미나, 관련 도서)
#      : 자율주행에 있어 필요하기 때문에 아직 전 세계적으로도 2단계 밖에 진행되지 않은 자율주행자동차 부분에서 '라이다'라는 제품을 이용한다면
#        더 발전할 수 있다고 생각한다. 테슬라에서 사용하는 카메라는 멈춰있거나, 차량 사고로 죽은 사슴과 같은 부분에 대해서는 인지하지 못한다.
#        그러나 라이더의 경우, 작은 오토바이들까지 인지하며 이러한 부분의 단점을 보완할 수 있다.
#
#     - 여담
#       : 한국을 빛내라라는 이름의 '이한빈' 대표는 회사 이름에도 '서울'을 넣어 추후에 유명해졌을 때, 이름만 들어도
#         '아, 이 사람들이 한국에서 왔구나, 서울에서 왔구나' 하는 것을 알리기 위해서 '서울로보틱스'라는 이름을 만들었다고-
#
#    - 취업 분야
#       - 연구 엔지니어 - 로봇 인식 (2차 지원)
#       - 연구 엔지니어 인턴 - 기계학습 (1차 지원)
#       - 소프트웨어 엔지니어 - C++, 응용 프로그램
#       - DevOps 엔지니어
#       - 비즈니스 인턴 - 비즈니스 팀

# %% [markdown]
# 회사가 왜 이 부분을 추진하게 되었는지?
#
# 스터디 그룹에서 모인 사람들과 실리콘벨리에서 개최된 자율주행자동차 경진대회에 나갔고, 라이다 소프트웨어에서 1위, 전 셰계 기준 10등
# 대회가 마무리되고 자율주행자동차 회사에서 6억의 연봉을 제시했을 때, 라이다가 접목될 수 있는 부분의 잠재력은 엄청 클 수 있겠다하여 창업 실시.
#
# 과업? 정부과제 No! 돈을 따기도 쉽고, 한번 획득하면 추후에도 획득하기 쉽다! 투자만 민간고객만 가지고 가겠다.
# 어떻게 나아가고 있는지?  라이다계의 윈도우가 되는 것이 목표. 현재 기술은 세계적으로 1위지만 내년에 시장점유율 1위를 탈환할 것을 준비하고 있다.
# 추후 예측 포인트(pt)

# %% [markdown]
#   - 기업의 장점 / 단점
#   - 기업 기회요인 / 위협요인

# %% [markdown]
#   - 자기 소개 항목(면접 질문 항목)
#     1. 지원 동기 // 입사후 포부
#
#       - 왜 하필이면 우리 회사에 지원했나요?
#       *
#
#       - 왜 당신은 이 직무를 하고 싶어하나요?
#       * 직무를 선택하게 된 계기
#       * 직무를 잘할 수 있는 나의 역량
#       * 직무를 준비해온 과정
#       * 내가 생각하는 직무의 재 정의, 그리고 나는 이걸 되게 잘한다. 내가 일을 어떻게 바라보고 있는가?
#         ex) 일을 성취의 수단으로 생각하고 있다.
#       * 면접 & 자소서 : 핵심을 파악하라! (핵심 메세지를 상단에 적어주세요 + 근거 (왜냐하면 ~~ )  경험! 내가 어떤 경험을 했는가? )
#
#         역량) ex) 분석력 !! 상단 노출 --> 근거
#
#   - 직무조사 : 나의 매칭도
#
#     신입사원 : "실력", 지식수준, 경험의 유뮤 확인, 관심도, 실력 가늠(가능성).
#
#     직무관련된 지식 / 기술 / 태도 (소프트스킬, 직장에 조직내 적응하는 역량)
#
#
#   - 회사에 대한 관심도, 직무에 대한 가능성
#
#     : 우리 회사와 잘 맞고 큰 비전, 직무 -> 이익
#
#   - 조직상
#
#     대기업 : 상향평준화 성취, 성과 / 중소 & 중견 기업 : 성실, 조직 내에서 나아가고자 하는 방향을 나는 너무 따라가고 싶다.
#
#     스타트업 : 전문영역, 전문적 명예, 전문적 기술에 대한 프라이드, 성장욕구 / 소기업 : 회자에 대한 관심도, 애정

# %% [markdown]
#     1. 지원 동기 // 입사후 포부 (구조화를 잘 시킨다)
#
#
#
#
#
#
#       - 왜 하필이면 우리 회사에 지원했나요?
#       *
#
#       - 왜 당신은 이 직무를 하고 싶어하나요?
#       * 직무를 선택하게 된 계기
#           -> 로봇 공학자가 꿈이었기에 이 같이 달리고 있습니다. 고등학교 때에도 로봇 동아리에 들어가 여러가지를 만들어보고, 회장을 맡아 동아리 회원들과 같이 학교 행사에 참여하고 타 학교에서 개최하는 발명 행사에 열정적으로 참여하는 등 꿈을 위해 열심히 달렸습니다.
#           비록 대학교와 입대 기간 동안, 현실에 안주하여 꿈을 놓았었지만, 최근 다시 꿈을 위해 AI 관련 공부를 하고 있습니다.
#
#
#
#       * 직무를 잘할 수 있는 나의 역량(x) -> (강점)
#           -> 저의 특기는 '집념'(x) -> '집중력'(o) 입니다. 수학 문제의 경우에도 막히게 되면 풀기 위해 몇 시간 동안 수많은 방향으로 도전하여 푸는 등, 어떤 문제로
#              인해 길이 막히게 되면 , 문제를 해결하기 위해 여러 방면으로 도전하여 문제를 풀어냅니다.
#
#       * 직무를 준비해온 과정
#
#
#       * 내가 생각하는 직무의 재 정의, 그리고 나는 이걸 되게 잘한다. 내가 일을 어떻게 바라보고 있는가?
#         - 문제에 대해 단계적, 합리적으로 생각하여 목표를 설정하는 방법과 도식화하여 최적의 모델을 구현해내는 것이 이 인공지능 엔지니어의 일이라고
#           생각한다. 나는 'Why'라는 질문을 좋아한다. 때문에 문제를 해결하는 것에 대해서는 분명, 시간을 많이 소모하지만, 이것이 어떤 원리로, 어떻게
#           이루어지는지 끝없이 궁금하고, 해결하고자 나아가기 때문에 문제를 해결함에 있어 중요한 지식, 정보들을 캐치하여 추후 이러한 문제를 응용함에
#           있어 수월하게 다가갈 수 있다.
#
#
#
#
#         ex) 일을 성취의 수단으로 생각하고 있다.
#       * 면접 & 자소서 : 핵심을 파악하라! (핵심 메세지를 상단에 적어주세요 + 근거 (왜냐하면 ~~ )  경험! 내가 어떤 경험을 했는가? )
#
#
#
#
#         역량) ex) 분석력 !! 상단 노출 --> 근거

# %% [markdown]
#       - 어릴 적부터 계속 관심을 가져온 분야. 흥미, 관심도에 따른 성장배경 바탕으로 직무 계기 -> 제가 가진 집중력의 강점
#      -> "문제 해결 능력"으로 역량을 성장시켰다.
#
#
#       + 경험적 근거
#       어떤 준비를 했는지? 첫번 째 지식, 두번째 기술  / 발휘했던 경험들이 있습니다.
#
#       회사에 대한 정보 나열 vs 회사에 대한 핵심 정보 = 나와 매칭
#
#       회사 지원 동기 + 회사의 사실적 정보 + 나도 어떤 관점으로 사업을 하고 싶은지 (이 직무에서)
#
#       업적 (결과물 수행 능력) 행동 -결과
#
#       ※ '~한다고 생각합니다' 라는 추측성 어미는 사용하지 말 것.
#
#       ---------------------------------------------------------
#       회사에 대한 지원동기 = 입사후 포부
#       1. 산업/직무에 트렌드 + 전략 세우고 싶은지
#          --> 현재 2세대까지밖에 발전하지 못한 자율주행자동차 분야는 현재의 벽만 넘어갈 수 있다면 발전 가능성은 무궁무진하다.
#              카메라와 레이더로 제한되어있던 자율주행에 고출력 펄스 레이저로 3차원 공간 정보를 획득할 수 있는 라이다라는 기술은 정말 중요한 기술이다.
#              입체화된 정보와 매우 적은 오차범위로 사고 발생률을 줄이고,
#              자동차라는 산업에만 국한되지 않고, 인공지능 로봇, 기차, 비행기, 배 등 다양한 산업과 사람이 하기 위험한 폭발물 제거,
#              위험지역 탐사 등의 업무 또한 기술이 빠지지 않고 들어갈 것이다. 미래에 핫하게 될 이 기술을 바탕으로 꿈을
#       2. 하필이면 그것이 왜 이 회사
#       (이미 그사업을 하고 있을수도 있고, 내가 그사업을 발전시킬만한 자신감->역량)
#          --> 첫번 째, 내가 원하는 자율주행 자동차와 매우 밀접한 관련이 있는 회사이기에 지원하였다.
#          나는 추후, 재난이 일어난 상황에서 사람을 구하기 위한 로봇을 개발하고자 한다. 재난 지역에서는 사람이 한계가 있어  로봇이
#          사람을 구출해야 하며, 만약 사람이 무선으로 컨트롤 하는 경우, 상황에 대한 빠른 판단이 불가능하다고 여긴다. 때문에 자율주행
#          기술을 접목하여 그 꿈을 현실화 하고자 한다. 그 꿈의 출발선으로 이 회사에 지원하였다. 꿈을 이루기 위해 라이다를 이용한
#          자율 주행과 AI 연구를 끝없이 이어나갈 것이며 이는 회사 연구에 큰 도움을 줄 것이다.
#
#          두번 째는 외국인들과 함께 일하는 것에 메리트를 느꼈다. 이 회사를 알기 전, 나는 다양한 사람들과 협업을 해보고자 하여 외국의
#          회사에 지원하는 것만 고려하였으나, 다양한 국가의 사람들이 함께 일하며, 수평적인 구조로 영어로 서로 소통한다는 것. 이것이
#          내게 큰 메리트로 다가왔다. 다양한 국가의 사람들의 다른 문화를 알아가는 것에 대해 나는 큰 관심을 가지니까. 때문에 현재 영어와
#          독일어를 공부하고 있으며, 추후 여러나라의 언어를 공부하고자 한다. 이것은 회사에서 여러 나라의 회사들과 커넥트를 취할 때,
#          정말로 도움이 될 것이다.
#
#        3. 계획..... 수행 근거
#
#
#          4. 의지

# %% [markdown]
#     - 왜? 하필이면 이 회사인가
#     - 왜 니가 이 직무를 잘하는 사람인가
#     -> 회사와 나의 매칭도 / 사업방향의 관점
#     -> 직무에 대한 흥미 + 관심
#     -> 일에 대한 의미
#
#     근거!!!
#     -> 경험 / 나의 노력
#     -> 계획 ~~~~
#
#     두괄식!!!!!
#     (핵심메세지 + 근거)
#     단문 !!!!!!
#
#     경험서술 + 성격의 장단점 + 면접 질의응답

# %% [markdown]
# ### 직무적합도
#
#   - 가장 직무와 연관된 경험이 무엇이었는지 말하세요
#   - 가장 기억에 남은 전공 관련 학업생활을 말하세요
#   - 직무관련된 경험을 말해주세요
#
#   - 직무경험 + 직무역량
#
#   --> 직무와 무관한 경험은 배제!!!
#
#    --> 집중력을 바탕으로 문제 해결 능력
#      -> 경험을 근간으로 말해줘라.
#      ★ STAR 기법
#      에피소드!
#      S : 언제/ 어디서/무엇을/어떻게 (실질적인 정보를 제공)
#      T : Task / Target 어떤 업무, 임무를 맡았는가, 나는 이때 "프로젝트 역항을 수행했다"
#      A : 행동 ~ 첫째, 목적 / 둘째 / 셋째,
#      R : 결과 ~~ (성과) 수치/ 수상 경력 + 느낀점 " 이러한 역량을 갖고 있다보니 이러한 경험이 도움~
#          입사를 할 때 이런 도움을 가질 것 같다.

# %% [markdown]
#   - 가장 직무와 연관된 경험이 무엇이었는지 말하세요
#
#   - 가장 기억에 남은 전공 관련 학업생활을 말하세요
#   - 직무관련된 경험을 말해주세요
#
#   - 직무경험 + 직무역량
#
#
# --> 직무와 무관한 경험은 배제!!!
#   개발 업무를 잘하기 위해 '내가 원하는 업무'의 기술, 지식, 태도를 이용하여 작성하라.
#
#    --> 집중력을 바탕으로 문제 해결 능력
#      -> 경험을 근간으로 말해줘라.
#      ★ STAR 기법
#      에피소드!
#      S : 언제/ 어디서/무엇을/어떻게 (실질적인 정보를 제공)
#      T : Task / Target 어떤 업무, 임무를 맡았는가, 나는 이때 "프로젝트 역항을 수행했다"
#
#
#      A : 행동 ~ 첫째, 목적 / 둘째 / 셋째,
#      R : 결과 ~~ (성과) 수치/ 수상 경력 + 느낀점 " 이러한 역량을 갖고 있다보니 이러한 경험이 도움~
#          입사를 할 때 이런 도움을 가질 것 같다.
#
#
#     - 대학교 4학년 때, 알고자, 해결하고자 하는 욕망 하나만으로 완료하였던 아두이노 프로젝트가 가장 인상이 깊다.
#       나와 팀원은 초음파 센서를 이용하여 자동으로 이상여부를 체크하여 작동하는 도개교를 만들었는데, 프로그래밍을 하는 것이
#       매우 어려웠다. 모터가 돌아가는 속도와 각도를 정하고, 초음파 센서와 lED 점등 작동 등 개별 행동에는 이상없이 성공하였으나
#       세 파트를 함께 연동하는 파트에서 오류가 지속적으로 발생하였다. 코드에 대해 명확하게 배우지 않고 시작된 프로젝트였기 때문에
#       팀원과 함께 밤을 세워가며 한 동작씩 이어서 작동하도록 문제를 해결하였고,
#
#
#
#       코딩에 대해 수업에서 배운 기본기외에 아는 것이 없었지만, 알고자, 해결하고자 하는 욕망 하나만으로 마칠 수 있었던 프로젝트였기에,
#       가장 인상이 깊은 학업생활이었으며, 문제를 해결하기 위해 했던 이러한 경험은 내게 어떤 문제가 생기더라도 해결 할 수 있다는 용기를
#       주었다. 때문에 업무 간에 발생한 막히는 일에도 주저없이 해결할 것이다.
#
#       피드백 :
#           - 업부적 태도, 추상적단어, 감정적 단어 배제
#           - 어떻게 해결하였는가?
#             어떤 문제가 있었고, 어떤 해결책으로 행동하였는가? 역량을 이용한 해결책? 직무에서 이러한 부분이 얼마만큼 필요한 것인가?
#
#
#           - 직무 경험) 직무에 대해 잘 알고 있고, 얻은 경험, 역량이 회사에서 어떤식으로 발휘가 될 것인가?
#           - 직무 역량 -> 내가 하려는 과업의 목적!
#             얼만큼 직무에 대해 역량이 있으며 // 회사에 와서 이것을 잘 해내갈 수 있는 사람인가? 행동의 근거
#
#             조직 역량(팀워크, 책임감) -> 팀원이 함께 설정하는 목표를 이루는 것!! ex) 내가 도전했던 경험 ~ / 팀 프로젝트 경험 ~

# %% [markdown]
# ---------------------------------
# star에서는 스토리가 많아, 이것을 지우고 추상적 단어, 감정적 단어를 배제하라.

# %% [markdown]
# ## 1. 지원 동기, 입사후 포부
# ## 2. 직무역량
# ## 3. 성장과정(인성) (가치관+ 인생 변화~ ) 부정적 x 업무적으로 괜찮은 사람이라는 것을 인지시킬 것.
#
#   - 삶을 바라보는 나의 태도
#   - 내가 살아가는 인생에서 중요하게 생각하는 가치
#     -> 구체적으로 내가 어떤 인생 로드맵
#     -> 업무/일로서 어떤 영향을?
#     -> 회사 조직에 어떤 이익!!!
#
#   - 요즘은~
#      - 근속 일수가 낮다. 동기 부여가 안된다
#      - 동기부여는 ?
#         -- > 외적 동기부여 : 하고 싶은거 할 때, 적절한 보상, 원하는 것을 얻을 때
#              내적 동기부여 : 자기계발(잠재하는 자기의 슬기나 재능, 사상 따위를 일깨워 줌), 소속감 등
#
#   - 매슬로우의 욕구단계설
#         1단계 : 의식주~
#         2단계 :
#         3단계 :
#         4단계 :
#         5단계 : 자아실현
#
#
#
#   ->   - 삶을 바라보는 나의 태도
#        - 내가 살아가는 인생에서 중요하게 생각하는 가치
#            --> 정직, 솔선수범, 멋, 모르는 것에 부끄러워 하지 말자(배움에는 나이가 없다.)
#     -> 구체적으로 내가 어떤 인생 로드맵
#         --> 어려운 일에 닥쳤을 때, 변명과 거짓말을 많이 하므로써 상황을 해결하기 보다는 회피하고자 하는 경험이 많았다.
#             이것이 부끄러운 일이며, 지금의 거짓말이 나중에 더 큰 화를 만드는 것을 깨달아, 실수, 잘못에 대해 바로 인정하고 사과한다.
#
#             배움에는 나이, 계급이 상관 없다고 생각한다. 때문에 소위로 부대에 배치되었을 때에도 모르는 것는 모르는 것이라고 생각하고
#             일병 친구와 함께 부대에서 소대가 맡는 업무 등을 배웠고, 배움으로서 추후 소대 통솔에도
#     -> 업무/일로서 어떤 영향을?
#     -> 회사 조직에 어떤 이익!!!

# %% [markdown]
# ### 동기부여 정리 (나만의 소스로 나만의 언어로 말하라.)
# 1. 내가 추구하는 가치관 / 태도
# 2. 내가 어떤 업무스타일 / 어떤 인생으로 살아가게 되었는지
# ※ 단문으로! 저는(x) -> 나는(o) or 생략
#
# ex) 1. 나는 스스로 사고하고 스스로 행동하는 사람이다. 6년간 일본 유학생활을 하면서 가장 중요하게 배운것은 '자율성'
#       일을 할때에도 스스로 동기부여를 가지고 스스로 성장해야 좋은 성과를 낸다는 것을 깨달았다. + 경험)

# %% [markdown]
# ### 자기소개 / 면접
# -> 상대방의 의도를 파악해라
# -> 핵심 메세지를 전달해라!
# -> 근거를 말해라!
#
# 대기업 (500자 ~ 1000자) 1000자 내외 --> 700자
# 1000자로 써라 --> 에피소드를 2개로 나누어 적어라.
# 직무역량 : 태도 / 지식, 전문적  or 회사의 지원동기 / 직무의 지원동기(이때 동일한 직무 역량)
# -->2개의 소제목으로 나누어 하되 전체적인 흐름을 맞추어 써라

# %% [markdown]
# ## Q) 팀장이 너를 믿는다, 큰 프로젝트를 맡겼다. 받고 하던 중 너무 어렵다, 어떻게 하겠는가?
#       강사님 ANSWER) 주변 지인의 도움으로 해결했다. 내가 이러한 성과를 해결하고자 하지만, 어렵다고 판단되면, 미리 이야기하여
#                      빠르게 업무를 분담하는 것이 더욱 중요하다고 생각한다.

# %% [markdown]
# # 면접
#   - 실무진 면접
#   - 임원 면접
#   - AI 면접
#   - PT 면접
#   - 토론/ 토의
#   - 태도(50%)
#      - 회사는 어떤 태도의 사람들을 선호할까?
#          --> 마인드셋 사고력! 준비성
#              - 긍정적인 마인드, 적극적인 사람, 자신감***(!= 자만감, 버릇x, 거들먹)
#   - 구조, 스피치
#      - PREP 기법
#        네, 제가 지원한 이유는 ~ 2줄 / 3줄
#        P : 포인트(핵심문장)
#        R : 이유 왜냐하면
#        E : 예시 / 경험/ 근거
#        P : 포인트 그래서 지원했습니다.
#
#        업무적인 목표() 사업적으로 어떻게 응용하고, 내가 궁금하여 어떻게 접근해왔는가
#        ex) 단기간 적인 목표 (2, 3년간 어떠한 프로젝트를 수행해보고 싶다)
#
#        제가 지원하게 된 이유는 제가 어릴 적 부터 꿈꿔왔던 로봇 공학자의 꿈의 시작을, 여기서의 경험이 이뤄줄 것이라고 믿기 때문입니다.
#        왜냐하면 '라이다'라는 기술을 이용한 자율주행은 3차원적인 공간의 데이터를 받아 이용하기 때문에, 위험하고 험난한 현장에서의
#        다양한 정보를 얻고 임무를 수행함에 매우 적합하며 때문에 이러한 기술을 개발하고 있는 이 회사에 지원하였습니다.  자동차 분야를
#        넘어 로봇과 다양한 분야로 뻗어 나가는 다리를 제가 함께 건설해보고 싶습니다.
