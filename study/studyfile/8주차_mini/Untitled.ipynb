# %%
import pandas as pd
import numpy as np

# %%
co2_total = pd.read_excel('UNEP-EDE__co2_total_cdiac__1610930982.xlsx', engine="openpyxl")

# %%
co2_total
# Out:
#           Identification Information  \
# 0                           Citation
# 1                                 ID
# 2                              Title
# 3                   Publication year
# 4                          Date type
# 5                Representation form
# 6                              Units
# 7                           Filename
# 8                                NaN
# 9                         Definition
# 10                          Abstract
# 11                            Status
# 12                    Topic Category
# 13                         GEO theme
# 14                 GEO data category
# 15                    Theme Keywords
# 16                  Update frequency
# 17                     Free keywords
# 18                   Temporal Extent
# 19                      Covered time
# 20                 Geographic Extent
# 21                          Coverage
# 22                    West longitude
# 23                    East longitude
# ...

# %%
co2_total.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 48 entries, 0 to 47
# Data columns (total 2 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   Identification Information  47 non-null     object
#  1   Unnamed: 1                  28 non-null     object
# dtypes: object(2)
# memory usage: 896.0+ bytes

# %%
forest_table = pd.read_csv('forest-area-as-share-of-land-area.csv')

# %%
forest_table
# Out:
#            Entity Code  Year  Forest cover
# 0     Afghanistan  AFG  1990      1.850994
# 1     Afghanistan  AFG  1991      1.850994
# 2     Afghanistan  AFG  1992      1.850994
# 3     Afghanistan  AFG  1993      1.850994
# 4     Afghanistan  AFG  1994      1.850994
# ...           ...  ...   ...           ...
# 7969     Zimbabwe  ZWE  2016     45.570273
# 7970     Zimbabwe  ZWE  2017     45.451183
# 7971     Zimbabwe  ZWE  2018     45.332093
# 7972     Zimbabwe  ZWE  2019     45.213002
# 7973     Zimbabwe  ZWE  2020     45.093912
#
# [7974 rows x 4 columns]

# %%
forest_table.pivot_table(index='Year', columns='Entity')

import matplotlib.pyplot as plt

# %%
forest_table['Year'][1900:]
# Out:
# 1900    1995
# 1901    1996
# 1902    1997
# 1903    1998
# 1904    1999
#         ...
# 7969    2016
# 7970    2017
# 7971    2018
# 7972    2019
# 7973    2020
# Name: Year, Length: 6074, dtype: int64

# %%
x_data = forest_table['Year']
y_data = forest_table['Entity']
plt.figure(figsize=(12,8))
plt.plot(x_data,y_data)
plt.legend(forest_table, loc='best') # 라벨 표기하기
plt.grid()
plt.show()

# %%
air_pollution = pd.read_csv('data/air_data/data_1.csv', header=2)

# %%
air_pollution
# Out:
#      Country Name Country Code  \
# 0           Aruba          ABW
# 1     Afghanistan          AFG
# 2          Angola          AGO
# 3         Albania          ALB
# 4         Andorra          AND
# ..            ...          ...
# 259        Kosovo          XKX
# 260   Yemen, Rep.          YEM
# 261  South Africa          ZAF
# 262        Zambia          ZMB
# 263      Zimbabwe          ZWE
#
#                                         Indicator Name     Indicator Code  \
# 0    PM2.5 air pollution, mean annual exposure (mic...  EN.ATM.PM25.MC.M3
# 1    PM2.5 air pollution, mean annual exposure (mic...  EN.ATM.PM25.MC.M3
# 2    PM2.5 air pollution, mean annual exposure (mic...  EN.ATM.PM25.MC.M3
# 3    PM2.5 air pollution, mean annual exposure (mic...  EN.ATM.PM25.MC.M3
# 4    PM2.5 air pollution, mean annual exposure (mic...  EN.ATM.PM25.MC.M3
# ..                                                 ...                ...
# ...

# %%
kor_tmp = pd.read_csv('data/tas_1901_2016_KOR.csv')

# %%
kor_tmp
# Out:
#            Temperature - (Celsius)          Year  Statistics       Country  \
# -1.51420                      1901   Jan Average       Korea   Republic of
# -4.13840                      1901   Feb Average       Korea   Republic of
#  2.42486                      1901   Mar Average       Korea   Republic of
#  10.11110                     1901   Apr Average       Korea   Republic of
#  14.01350                     1901   May Average       Korea   Republic of
# ...                            ...           ...         ...           ...
#  25.85300                     2016   Aug Average       Korea   Republic of
#  20.19010                     2016   Sep Average       Korea   Republic of
#  14.32340                     2016   Oct Average       Korea   Republic of
#  6.33090                      2016   Nov Average       Korea   Republic of
#  1.31452                      2016   Dec Average       Korea   Republic of
#
#            ISO3
# -1.51420    KOR
# -4.13840    KOR
# ...

# %%
kor_tmp.columns
# Out:
# Index(['Temperature - (Celsius)', ' Year', ' Statistics', ' Country', ' ISO3'], dtype='object')

# %%
kor_tmp.index
# Out:
# Float64Index([-1.5142, -4.1384, 2.42486, 10.1111, 14.0135, 18.9166, 20.8477,
#               23.2861, 17.8684, 13.2048,
#               ...
#               5.78669,  12.352, 17.3603, 21.5184, 24.5801,  25.853, 20.1901,
#               14.3234,  6.3309, 1.31452],
#              dtype='float64', length=1392)

# %%
kor_pit
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-16-a64b62fbc7ae> in <module>
# ----> 1 kor_pit
#
# NameError: name 'kor_pit' is not defined

# %%
kor_tmp['Temperature - (Celsius)']

# %%
co2_total = pd.read_excel('data/flood.xlsx', engine="openpyxl")

# %%
co2_total

# %%
co2_total[co2_total['Country'] == 'Algeria']

# %%
pd.read_excel('data/finddata/ACI_v1.1_Values_Through_May_2020_in_English.xlsx', engine="openpyxl")

# %%
co2_total.columns

# %%
ACI_v1.1_Values_Through_May_2020_in_English

# %%
pd.read_excel('data/drogu/Sta_GlobalDrought.xlsx', engine="openpyxl")

# %%
pd.read_csv('data/drogu/drought.csv', names= ['GID', 'EV_ID', 'ISO3DISNO', 'ISO3YEAR', 'GLIDE', 'ISO3','ID_NAT', 'ID_CAT', 'YEAR', 'START_DATE', 'END_DATE', 'TIME_GMT', 'TIME_LOCAL', 'DURATION'])
