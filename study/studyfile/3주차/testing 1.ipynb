# %%
import requests
from bs4 import BeautifulSoup
# Create your views here.


with requests.get('https://movie.naver.com/movie/running/current.nhn?sel=cnt&date=20201218') as res:
        soup= BeautifulSoup(res.text)
data=[]

tags=soup.select('dl[class=lst_dsc]')
for i in tags:
    data.append(i.text.split())
data
# Out:
# [['15세',
#   '관람가',
#   '조제',
#   '네티즌',
#   '7.04참여',
#   '1,232명',
#   '|',
#   '예매율',
#   '36.28%',
#   '개요',
#   '멜로/로맨스,',
#   '드라마',
#   '|',
#   '117분',
#   '|',
#   '2020.12.10',
#   '개봉',
#   '감독',
#   '김종관',
#   '출연',
#   '한지민,',
#   '남주혁',
#   '예매하기',
#   '포토보기',
#   '예고편'],
#  ['12세',
#   '관람가',
#   '이웃사촌',
#   '네티즌',
#   '6.06참여',
#   '1,871명',
#   '|',
#   '예매율',
#   '13.47%',
#   '개요',
#   '드라마,',
#   '코미디',
#   '|',
#   '130분',
#   '|',
#   '2020.11.25',
#   '개봉',
#   '감독',
#   '이환경',
#   '출연',
#   '정우,',
#   '오달수,',
#   '김희원,',
#   '김병철,',
#   '이유비,',
#   '조현철',
#   '예매하기',
#   '포토보기',
#   '예고편'],
#  ['12세',
#   '관람가',
#   '도굴',
#   '네티즌',
#   '7.52참여',
#   '3,098명',
#   '|',
#   '예매율',
#   '10.64%',
#   '개요',
#   '범죄',
#   '|',
#   '114분',
#   '|',
#   '2020.11.04',
#   '개봉',
#   '감독',
#   '박정배',
#   '출연',
#   '이제훈,',
#   '조우진,',
#   '신혜선,',
#   '임원희',
#   '예매하기',
#   '다운로드',
#   '포토보기',
#   '예고편',
#   '메이킹'],
#  ['15세',
#   '관람가',
#   '런',
#   '네티즌',
#   '8.18참여',
# ...

# %%
with requests.get('https://movie.naver.com/movie/running/current.nhn?sel=cnt&date=20201218') as res:
                soup= BeautifulSoup(res.text)
data={}

tags=soup.select('dl[class=lst_dsc]')
for i in range (len(tags)):
    data[i+1] = [tags[i].text.split()]
data
# Out:
# {0: [['15세',
#    '관람가',
#    '조제',
#    '네티즌',
#    '7.04참여',
#    '1,232명',
#    '|',
#    '예매율',
#    '36.28%',
#    '개요',
#    '멜로/로맨스,',
#    '드라마',
#    '|',
#    '117분',
#    '|',
#    '2020.12.10',
#    '개봉',
#    '감독',
#    '김종관',
#    '출연',
#    '한지민,',
#    '남주혁',
#    '예매하기',
#    '포토보기',
#    '예고편']],
#  1: [['12세',
#    '관람가',
#    '이웃사촌',
#    '네티즌',
#    '6.06참여',
#    '1,871명',
#    '|',
#    '예매율',
#    '13.47%',
#    '개요',
#    '드라마,',
#    '코미디',
#    '|',
#    '130분',
#    '|',
#    '2020.11.25',
#    '개봉',
#    '감독',
#    '이환경',
#    '출연',
#    '정우,',
#    '오달수,',
#    '김희원,',
#    '김병철,',
#    '이유비,',
#    '조현철',
#    '예매하기',
#    '포토보기',
#    '예고편']],
#  2: [['12세',
#    '관람가',
#    '도굴',
#    '네티즌',
#    '7.52참여',
#    '3,098명',
#    '|',
#    '예매율',
#    '10.64%',
#    '개요',
#    '범죄',
#    '|',
#    '114분',
#    '|',
#    '2020.11.04',
#    '개봉',
#    '감독',
#    '박정배',
#    '출연',
#    '이제훈,',
#    '조우진,',
#    '신혜선,',
#    '임원희',
#    '예매하기',
#    '다운로드',
# ...
