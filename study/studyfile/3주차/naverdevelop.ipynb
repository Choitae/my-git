# %%
import os
import sys
import urllib.request
client_id = "U_WNMOWJengOfZpwleGI"
client_secret = "7kXcf8LOzc"
encText = urllib.parse.quote("아이유")
url = "https://openapi.naver.com/v1/search/blog?query=" + encText + "&display=20" # json 결과
# url = "https://openapi.naver.com/v1/search/blog.xml?query=" + encText # xml 결과
request = urllib.request.Request(url)
request.add_header("X-Naver-Client-Id",client_id)
request.add_header("X-Naver-Client-Secret",client_secret)
response = urllib.request.urlopen(request)
rescode = response.getcode()
if(rescode==200):
    response_body = response.read()
    print(response_body.decode('utf-8'))
else:
    print("Error Code:" + rescode)
# Out:
# {
# "lastBuildDate": "Thu, 17 Dec 2020 13:52:26 +0900",
# "total": 674384,
# "start": 1,
# "display": 20,
# "items": [
# {
# "title": "<b>아이유</b> 친 동생과 개꿀잼 인터뷰(동생,이종훈?나이)",
# "link": "https:\/\/blog.naver.com\/gksmfjdjfgjk?Redirect=Log&logNo=222167575136",
# "description": "<b>아이유</b>가 <b>아이유</b>가 아닌 '이지은'에 대해 인터뷰를 했습니다. 이 인터뷰는 친동생분이 질문을 하는 형식으로 진행했는데요 ㅎㅎ 유튜브에 자신의 채널을 통해 '지은이가 보는 지은이'라는 제목의 영상을... ",
# "bloggername": "연예계 이슈, 사건 사고",
# "bloggerlink": "https://blog.naver.com/gksmfjdjfgjk",
# "postdate": "20201209"
#
# },
# {
# "title": "산본 속눈썹 펌까지 잘하는 <b>아이유</b>",
# "link": "https:\/\/blog.naver.com\/jid21c?Redirect=Log&logNo=222119259785",
# "description": "산본역 로데오쪽으로 나오면 걸어서 1분도 안되는 가까운 거리에 속눈썹 연장 펌 전문점 <b>아이유</b>에서... 7층에 위치하고 있는 산본 속눈썹 <b>아이유</b>에요. 이곳은 연장 뿐만 아니라 펌, 왁싱 아라네일살롱 네일... ",
# "bloggername": "지나의 블로그",
# "bloggerlink": "https://blog.naver.com/jid21c",
# "postdate": "20201018"
#
# },
# {
# "title": "언주역 네일 :: 24시<b>아이유</b>네일에서 예쁘고 빠르게 네일받으세용!",
# ...

# %%
import os
import sys
import urllib.request
client_id = "U_WNMOWJengOfZpwleGI"
client_secret = "7kXcf8LOzc"
encText = urllib.parse.quote("아이유")
url = "https://openapi.naver.com/v1/search/blog?query=" + encText + "&display=20" # json 결과
# url = "https://openapi.naver.com/v1/search/blog.xml?query=" + encText # xml 결과
request = urllib.request.Request(url)
request.add_header("X-Naver-Client-Id",client_id)
request.add_header("X-Naver-Client-Secret",client_secret)

with requests.get("https://openapi.naver.com/v1/search/blog?query=") as res:
    soup= BeautifulSoup(res.text)
    res.
response = soup.
rescode = response.getcode()
if(rescode==200):
    response_body = response.read()
    print(response_body.decode('utf-8'))
else:
    print("Error Code:" + rescode)
# Out:
# {"errorMessage":"Not Exist Client ID : Authentication failed. (인증에 실패했습니다.)","errorCode":"024"}

# %%
import os
import sys
import urllib.request
client_id = "U_WNMOWJengOfZpwleGI"
client_secret = "7kXcf8LOzc"
encText = urllib.parse.quote("아이유")
url = "https://openapi.naver.com/v1/search/blog?query=" + encText + "&display=20" # json 결과
# url = "https://openapi.naver.com/v1/search/blog.xml?query=" + encText # xml 결과
request = urllib.request.Request(url)
request.add_header("X-Naver-Client-Id",client_id)
request.add_header("X-Naver-Client-Secret",client_secret)
with requests.get(url) as res:
    soup= BeautifulSoup(res.text, 'html.parser')
response = urllib.request.urlopen(request)
rescode = response.getcode()
if(rescode==200):
    response_body = response.read()
    print(response_body.decode('utf-8'))
else:
    print("Error Code:" + rescode)
# Out:
# {
# "lastBuildDate": "Thu, 17 Dec 2020 10:01:16 +0900",
# "total": 674318,
# "start": 1,
# "display": 20,
# "items": [
# {
# "title": "<b>아이유</b> 친 동생과 개꿀잼 인터뷰(동생,이종훈?나이)",
# "link": "https:\/\/blog.naver.com\/gksmfjdjfgjk?Redirect=Log&logNo=222167575136",
# "description": "<b>아이유</b>가 <b>아이유</b>가 아닌 '이지은'에 대해 인터뷰를 했습니다. 이 인터뷰는 친동생분이 질문을 하는 형식으로 진행했는데요 ㅎㅎ 유튜브에 자신의 채널을 통해 '지은이가 보는 지은이'라는 제목의 영상을... ",
# "bloggername": "연예계 이슈, 사건 사고",
# "bloggerlink": "https://blog.naver.com/gksmfjdjfgjk",
# "postdate": "20201209"
#
# },
# {
# "title": "산본 속눈썹 펌까지 잘하는 <b>아이유</b>",
# "link": "https:\/\/blog.naver.com\/jid21c?Redirect=Log&logNo=222119259785",
# "description": "산본역 로데오쪽으로 나오면 걸어서 1분도 안되는 가까운 거리에 속눈썹 연장 펌 전문점 <b>아이유</b>에서... 7층에 위치하고 있는 산본 속눈썹 <b>아이유</b>에요. 이곳은 연장 뿐만 아니라 펌, 왁싱 아라네일살롱 네일... ",
# "bloggername": "지나의 블로그",
# "bloggerlink": "https://blog.naver.com/jid21c",
# "postdate": "20201018"
#
# },
# {
# "title": "언주역 네일 :: 24시<b>아이유</b>네일에서 예쁘고 빠르게 네일받으세용!",
# ...
