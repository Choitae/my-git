# %%
from bs4 import BeautifulSoup
import requests

meximum = 0
page = 1

URL = 'http://land.naver.com/news/field.nhn?page=1'
response = requests.get(URL)
source = response.text
soup = BeautifulSoup(source, 'html.parser')

while 1: 
    page_list = soup.findAll("a", {"class": "NP=r:" + str(page)})
    if not page_list:
        maximum = page -1
        break
    page = page +1
print(f"총  {str(maximum)} 개의 페이지가 확인 됐습니다. ")
# Out:
# 총  3 개의 페이지가 확인 됐습니다.

# %%
soup
# Out:
# <!DOCTYPE HTML PUBLIC "-//W3C//DTD HTML 4.01 Transitional//EN" "http://www.w3.org/TR/html4/loose.dtd">
#
# <html lang="ko">
# <head>
# <meta content="text/html; charset=utf-8" http-equiv="Content-Type"/>
# <meta contents="always" name="referrer">
# <meta content="IE=Edge" http-equiv="X-UA-Compatible"/>
# <title>
# 뉴스 : 네이버 부동산</title>
# <script type="text/javascript">
# document.domain = "naver.com";
#
# var ccsrv="cc.naver.com";
# var g_query = "";
# var nclk_evt = 3;
# </script>
# <link href="https://ssl.pstatic.net/static.land/static/service/css/202011051426/min/news/news.css" rel="stylesheet" type="text/css"/><script type="text/javascript">	document.domain = 'naver.com';</script>
# <script src="https://ssl.pstatic.net/static.land/static/service/js/202011051426/search/flashObject.js" type="text/javascript"></script><script type="text/javascript">
# 	nsc = "land.news_cn";
# 	document.title="분야별뉴스, 뉴스 : 내집마련의 시작, 네이버 부동산";
# </script><style type="text/css">
# .wordwrap
# {
#      word-wrap:break-word;
#      word-break:break-all;
#      -moz-binding: url('/css/wordwrap.xml#wordwrap');
#      overflow: hidden;
# }
# </style>
# <meta content="네이버부동산 " property="me2:post_tag"/>
# <meta content="네이버부동산" property="me2:category1"/>
# <meta content="" property="me2:category2"/>
# <!DOCTYPE HTML PUBLIC "-//W3C//DTD HTML 4.01 Transitional//EN" "http://www.w3.org/TR/html4/loose.dtd">
#
# <!-- og:tag -->
# <link href="http://land.naver.com" rel="canonical"/>
# <meta content="land" property="og:site_name"/>
# <meta content="네이버 부동산" property="og:title"/>
# <meta content="article" property="og:type"/>
# <meta content="네이버 부동산 분야별 뉴스" property="og:description"/>
# <meta content="네이버 부동산 분야별 뉴스" name="description"/>
# <meta content="https://landthumb-phinf.pstatic.net/20201030_229/land_naver_1604037626049TB83t_PNG/%B3%D7%C0%CC%B9%F6_%BA%CE%B5%BF%BB%EA.png" property="og:image">
# <meta content="네이버 부동산" property="og:article:author"/>
# <meta content="https://land.naver.com/news/field.nhn?page=1" property="og:url"/>
# <meta content="http://land.naver.com/" property="og:article:author:url"/>
# <!-- //og:tag -->
# <script type="text/javascript">
# 	photoDomain = "https://landthumb-phinf.pstatic.net";
#
# 	serviceImageUrl = "https://ssl.pstatic.net/static.land/static/service/20191007";
#
# 	today = "20201217";
#
#
# 	function getDefaultImage(width) {
# 		var dfltImgUrl = "";
#
# 		if(width >= 120){
# 			if(width > 206){
# 				dfltImgUrl = serviceImageUrl +"/noimage/noimage_232.gif";
# 			}else if(width > 196){
# 				dfltImgUrl = serviceImageUrl +"/noimage/noimage_206.gif";
# 			}else if(width > 120 ){
# 				dfltImgUrl = serviceImageUrl +"/noimage/noimage_196.gif";
# 			}else{
# 				dfltImgUrl = serviceImageUrl +"/noimage/noimage_120.gif";
# 			}
# 		}else{
# 			if(width > 102){
# 				dfltImgUrl = serviceImageUrl +"/noimage/noimage_120.gif";
# 			}else if(width > 83){
# 				dfltImgUrl = serviceImageUrl +"/noimage/noimage_102.gif";
# 			}else if(width > 63 ){
# 				dfltImgUrl = serviceImageUrl +"/noimage/noimage_083.gif";
# 			}else{
# 				dfltImgUrl = serviceImageUrl +"/noimage/noimage_063.gif";
# 			}
# 		}
# 		return dfltImgUrl;
# 	}
#
# 	function getPhotoInfraImg(photo, type, width) {
# 		if(photo == null || photo == "") {
# 			return getDefaultImage(width);
# 		} else {
# 			if(type == null || type == "" || typeof type == "undefined") {
# 				return photoDomain + "/" + photo;
# 			} else {
# 				return photoDomain + "/" + photo + "?type=" + type;
# 			}
# 		}
# 	}
#
# 	function errorImg(el , dWidth) {
#
# 		var width = dWidth || Number(el.getAttribute("width"));
# 		if(el.src.indexOf("noimage") > -1){
# 			return;
# 		}
# 		el.src = getDefaultImage(width);
# 	}
#
# 	function generatePhotoInfraImgTag(hashAttr, type) {
#
# 		var isEmpty = function (value) {
# 			if (!value || value == null || value == "" || typeof value == "undefined") {
# 				return true;
# 			}
# 			return false;
# 		};
#
# 		var tagAttrs = "";
# 		var attachAttr = function(value, key) {
# 			tagAttrs += " " + key + "=\"" + value + "\"";
# 		};
#
# 		var dfltImgUrl = getDefaultImage(hashAttr.$("width"));
#
# 		if (isEmpty(hashAttr.$("src"))) {
# 			hashAttr.add("src", dfltImgUrl);
# 		} else {
# 			hashAttr.add("src", photoDomain + hashAttr.$("src"));
#
# 			if (!isEmpty(type)) {
# 				hashAttr.add("src", hashAttr.$("src") + "?type=" + type);
# 			}
# 		}
#
# 		hashAttr.forEach(attachAttr);
#
# 		return "<img " + tagAttrs + " onerror=\"errorImg(this)\">";
# 	}
# </script></meta></meta></head>
# <body class="" onload="">
# <div id="wrap">
# <div id="u_skip">
# <a href="#lnb" onclick="document.getElementById('lnb').tabIndex = -1;document.getElementById('lnb').focus();return false;"><span>메인 메뉴로 바로가기</span></a>
# <a href="#container" onclick="document.getElementById('container').tabIndex = -1;document.getElementById('container').focus();return false;"><span>하위 메뉴로 바로가기</span></a>
# <a href="#content" onclick="document.getElementById('content').tabIndex = -1;document.getElementById('content').focus();return false;"><span>본문으로 바로가기</span></a>
# </div>
# <div id="pvframe" style="display:none;"></div>
# <!-- header -->
# <script src="https://ssl.pstatic.net/static.land/static/service/js/202011051426/lib/lcslog.js" type="text/javascript"></script><script src="https://wcs.naver.net/wcslog.js" type="text/javascript"></script>
# <script type="text/javascript">
# 	lcs_do();
#
# 	if(!wcs_add) var wcs_add = {};
# 	wcs_add["wa"] = "60717a12f2b3c8";
# 	if(typeof wcs_do !== 'undefined') wcs_do();
# </script>
# <div class="header_one" id="header">
# <div class="gnb_wrap">
# <div class="inner_wrap">
# <div class="item_area NE=a:STA">
# <h1 class="logo_area">
# <a class="logo_naver NPI=a:naverlogo" href="http://www.naver.com/"><i class="icon">NAVER</i></a>
# <a class="logo_land NPI=a:land" href="http://land.naver.com/"><i class="icon">부동산</i></a>
# </h1>
# <div class="inner_gnb_search">
# <h2 class="blind">검색영역</h2>
# <fieldset>
# <legend>검색</legend>
# <!-- [D] 입력위해 focus 가지면 sta_text_ovr 추가 -->
# <input name="where" type="hidden" value="nexearch"/>
# <input name="sm" type="hidden" value="top_hty"/>
# <input name="fbm" type="hidden" value="1"/>
# <input id="serviceInternalSearchQuery" name="query" type="hidden" value=""/>
# <input id="internalSearchURL" name="internalSearchURL" type="hidden" value="https://land.naver.com"/>
# <input accesskey="s" class="search_input sta_search_text" id="queryInputHeader" onfocus="searchInputBoxFocus(this);" onkeyup="serviceInternalSearchEnterCheck(event,0);" query="" searchareaclicked="false" searchtype="Promotion" title="검색" type="text" value=""/>
# <a class="search_button type_inside NPI=a:search" href="#" onclick="serviceInternalSearch();return false;"><i class="icon">검색</i></a>
# <a class="search_button type_integration NPI=a:nx" href="#" onclick="serviceInternalTotalSearch();return false;" title="새창 열림"><i class="icon">통합검색</i></a>
# </fieldset>
# </div>
# </div>
# <div class="gnb_area">
# <div id="gnb">
# <script charset="utf-8" src="https://ssl.pstatic.net/static.gn/templates/gnb_utf8.nhn?20201217" type="text/javascript"></script>
# </div>
# </div>
# </div>
# </div>
# <div class="nav_wrap" id="lnb">
# <h2 class="blind">메인메뉴</h2>
# <div class="inner_wrap">
# <!-- [D] 활성화 클래스 on -->
# <ul class="nav_list NE=a:LNB">
# <li class="menu main_home">
# <a class="NPI=a:home" href="/">부동산홈</a>
# </li>
# <li class="menu main_article_beta">
# <a class="NPI=a:article_beta" href="https://new.land.naver.com/complexes">매물베타</a>
# </li>
# <li class="menu main_isale">
# <a class="NPI=a:sale" href="https://isale.land.naver.com/iSale/Map/">분양</a>
# </li>
# <li class="menu main_news on">
# <a class="NPI=a:news" href="/news/">뉴스</a>
# </li>
# <li class="menu main_community">
# <a class="NPI=a:community" href="/community/">커뮤니티</a>
# </li>
# <li class="menu main_auction">
# <a class="NPI=a:auction" href="/auction/">경매</a>
# </li>
# <li class="menu main_mypage">
# <a class="NPI=a:mypage" href="https://new.land.naver.com/interests">MY페이지</a>
# </li>
# <!--[if lte IE 9]>
# 						<li id="_ieVerCheck" class="hidden ie9"></li>
# 					<![endif]-->
# </ul>
# <div class="button_area NE=a:LNB">
# <a class="type_admin NPI=a:landad" href="http://landad.naver.com/" target="_blank">부동산관리센터</a>
# </div>
# </div>
# </div>
# <div class="sub_nav_wrap">
# <h2 class="blind">서브메뉴</h2>
# <div class="inner_wrap">
# <!-- [D] 활성화 클래스 on -->
# <ul class="sub_nav_list NE=a:LNB">
# <li class="menu news_headline"><a class="on" href="/news/headline.nhn">주요뉴스</a></li>
# <li class="menu news_region"><a class="on" href="/news/region.nhn">우리동네뉴스</a></li>
# <li class="menu news_issue"><a class="on" href="/news/hotIssue.nhn">핫이슈</a></li>
# <li class="menu news_field on"><a class="on" href="/news/field.nhn">분야별뉴스</a></li>
# <li class="menu news_breaking"><a class="on" href="/news/breaking.nhn">실시간속보</a></li>
# <li class="menu news_expert"><a class="on" href="/news/expertColumn.nhn">부동산칼럼</a></li>
# <li class="menu news_magazine"><a class="on" href="/news/magazine.nhn">매거진</a></li>
# <li class="menu news_trend"><a class="on" href="/news/trendReport.nhn">동향보고서</a></li>
# </ul>
# </div>
# </div>
# </div>
# <!-- //header --><!--하위 컨텐츠 및 Aside Component 영역 List Container -->
# <div id="container">
# <div id="content">
# <h2 class="h_news field" tabindex="0"><span>분야별 뉴스</span></h2>
# <div class="section_field NEI=a:cat.title">
# <a class="NP=r:1,i:10" href="#"><strong>시장동향</strong></a>
# <span class="bar">|</span>
# <a class="NP=r:2,i:20" href="?news_type_cd=20">정책/제도</a>
# <span class="bar">|</span>
# <a class="NP=r:3,i:30" href="?news_type_cd=30">개발정보</a>
# <span class="bar">|</span>
# <a class="NP=r:4,i:40" href="?news_type_cd=40">분양</a>
# <span class="bar">|</span>
# <a class="NP=r:5,i:50" href="?news_type_cd=50">업계동향</a>
# <span class="bar">|</span>
# <a class="NP=r:6,i:60" href="?news_type_cd=60">부동산금융</a>
# <span class="bar">|</span>
# <a class="NP=r:7,i:70" href="?news_type_cd=70">경매/공매</a>
# <span class="bar">|</span>
# <a class="NP=r:8,i:80" href="?news_type_cd=80">기타</a>
# </div>
# <div class="section_headline">
# <ul class="headline_list NEI=a:lst.title">
# <li>
# <dl>
# <dt class="photo"><a class="NP=r:1,i:014_0004548354" href="/news/newsRead.nhn?type=field&amp;news_type_cd=10&amp;prsco_id=014&amp;arti_id=0004548354"><img alt="규제지역 집값 다시 올랐다.." onerror="this.src='https://ssl.pstatic.net/static.land/static/service/20191007/noimage/noimage_102.gif'" src="https://s.pstatic.net/imgnews/image/thumb100/014/2020/12/16/4548354.jpg" 교란"="" 부동산="" 사진"="" 시장="" 정책이=""/></a></dt>
# <dt><a class="NP=r:1,i:014_0004548354" href="/news/newsRead.nhn?type=field&amp;news_type_cd=10&amp;prsco_id=014&amp;arti_id=0004548354">규제지역 집값 다시 올랐다.."부동산 정책이 시장 교란"</a></dt>
# <dd tabindex="0">
# 						[파이낸셜뉴스]6·17 대책 당시 규제지역으로 묶인 수도권 지역들의 집값이 다시 반등하면서 '규제 무용론'이 불거지고 있다. 정부가 11·19 전세대책을 내놨지만 오히려 공급에 한계를 드러내...<span class="writing">파이낸셜뉴스</span>
# <span class="date">2020.12.16</span>
# </dd>
# </dl>
# </li>
# <li>
# <dl>
# <dt class="photo"><a class="NP=r:2,i:011_0003842946" href="/news/newsRead.nhn?type=field&amp;news_type_cd=10&amp;prsco_id=011&amp;arti_id=0003842946"><img alt="2030세대 ‘오직 아파트’ ···단독·연립과 가격차 ‘역대급 사진" onerror="this.src='https://ssl.pstatic.net/static.land/static/service/20191007/noimage/noimage_102.gif'" src="https://s.pstatic.net/imgnews/image/thumb100/011/2020/12/16/3842946.jpg"/></a></dt>
# <dt><a class="NP=r:2,i:011_0003842946" href="/news/newsRead.nhn?type=field&amp;news_type_cd=10&amp;prsco_id=011&amp;arti_id=0003842946">2030세대 ‘오직 아파트’ ···단독·연립과 가격차 ‘역대급</a></dt>
# <dd tabindex="0">
# 						[서울경제] 서울 아파트값과 단독·연립주택 가격 격차가 역대 최대 수준으로 벌어진 것으로 나타났다. 시장에서 ‘아파트 편애’ 현상이 심화한 것이다. 16일 KB부동산 월간 주택가격동향 시...<span class="writing">서울경제</span>
# <span class="date">2020.12.16</span>
# </dd>
# </dl>
# </li>
# <li>
# <dl>
# <dt class="photo"><a class="NP=r:3,i:016_0001766721" href="/news/newsRead.nhn?type=field&amp;news_type_cd=10&amp;prsco_id=016&amp;arti_id=0001766721"><img alt="“무주택자는 치솟는 전셋값, 유주택자는 세금때문에 못살겠다”…2020 부동산에선 누구도 행복하지 않았다 [부동산360] 사진" onerror="this.src='https://ssl.pstatic.net/static.land/static/service/20191007/noimage/noimage_102.gif'" src="https://s.pstatic.net/imgnews/image/thumb100/016/2020/12/16/1766721.jpg"/></a></dt>
# <dt><a class="NP=r:3,i:016_0001766721" href="/news/newsRead.nhn?type=field&amp;news_type_cd=10&amp;prsco_id=016&amp;arti_id=0001766721">“무주택자는 치솟는 전셋값, 유주택자는 세금때문에 못살겠다”…2020 부동산에선 누구도 행복하지 않았다 [부동산360]</a></dt>
# <dd tabindex="0">
# 						[헤럴드경제=민상식 기자] 올해 부동산 시장에서는 누구도 웃지 못했다. 보유세(재산세·종부세), 양도세 등 부동산 세금이 일제히 오르면서 유주택자들은 “세금 때문에 못살겠다”는 불만이...<span class="writing">헤럴드경제</span>
# <span class="date">2020.12.16</span>
# </dd>
# </dl>
# </li>
# <li>
# <dl>
# <dt class="photo"><a class="NP=r:4,i:421_0005054101" href="/news/newsRead.nhn?type=field&amp;news_type_cd=10&amp;prsco_id=421&amp;arti_id=0005054101"><img alt="전국 주택 매매시장 소비심리, 5년7개월 만에 최고 사진" onerror="this.src='https://ssl.pstatic.net/static.land/static/service/20191007/noimage/noimage_102.gif'" src="https://s.pstatic.net/imgnews/image/thumb100/421/2020/12/16/5054101.jpg"/></a></dt>
# <dt><a class="NP=r:4,i:421_0005054101" href="/news/newsRead.nhn?type=field&amp;news_type_cd=10&amp;prsco_id=421&amp;arti_id=0005054101">전국 주택 매매시장 소비심리, 5년7개월 만에 최고</a></dt>
# <dd tabindex="0">
# 						(서울=뉴스1) 노해철 기자 = 전세 시장 불안이 매매시장으로 번지면서 지난달 전국 주택 매매시장 소비심리지수는 5년7개월 만에 최고치를 기록했다. 16일 국토연구원 부동산시장연구센터에 ...<span class="writing">뉴스1</span>
# <span class="date">2020.12.16</span>
# </dd>
# </dl>
# </li>
# <li>
# <dl>
# <dt class="photo"><a class="NP=r:5,i:417_0000632528" href="/news/newsRead.nhn?type=field&amp;news_type_cd=10&amp;prsco_id=417&amp;arti_id=0000632528"><img alt="중대형 아파트에 쏠린 '로또 청약' 열풍… 이유는? 사진" onerror="this.src='https://ssl.pstatic.net/static.land/static/service/20191007/noimage/noimage_102.gif'" src="https://s.pstatic.net/imgnews/image/thumb100/417/2020/12/16/632528.jpg"/></a></dt>
# <dt><a class="NP=r:5,i:417_0000632528" href="/news/newsRead.nhn?type=field&amp;news_type_cd=10&amp;prsco_id=417&amp;arti_id=0000632528">중대형 아파트에 쏠린 '로또 청약' 열풍… 이유는?</a></dt>
# <dd tabindex="0">
# 						이른바 '로또 분양' 기대감으로 청약 경쟁률이 무섭게 치솟은 가운데 추첨제 물량이 있는 중대형 면적에 대한 인기가 뜨겁다. 16일 부동산분석업체 부동산인포에 따르면 올해 수도권 청약 단...<span class="writing">머니S</span>
# <span class="date">2020.12.16</span>
# </dd>
# </dl>
# </li>
# <li>
# <dl>
# <dt class="photo"><a class="NP=r:6,i:003_0010245632" href="/news/newsRead.nhn?type=field&amp;news_type_cd=10&amp;prsco_id=003&amp;arti_id=0010245632"><img alt="전세난이 부른 새 아파트 인기…입주경기지수 '역대 최고' 사진" onerror="this.src='https://ssl.pstatic.net/static.land/static/service/20191007/noimage/noimage_102.gif'" src="https://s.pstatic.net/imgnews/image/thumb100/003/2020/12/16/10245632.jpg"/></a></dt>
# <dt><a class="NP=r:6,i:003_0010245632" href="/news/newsRead.nhn?type=field&amp;news_type_cd=10&amp;prsco_id=003&amp;arti_id=0010245632">전세난이 부른 새 아파트 인기…입주경기지수 '역대 최고'</a></dt>
# <dd tabindex="0">
# 						[서울=뉴시스] 박성환 기자 = 전세 수급 차질과 입주 물량 감소 등으로 아파트 입주경기실사지수(HOSI)가 조사 시작 이래 최고치를 기록했다. 전세난이 심해지면서 입주를 시작한 아파트의 ...<span class="writing">뉴시스</span>
# <span class="date">2020.12.16</span>
# </dd>
# </dl>
# </li>
# <li>
# <dl>
# <dt class="photo"><a class="NP=r:7,i:003_0010245595" href="/news/newsRead.nhn?type=field&amp;news_type_cd=10&amp;prsco_id=003&amp;arti_id=0010245595"><img alt="" onerror="this.src='https://ssl.pstatic.net/static.land/static/service/20191007/noimage/noimage_102.gif'" src="https://s.pstatic.net/imgnews/image/thumb100/003/2020/12/16/10245595.jpg" 고조="" 데"…저금리·전세난에="" 부동산="" 불안="" 비수기인="" 사진"="" 집값=""/></a></dt>
# <dt><a class="NP=r:7,i:003_0010245595" href="/news/newsRead.nhn?type=field&amp;news_type_cd=10&amp;prsco_id=003&amp;arti_id=0010245595">"부동산 비수기인 데"…저금리·전세난에 집값 불안 고조</a></dt>
# <dd tabindex="0">
# 						[서울=뉴시스] 이인준 기자 = 전국 아파트 매매시장이 저금리와 전세대란에 '불장'(상승장)으로 급격하게 전환되자, 부동산 비수기임에도 집값 상승에 대한 불안감이 고조되고 있다. 전세시...<span class="writing">뉴시스</span>
# <span class="date">2020.12.16</span>
# </dd>
# </dl>
# </li>
# <li>
# <dl>
# <dt class="photo"><a class="NP=r:8,i:277_0004811452" href="/news/newsRead.nhn?type=field&amp;news_type_cd=10&amp;prsco_id=277&amp;arti_id=0004811452"><img alt="전세 불안에 전국 아파트 입주경기실사지수 최고치 사진" onerror="this.src='https://ssl.pstatic.net/static.land/static/service/20191007/noimage/noimage_102.gif'" src="https://s.pstatic.net/imgnews/image/thumb100/277/2020/12/16/4811452.jpg"/></a></dt>
# <dt><a class="NP=r:8,i:277_0004811452" href="/news/newsRead.nhn?type=field&amp;news_type_cd=10&amp;prsco_id=277&amp;arti_id=0004811452">전세 불안에 전국 아파트 입주경기실사지수 최고치</a></dt>
# <dd tabindex="0">
# 						[아시아경제 임온유 기자] 전세 수급 차질과 입주 물량 감소로 불안 심리가 커지면서 전국 아파트 입주경기실사지수(HOSI)가 조사 시작 이래 최고치를 기록했다. 16일 주택산업연구원에 따르...<span class="writing">아시아경제</span>
# <span class="date">2020.12.16</span>
# </dd>
# </dl>
# </li>
# <li>
# <dl>
# <dt class="photo"><a class="NP=r:9,i:016_0001766653" href="/news/newsRead.nhn?type=field&amp;news_type_cd=10&amp;prsco_id=016&amp;arti_id=0001766653"><img alt="“서울 무권리금 상가 비율, 올 역대 최악 전망” 사진" onerror="this.src='https://ssl.pstatic.net/static.land/static/service/20191007/noimage/noimage_102.gif'" src="https://s.pstatic.net/imgnews/image/thumb100/016/2020/12/16/1766653.jpg"/></a></dt>
# <dt><a class="NP=r:9,i:016_0001766653" href="/news/newsRead.nhn?type=field&amp;news_type_cd=10&amp;prsco_id=016&amp;arti_id=0001766653">“서울 무권리금 상가 비율, 올 역대 최악 전망”</a></dt>
# <dd tabindex="0">
# 						‘임대료 멈춤법’이 큰 논란이 되고 있는 가운데, 2017년 이후로 서울시에서 권리금을 받는 상가의 비중은 꾸준히 감소하고 있는 것으로 나타났다. 무권리금 상가가 늘어난다는 것은 그만큼...<span class="writing">헤럴드경제</span>
# <span class="date">2020.12.16</span>
# </dd>
# </dl>
# </li>
# <li>
# <dl>
# <dt class="photo"><a class="NP=r:10,i:016_0001766652" href="/news/newsRead.nhn?type=field&amp;news_type_cd=10&amp;prsco_id=016&amp;arti_id=0001766652"><img alt="“세금은 반만, 이자유예는 금융사가 알아서…” 실속없는 세금멈춤법 사진" onerror="this.src='https://ssl.pstatic.net/static.land/static/service/20191007/noimage/noimage_102.gif'" src="https://s.pstatic.net/imgnews/image/thumb100/016/2020/12/16/1766652.jpg"/></a></dt>
# <dt><a class="NP=r:10,i:016_0001766652" href="/news/newsRead.nhn?type=field&amp;news_type_cd=10&amp;prsco_id=016&amp;arti_id=0001766652">“세금은 반만, 이자유예는 금융사가 알아서…” 실속없는 세금멈춤법</a></dt>
# <dd tabindex="0">
# 						코로나19로 타격을 입은 자영업자와 소상공인의 임대료 부담을 덜어주기 위한 움직임이 정부와 여당 중심으로 본격화하고 있다. 더불어민주당은 ‘공정 임대료’제도 공론화에 나섰고, 임대...<span class="writing">헤럴드경제</span>
# <span class="date">2020.12.16</span>
# </dd>
# </dl>
# </li>
# <li>
# <dl>
# <dt class="photo"><a class="NP=r:11,i:277_0004811429" href="/news/newsRead.nhn?type=field&amp;news_type_cd=10&amp;prsco_id=277&amp;arti_id=0004811429"><img alt="'임대료 멈춤법'에 또 갈라진 임대인-임차인…갈등만 커진다 사진" onerror="this.src='https://ssl.pstatic.net/static.land/static/service/20191007/noimage/noimage_102.gif'" src="https://s.pstatic.net/imgnews/image/thumb100/277/2020/12/16/4811429.jpg"/></a></dt>
# <dt><a class="NP=r:11,i:277_0004811429" href="/news/newsRead.nhn?type=field&amp;news_type_cd=10&amp;prsco_id=277&amp;arti_id=0004811429">'임대료 멈춤법'에 또 갈라진 임대인-임차인…갈등만 커진다</a></dt>
# <dd tabindex="0">
# 						[아시아경제 문제원 기자] 정부와 여당이 신종 코로나바이러스감염증(코로나19) 확산으로 힘들어진 임차인을 위해 상가 임대료를 강제로 인하하려는 움짐임을 보이자 시장의 혼란이 커지고 ...<span class="writing">아시아경제</span>
# <span class="date">2020.12.16</span>
# </dd>
# </dl>
# </li>
# <li>
# <dl>
# <dt class="photo"><a class="NP=r:12,i:277_0004811336" href="/news/newsRead.nhn?type=field&amp;news_type_cd=10&amp;prsco_id=277&amp;arti_id=0004811336"><img alt="서울 외곽 9억 이상 아파트 3배로 급증…" onerror="this.src='https://ssl.pstatic.net/static.land/static/service/20191007/noimage/noimage_102.gif'" src="https://s.pstatic.net/imgnews/image/thumb100/277/2020/12/16/4811336.jpg" 그림의떡"="" 내집마련,="" 사진"=""/></a></dt>
# <dt><a class="NP=r:12,i:277_0004811336" href="/news/newsRead.nhn?type=field&amp;news_type_cd=10&amp;prsco_id=277&amp;arti_id=0004811336">서울 외곽 9억 이상 아파트 3배로 급증…"내집마련, 그림의떡"</a></dt>
# <dd tabindex="0">
# 						[아시아경제 임온유 기자] 올해 서울 외곽 지역에서 고가 주택 기준인 9억원 이상 아파트 매매 거래량이 지난해보다 세 배 가까이 는 것으로 확인됐다. 특히 관악구의 경우 27배나 급증했다....<span class="writing">아시아경제</span>
# <span class="date">2020.12.16</span>
# </dd>
# </dl>
# </li>
# <li>
# <dl>
# <dt class="photo"><a class="NP=r:13,i:366_0000636336" href="/news/newsRead.nhn?type=field&amp;news_type_cd=10&amp;prsco_id=366&amp;arti_id=0000636336"><img alt="임대료 멈춤법 급물살에… 자영업자는 “서둘러달라” 건물주는 “절반 깎으면 우리도 망해” 사진" onerror="this.src='https://ssl.pstatic.net/static.land/static/service/20191007/noimage/noimage_102.gif'" src="https://s.pstatic.net/imgnews/image/thumb100/366/2020/12/16/636336.jpg"/></a></dt>
# <dt><a class="NP=r:13,i:366_0000636336" href="/news/newsRead.nhn?type=field&amp;news_type_cd=10&amp;prsco_id=366&amp;arti_id=0000636336">임대료 멈춤법 급물살에… 자영업자는 “서둘러달라” 건물주는 “절반 깎으면 우리도 망해”</a></dt>
# <dd tabindex="0">
# 						여당이 내놓은 상가건물 임대차보호법 개정안, 이른바 ‘임대료 멈춤법’에 대한 논의가 급물살을 타면서 자영업자들과 임대인의 의견이 팽팽하게 맞서고 있다. 신종 코로나바이러스 감염증(...<span class="writing">조선비즈</span>
# <span class="date">2020.12.16</span>
# </dd>
# </dl>
# </li>
# <li>
# <dl>
# <dt class="photo"><a class="NP=r:14,i:421_0005053361" href="/news/newsRead.nhn?type=field&amp;news_type_cd=10&amp;prsco_id=421&amp;arti_id=0005053361"><img alt="장애인명의로 아파트 14채 당첨된 장애인 대표, 웃돈 '4억' 챙겼다 사진" onerror="this.src='https://ssl.pstatic.net/static.land/static/service/20191007/noimage/noimage_102.gif'" src="https://s.pstatic.net/imgnews/image/thumb100/421/2020/12/16/5053361.jpg"/></a></dt>
# <dt><a class="NP=r:14,i:421_0005053361" href="/news/newsRead.nhn?type=field&amp;news_type_cd=10&amp;prsco_id=421&amp;arti_id=0005053361">장애인명의로 아파트 14채 당첨된 장애인 대표, 웃돈 '4억' 챙겼다</a></dt>
# <dd tabindex="0">
# 						(세종=뉴스1) 김희준 기자 = 국토교통부가 장애인의 명의를 빌려 아파트 특별공급에 당첨된 장애인 대표 A씨 등을 검찰에 입건했다. 고시원 위장전입을 통한 부정청약자도 적발했다. 16일 국...<span class="writing">뉴스1</span>
# <span class="date">2020.12.16</span>
# </dd>
# </dl>
# </li>
# <li>
# <dl>
# <dt class="photo"><a class="NP=r:15,i:018_0004808632" href="/news/newsRead.nhn?type=field&amp;news_type_cd=10&amp;prsco_id=018&amp;arti_id=0004808632"><img alt="이동주 " onerror="this.src='https://ssl.pstatic.net/static.land/static/service/20191007/noimage/noimage_102.gif'" src="https://s.pstatic.net/imgnews/image/thumb100/018/2020/12/16/4808632.jpg" 멈춤법,="" 사진"="" 생계형="" 이익"="" 임대료="" 임대인에도=""/></a></dt>
# <dt><a class="NP=r:15,i:018_0004808632" href="/news/newsRead.nhn?type=field&amp;news_type_cd=10&amp;prsco_id=018&amp;arti_id=0004808632">이동주 "임대료 멈춤법, 생계형 임대인에도 이익"</a></dt>
# <dd tabindex="0">
# 						[이데일리 신수정 기자]‘임대료 멈춤법’을 발의한 이동주 더불어민주당 의원이 임대료를 감면해 주는 것이 장기적으로는 생계형 임대인에게도 도움이 될 수 있다고 주장했다. 16일 이동주 ...<span class="writing">이데일리</span>
# <span class="date">2020.12.16</span>
# </dd>
# </dl>
# </li>
# <li>
# <dl>
# <dt class="photo"><a class="NP=r:16,i:018_0004808612" href="/news/newsRead.nhn?type=field&amp;news_type_cd=10&amp;prsco_id=018&amp;arti_id=0004808612"><img alt="" onerror="this.src='https://ssl.pstatic.net/static.land/static/service/20191007/noimage/noimage_102.gif'" src="https://s.pstatic.net/imgnews/image/thumb100/018/2020/12/16/4808612.jpg" 그="" 나갔네요"…‘부동산실장’="" 낚시영업="" 매물="" 방금="" 사진"="" 속출="" 앞세운=""/></a></dt>
# <dt><a class="NP=r:16,i:018_0004808612" href="/news/newsRead.nhn?type=field&amp;news_type_cd=10&amp;prsco_id=018&amp;arti_id=0004808612">"방금 그 매물 나갔네요"…‘부동산실장’ 앞세운 낚시영업 속출</a></dt>
# <dd tabindex="0">
# 						중개보조원 앞세운 허위매물 영업 더 교묘해져정부·플랫폼 강력 모니터링 촉구…“강한 처벌 필요”[이데일리 정두리 기자] “문의하신 매물은 방금 계약이 됐다고 하네요. 비슷한 조건의 더...<span class="writing">이데일리</span>
# <span class="date">2020.12.16</span>
# </dd>
# </dl>
# </li>
# <li>
# <dl>
# <dt class="photo"><a class="NP=r:17,i:009_0004717332" href="/news/newsRead.nhn?type=field&amp;news_type_cd=10&amp;prsco_id=009&amp;arti_id=0004717332"><img alt="서울 아파트값, 단독주택보다 1억 이상 비싸…역대 최대폭 차이 사진" onerror="this.src='https://ssl.pstatic.net/static.land/static/service/20191007/noimage/noimage_102.gif'" src="https://s.pstatic.net/imgnews/image/thumb100/009/2020/12/16/4717332.jpg"/></a></dt>
# <dt><a class="NP=r:17,i:009_0004717332" href="/news/newsRead.nhn?type=field&amp;news_type_cd=10&amp;prsco_id=009&amp;arti_id=0004717332">서울 아파트값, 단독주택보다 1억 이상 비싸…역대 최대폭 차이</a></dt>
# <dd tabindex="0">
# 						서울 아파트 가격 급등으로 단독·연립주택과의 가격 차이가 역대 최대 수준으로 벌어진 것으로 집계됐다. . 16일 KB국민은행 월간 주택가격동향 통계에 따르면, 지난달 기준 서울 아파트 평...<span class="writing">매일경제</span>
# <span class="date">2020.12.16</span>
# </dd>
# </dl>
# </li>
# <li>
# <dl>
# <dt class="photo"><a class="NP=r:18,i:016_0001766347" href="/news/newsRead.nhn?type=field&amp;news_type_cd=10&amp;prsco_id=016&amp;arti_id=0001766347"><img alt="문닫는 식당·카페…서울 주요상권서 나란히 쇠퇴의 길로 [부동산360] 사진" onerror="this.src='https://ssl.pstatic.net/static.land/static/service/20191007/noimage/noimage_102.gif'" src="https://s.pstatic.net/imgnews/image/thumb100/016/2020/12/16/1766347.jpg"/></a></dt>
# <dt><a class="NP=r:18,i:016_0001766347" href="/news/newsRead.nhn?type=field&amp;news_type_cd=10&amp;prsco_id=016&amp;arti_id=0001766347">문닫는 식당·카페…서울 주요상권서 나란히 쇠퇴의 길로 [부동산360]</a></dt>
# <dd tabindex="0">
# 						[헤럴드경제=김은희 기자] 신종 코로나바이러스 감염증(코로나19) 여파로 문 닫는 식당과 카페가 늘어나면서 서울 주요 상권에서 음식업이 업종 쇠퇴의 길에 접어들고 있는 것으로 확인됐다....<span class="writing">헤럴드경제</span>
# <span class="date">2020.12.16</span>
# </dd>
# </dl>
# </li>
# <li>
# <dl>
# <dt class="photo"><a class="NP=r:19,i:014_0004547936" href="/news/newsRead.nhn?type=field&amp;news_type_cd=10&amp;prsco_id=014&amp;arti_id=0004547936"><img alt="4억5000만원 쓴 문 대통령 임대주택 방문… 입주민은 " onerror="this.src='https://ssl.pstatic.net/static.land/static/service/20191007/noimage/noimage_102.gif'" src="https://s.pstatic.net/imgnews/image/thumb100/014/2020/12/16/4547936.jpg" 사진"="" 쇼룸"=""/></a></dt>
# <dt><a class="NP=r:19,i:014_0004547936" href="/news/newsRead.nhn?type=field&amp;news_type_cd=10&amp;prsco_id=014&amp;arti_id=0004547936">4억5000만원 쓴 문 대통령 임대주택 방문… 입주민은 "쇼룸"</a></dt>
# <dd tabindex="0">
# 						[파이낸셜뉴스] 문재인 대통령의 경기 화성동탄 임대주택 방문을 위해 4억5000만원이 사용된 것으로 나타났다. 하지만 정작 같은 단지의 4집 중 1집은 비어있고, 입주민들의 하자보수에 대한...<span class="writing">파이낸셜뉴스</span>
# <span class="date">2020.12.16</span>
# </dd>
# </dl>
# </li>
# <li>
# <dl>
# <dt class="photo"><a class="NP=r:20,i:029_0002643310" href="/news/newsRead.nhn?type=field&amp;news_type_cd=10&amp;prsco_id=029&amp;arti_id=0002643310"><img alt="아파트값만 왕창 띄운 문정부…연립주택 3채 구매할 돈과 맞먹어 사진" onerror="this.src='https://ssl.pstatic.net/static.land/static/service/20191007/noimage/noimage_102.gif'" src="https://s.pstatic.net/imgnews/image/thumb100/029/2020/12/16/2643310.jpg"/></a></dt>
# <dt><a class="NP=r:20,i:029_0002643310" href="/news/newsRead.nhn?type=field&amp;news_type_cd=10&amp;prsco_id=029&amp;arti_id=0002643310">아파트값만 왕창 띄운 문정부…연립주택 3채 구매할 돈과 맞먹어</a></dt>
# <dd tabindex="0">
# 						[디지털타임스 박상길 기자] 서울 아파트 가격이 급등하면서 단독·연립주택과의 가격 차가 가장 많이 벌어졌다. 서울 아파트 1채 가격이면 연립주택을 3채는 살 수 있다. 16일 KB국민은행 부...<span class="writing">디지털타임스</span>
# <span class="date">2020.12.16</span>
# </dd>
# </dl>
# </li>
# </ul>
# </div>
# <div class="paginate paginate_line NEI=a:lst.page">
# <a class="NP=r:1" href="javascript:goPage(1)" style="margin-right:0px; padding:0px 0px 0px 0px; background:#fff;"><strong>1</strong></a>
# <a class="NP=r:2" href="javascript:goPage(2)">2</a>
# <a class="NP=r:3" href="javascript:goPage(3)">3</a>
# <a class="next NP=r:2" href="javascript:goPage(2)">다음페이지 </a>
# </div>
# <div class="paginate_day NEI=a:lst.date">
# <span class="viewday" tabindex="0">12월16일(수)</span>
# <span class="devidebar">·</span>
# <a class="NP=r:2,i=20201215" href="?bss_ymd=20201215&amp;news_type_cd=10">12월15일(화)</a>
# <span class="devidebar">·</span>
# <a class="NP=r:3,i=20201214" href="?bss_ymd=20201214&amp;news_type_cd=10">12월14일(월)</a>
# <span class="devidebar">·</span>
# <a class="NP=r:4,i=20201211" href="?bss_ymd=20201211&amp;news_type_cd=10">12월11일(금)</a>
# <span class="devidebar">·</span>
# <a class="NP=r:5,i=20201210" href="?bss_ymd=20201210&amp;news_type_cd=10">12월10일(목)</a>
# </div>
# </div>
# <hr/>
# <div class="aside">
# <!-- DA BANNER -->
# <div id="da_280240" name="da_280240">
# <iframe align="middle" data-veta-preview="land_new" frameborder="0" height="240" id="f280240" marginheight="0" marginwidth="0" name="f280240" scrolling="no" src="https://veta.naver.com/fxshow?su=SU10354&amp;rui=20201217091607889" title="광고" width="280"></iframe>
# </div>
# <!-- //og:tag --><div class="section_aside line NE=a:rhi">
# <h3 class="tit_h3 h_issue">
# <span>이슈</span>
# <strong tabindex="0">11.19 전세대책</strong>
# </h3>
# <ul class="issue_list NI=a:list">
# <li><a class="NP=r:1,i:011_0003841163" href="/news/newsRead.nhn?source=aside&amp;type=issueView&amp;isu_no=102132&amp;prsco_id=011&amp;arti_id=0003841163">원룸 곳곳 넘쳐나는데···정부 전세대책...</a></li>
# <li><a class="NP=r:2,i:009_0004714641" href="/news/newsRead.nhn?source=aside&amp;type=issueView&amp;isu_no=102132&amp;prsco_id=009&amp;arti_id=0004714641">11·19 대책 후 경기 김포·부산 해운대 ...</a></li>
# <li><a class="NP=r:3,i:015_0004464612" href="/news/newsRead.nhn?source=aside&amp;type=issueView&amp;isu_no=102132&amp;prsco_id=015&amp;arti_id=0004464612">11·19대책 후폭풍…김포 거래량 '반토막...</a></li>
# <li><a class="NP=r:4,i:016_0001761685" href="/news/newsRead.nhn?source=aside&amp;type=issueView&amp;isu_no=102132&amp;prsco_id=016&amp;arti_id=0001761685">전세대책, 불안감만 더 키웠나…서울 아...</a></li>
# <li><a class="NP=r:5,i:119_0002449045" href="/news/newsRead.nhn?source=aside&amp;type=issueView&amp;isu_no=102132&amp;prsco_id=119&amp;arti_id=0002449045">정부 실책 전세대란에 ‘부동산 예산’ ...</a></li>
# </ul>
# <a class="btn_more NPI=a:more" href="/news/issueView.nhn?isu_no=102132">더보기</a>
# </div>
# <div class="section_aside line NE=a:rln" id="region_news_control">
# <h3 class="tit_h3 h_area"><span tabindex="0">우리동네뉴스</span></h3>
# <p class="category area1" id="region_select_area">
# <a class="total NPI=a:all" href="#" onclick="setAreaByAside('total');return false;" rcode="total"><strong>종합</strong></a>
# <span class="area1">
# <span class="bar">|</span>
# <a class="NPI=a:region,i:1100000000" href="#" onclick="setAreaByAside('1100000000');return false;" rcode="1100000000">서울</a>
# <span class="bar">|</span>
# <a class="NPI=a:region,i:4100000000" href="#" onclick="setAreaByAside('4100000000');return false;" rcode="4100000000">경기</a>
# <span class="bar">|</span>
# <a class="NPI=a:region,i:2800000000" href="#" onclick="setAreaByAside('2800000000');return false;" rcode="2800000000">인천</a>
# <span class="bar">|</span>
# <a class="NPI=a:region,i:2600000000" href="#" onclick="setAreaByAside('2600000000');return false;" rcode="2600000000">부산</a>
# </span>
# <span class="area2">
# <span class="bar">|</span>
# <a class="NPI=a:region,i:3000000000" href="#" onclick="setAreaByAside('3000000000');return false;" rcode="3000000000">대전</a>
# <span class="bar">|</span>
# <a class="NPI=a:region,i:2700000000" href="#" onclick="setAreaByAside('2700000000');return false;" rcode="2700000000">대구</a>
# <span class="bar">|</span>
# <a class="NPI=a:region,i:3100000000" href="#" onclick="setAreaByAside('3100000000');return false;" rcode="3100000000">울산</a>
# <span class="bar">|</span>
# <a class="NPI=a:region,i:3600000000" href="#" onclick="setAreaByAside('3600000000');return false;" rcode="3600000000">세종</a>
# </span>
# <span class="area3">
# <span class="bar">|</span>
# <a class="NPI=a:region,i:2900000000" href="#" onclick="setAreaByAside('2900000000');return false;" rcode="2900000000">광주</a>
# <span class="bar">|</span>
# <a class="NPI=a:region,i:4200000000" href="#" onclick="setAreaByAside('4200000000');return false;" rcode="4200000000">강원</a>
# <span class="bar">|</span>
# <a class="NPI=a:region,i:4300000000" href="#" onclick="setAreaByAside('4300000000');return false;" rcode="4300000000">충북</a>
# <span class="bar">|</span>
# <a class="NPI=a:region,i:4400000000" href="#" onclick="setAreaByAside('4400000000');return false;" rcode="4400000000">충남</a>
# </span>
# <span class="area4">
# <span class="bar">|</span>
# <a class="NPI=a:region,i:4700000000" href="#" onclick="setAreaByAside('4700000000');return false;" rcode="4700000000">경북</a>
# <span class="bar">|</span>
# <a class="NPI=a:region,i:4800000000" href="#" onclick="setAreaByAside('4800000000');return false;" rcode="4800000000">경남</a>
# <span class="bar">|</span>
# <a class="NPI=a:region,i:4500000000" href="#" onclick="setAreaByAside('4500000000');return false;" rcode="4500000000">전북</a>
# <span class="bar">|</span>
# <a class="NPI=a:region,i:4600000000" href="#" onclick="setAreaByAside('4600000000');return false;" rcode="4600000000">전남</a>
# </span>
# <span class="area5">
# <span class="bar">|</span>
# <a class="NPI=a:region,i:5000000000" href="#" onclick="setAreaByAside('5000000000');return false;" rcode="5000000000">제주</a>
# <span class="btn_area">
# <a class="btn prev NPI=a:prev" href="#" onclick="moveAreaSelect(-1);return false;"><span>이전</span></a>
# <a class="btn next NPI=a:next" href="#" onclick="moveAreaSelect(1);return false;"><span>다음</span></a>
# </span>
# </span></p>
# <div class="area_on NI=a:list" id="total_news">
# <ul class="category_list">
# <li>
# <a class="area NP=r:1,i:421_0005053345" href="region.nhn?city_no=1100000000&amp;dvsn_no=1156000000">[영등포구]</a>
# <a class="NP=r:1,i:421_0005053345" href="/news/newsRead.nhn?source=aside&amp;type=region&amp;city_no=1100000000&amp;dvsn_no=1156000000&amp;prsco_id=421&amp;arti_id=0005053345">
# 						서울 영등포구 '쪽방촌 정...</a>
# </li>
# <li>
# <a class="area NP=r:2,i:417_0000632315" href="region.nhn?city_no=1100000000&amp;dvsn_no=1130500000">[강북구]</a>
# <a class="NP=r:2,i:417_0000632315" href="/news/newsRead.nhn?source=aside&amp;type=region&amp;city_no=1100000000&amp;dvsn_no=1130500000&amp;prsco_id=417&amp;arti_id=0000632315">
# 						서울 최고도지역 우이동 55...</a>
# </li>
# <li>
# <a class="area NP=r:3,i:001_0012083601" href="region.nhn?city_no=3000000000&amp;dvsn_no=3017000000">[서구]</a>
# <a class="NP=r:3,i:001_0012083601" href="/news/newsRead.nhn?source=aside&amp;type=region&amp;city_no=3000000000&amp;dvsn_no=3017000000&amp;prsco_id=001&amp;arti_id=0012083601">
# 						대전시 2023년까지 5만6천...</a>
# </li>
# <li>
# <a class="area NP=r:4,i:018_0004808524" href="region.nhn?city_no=1100000000&amp;dvsn_no=1159000000">[동작구]</a>
# <a class="NP=r:4,i:018_0004808524" href="/news/newsRead.nhn?source=aside&amp;type=region&amp;city_no=1100000000&amp;dvsn_no=1159000000&amp;prsco_id=018&amp;arti_id=0004808524">
# 						동작구 본동종합사회복지관...</a>
# </li>
# <li>
# <a class="area NP=r:5,i:421_0005051466" href="region.nhn?city_no=4300000000&amp;dvsn_no=4313000000">[충주시]</a>
# <a class="NP=r:5,i:421_0005051466" href="/news/newsRead.nhn?source=aside&amp;type=region&amp;city_no=4300000000&amp;dvsn_no=4313000000&amp;prsco_id=421&amp;arti_id=0005051466">
# 						국토부, 수소충전 복합기지...</a>
# </li>
# <li>
# <a class="area NP=r:6,i:277_0004810510" href="region.nhn?city_no=1100000000&amp;dvsn_no=1171000000">[송파구]</a>
# <a class="NP=r:6,i:277_0004810510" href="/news/newsRead.nhn?source=aside&amp;type=region&amp;city_no=1100000000&amp;dvsn_no=1171000000&amp;prsco_id=277&amp;arti_id=0004810510">
# 						서울시, 문정역 인근에 '역...</a>
# </li>
# <li>
# <a class="area NP=r:7,i:001_0012075348" href="region.nhn?city_no=4500000000&amp;dvsn_no=4575000000">[임실군]</a>
# <a class="NP=r:7,i:001_0012075348" href="/news/newsRead.nhn?source=aside&amp;type=region&amp;city_no=4500000000&amp;dvsn_no=4575000000&amp;prsco_id=001&amp;arti_id=0012075348">
# 						"좋은 일에 부동산 쓰라"…...</a>
# </li>
# <li>
# <a class="area NP=r:8,i:018_0004805411" href="region.nhn?city_no=1100000000&amp;dvsn_no=1174000000">[강동구]</a>
# <a class="NP=r:8,i:018_0004805411" href="/news/newsRead.nhn?source=aside&amp;type=region&amp;city_no=1100000000&amp;dvsn_no=1174000000&amp;prsco_id=018&amp;arti_id=0004805411">
# 						[동네방네]강동구, 골목길 ...</a>
# </li>
# <li>
# <a class="area NP=r:9,i:003_0010236514" href="region.nhn?city_no=2600000000&amp;dvsn_no=2635000000">[해운대구]</a>
# <a class="NP=r:9,i:003_0010236514" href="/news/newsRead.nhn?source=aside&amp;type=region&amp;city_no=2600000000&amp;dvsn_no=2635000000&amp;prsco_id=003&amp;arti_id=0010236514">
# 						부산시 ‘센텀2지구 도시첨...</a>
# </li>
# <li>
# <a class="area NP=r:10,i:001_0012071273" href="region.nhn?city_no=4800000000&amp;dvsn_no=4812100000">[창원시]</a>
# <a class="NP=r:10,i:001_0012071273" href="/news/newsRead.nhn?source=aside&amp;type=region&amp;city_no=4800000000&amp;dvsn_no=4812100000&amp;prsco_id=001&amp;arti_id=0012071273">
# 						"집 걱정 없이 일하세요"…...</a>
# </li>
# </ul>
# </div>
# <div class="area_off NI=a:list" id="area_news">
# <ul class="category_list" id="region_news_area">
# <script defer="defer" id="region_news_template" type="text/template">
# 				{for idx:news in newsList}
# 					{if idx < 10 }
# 					<li>
# 						<a href="region.nhn?city_no={=current}&dvsn_no={=news.cortar1_no}" class="area NP=r:{=idx+1},i={=news.prsco_id}_{=news.arti_id}">[{js splitRegionName(=news.dvsn_nm,0)}]</a>
# 						<a href="/news/newsRead.nhn?source=aside&type=region&city_no={=current}&dvsn_no={=news.cortar1_no}&prsco_id={=news.prsco_id}&arti_id={=news.arti_id}" class="NP=r:{=idx+1},i={=news.prsco_id}_{=news.arti_id}">{js cutStringByPixel(=news.ttl,160,'...')}</a>
# 					</li>
# 					{/if}
# 				{/for}
# 			</script>
# </ul>
# </div>
# <a class="btn_more NPI=a:more" href="#" onclick="goRegionNews();return false">더보기</a>
# </div>
# </div>
# </div><!-- footer -->
# <script language="javascript" src="https://ssl.pstatic.net/static/common/js/cs_ops_webncc.js" type="text/javascript"></script>
# <div id="footer">
# <div class="footwrap NE=a:fot">
# <fieldset>
# <legend class="blind">검색</legend>
# <div class="sta_search_box NE=a:lsc">
# <input accesskey="s" class="sta_search_text" id="queryInputFooter" onfocus="searchInputBoxFocus(this);" onkeyup="serviceInternalSearchEnterCheck(event,1);" query="" searchareaclicked="false" searchtype="Promotion" title="검색" type="text" value=""/>
# <a class="btn_search NPI=a:search" href="#" onclick="serviceInternalSearchFooter();return false;">검색</a>
# <a class="btn_search2 NPI=a:nx" href="#" onclick="serviceInternalTotalSearchFooter();return false;" title="새창 열림">통합검색</a>
# </div>
# </fieldset>
# <ul class="NE=a:fot">
# <li class="first"><a class="NPI=a:service" href="http://www.naver.com/policy/service.html">이용약관</a></li>
# <li><a href="/index/declaredArticlePolicy.nhn">매물신고운영</a></li>
# <li><a class="NPI=a:privacy" href="http://www.naver.com/rules/privacy.html" target="_blank" title="새창 열림"><strong>개인정보처리방침 </strong></a></li>
# <li><a class="NPI=a:help" href="#" onclick="OPS.viewOPS('ops', {url : 'https://help.naver.com/support/alias/land/landmain.naver'}); return false;" title="새창 열림">부동산 고객센터</a></li>
# </ul>
# <p class="info" tabindex="0">네이버부동산에서 제공하는 부동산 정보는 각 콘텐츠 제공업체로부터 받는 정보로 참고용입니다.<br/>
#                                          정보의 정확성이나 신뢰성을 보증하지 않으며, 서비스 이용의 결과에 대해서 어떠한 법적인 책임을 지지 않습니다. 게시된 정보는 무단으로 배포할 수 없습니다.</p>
# <address>
# <a class="logo N=a:fot.nbpcorp" href="http://www.navercorp.com/ko/index.nhn" target="_blank"><span class="blind">NAVER</span></a>
# <em>Copyright ⓒ</em> <a href="http://www.navercorp.com/ko/index.nhn" target="_blank">NAVER Corp.</a> <span>All Rights Reserved.</span>
# </address>
# </div>
# </div>
# <!-- //footer --></div>
# </body>
# <script src="https://ssl.pstatic.net/static.land/static/service/js/202011051426/min/news/news.jindo.js" type="text/javascript"></script><script src="https://ssl.pstatic.net/static.land/static/service/js/202011051426/min/news/news.util.js" type="text/javascript"></script><script src="https://ssl.pstatic.net/static.land/static/service/js/202011051426/min/news/news.js" type="text/javascript"></script><script type="text/javascript">
# var oDatePickerdate1,
# oDatePickerdate2;
#
# //뉴스홈 우측하단 rolling 부분
# if(typeof(rolling) == "function"){
# 	rolling();
# }
#
# //이벤트 Listener 함수 호출
# nclk_do();
#
#
#
# // 전문가칼럼 등록기간
# if ($('writer_sel') != null){
# 	var writerSel = new ISelectBox($("writer_sel"),{ width : "172", height : false, bUseDefaultOption : false });
# 	dateShow_date1();dateShow_date2();
# }
#
# // 실시간 속보 뉴스 검색
# if ($('searchForm') != null){
# 	var sdate1 = $("date1");
# 	var sdate2 = $("date2");
# }
#
# if ($('issue_sel') != null){
# 	new ISelectBox($('issue_sel'),{ width : "229", height : false, bUseDefaultOption : false });
# }
# </script>
# </html>

# %%
whole_source = ""
for page_number in range(1, maximum+1):
	URL = 'http://land.naver.com/news/field.nhn?page=' + str(page_number)
	response = requests.get(URL)
	whole_source = whole_source + response.text
soup = BeautifulSoup(whole_source, 'html.parser')
find_title = soup.select("#content > div.section_headline > ul > li > dl > dt > a")

for title in find_title:
	print(title.text)
# Out:
# 규제지역 집값 다시 올랐다.."부동산 정책이 시장 교란"
#
# 2030세대 ‘오직 아파트’ ···단독·연립과 가격차 ‘역대급
#
# “무주택자는 치솟는 전셋값, 유주택자는 세금때문에 못살겠다”…2020 부동산에선 누구도 행복하지 않았다 [부동산360]
#
# 전국 주택 매매시장 소비심리, 5년7개월 만에 최고
#
# 중대형 아파트에 쏠린 '로또 청약' 열풍… 이유는?
#
# 전세난이 부른 새 아파트 인기…입주경기지수 '역대 최고'
#
# "부동산 비수기인 데"…저금리·전세난에 집값 불안 고조
#
# 전세 불안에 전국 아파트 입주경기실사지수 최고치
#
# “서울 무권리금 상가 비율, 올 역대 최악 전망”
#
# “세금은 반만, 이자유예는 금융사가 알아서…” 실속없는 세금멈춤법
#
# '임대료 멈춤법'에 또 갈라진 임대인-임차인…갈등만 커진다
#
# 서울 외곽 9억 이상 아파트 3배로 급증…"내집마련, 그림의떡"
#
# 임대료 멈춤법 급물살에… 자영업자는 “서둘러달라” 건물주는 “절반 깎으면 우리도 망해”
#
# 장애인명의로 아파트 14채 당첨된 장애인 대표, 웃돈 '4억' 챙겼다
#
# 이동주 "임대료 멈춤법, 생계형 임대인에도 이익"
#
# "방금 그 매물 나갔네요"…‘부동산실장’ 앞세운 낚시영업 속출
#
# 서울 아파트값, 단독주택보다 1억 이상 비싸…역대 최대폭 차이
#
# 문닫는 식당·카페…서울 주요상권서 나란히 쇠퇴의 길로 [부동산360]
#
# 4억5000만원 쓴 문 대통령 임대주택 방문… 입주민은 "쇼룸"
#
# 아파트값만 왕창 띄운 문정부…연립주택 3채 구매할 돈과 맞먹어
#
# 서울시장 보궐선거 부동산 공약은?… 여야 '아파트 공급' 최대 관심사
#
# "변창흠도 인정?" 규제지역 해제 기대에 꿈틀대는 청주 집값
#
# 서울 '아파트 불패' 심화…단독·연립주택과 가격차 역대 최대
#
# 코픽스 1.5% 오르니 서울 아파트 주담대 '한달이자 45만원' 오르네
#
# [김하나의 R까기] "文 대통령 말 일리있다"…4년 전에는
#
# ‘공정 임대료’ 속도에···그럼 "이자·세금도 깎아주나" 갈등
#
# [인터뷰] "집 사서 돈 벌려면 OO이 가장 중요하죠"
#
# 조정대상지역 지정에도 김포 아파트 잇달아 신고가…"실수요 매수 여전"
#
# 연말 ‘대출 한파’, 신용대출 규제에 주담대 금리까지 ‘꿈틀’
#
# [문정권 부동산 말말말②] “일산 내 집 정도는 5억원에 산다”
#
# 청주시 집값·전셋값 하락, 매매량도 뚝…조정지역 해제 하세월
#
# 서울 보선 앞두고 부동산 공약 속속…효과·실현 가능성 '글쎄'
#
# 1인 가구 잡으면 전세난 해결된다면서 정책은 온통 '엇박자'
#
# [단독]'역 추가vs통과 반대' 갈라진 GTX, "갈등 해결 능력도 평가"
#
# "공급 막힌 서울, 내년 집값도 답없다"[부릿지]
#
# “다시 오르는 강남” 토지거래허가구역 잠실·대치도 연이은 신고가
#
# "돌고 돌아 강남"…다시 꿈틀대는 강남 집값 왜?
#
# "희망은 추첨 뿐"…중대형 아파트 청약에 구름 인파
#
# 변창흠이 받았던 ‘보금자리론’, 이제 서울선 어려워
#
# 올해 6차례 대책에도 전국 집값 6.89% 올라… 盧정부 이후 최대 폭
#
# ‘수도권 마지막 비규제’ 파주, 집값 상승률 1위
# 내년부터 건설사가 입주 전 전용부분 하자조치 의무화
# 아파트 분양사업실적 사상 최고

# %%
soup
# Out:
# <!DOCTYPE HTML PUBLIC "-//W3C//DTD HTML 4.01 Transitional//EN" "http://www.w3.org/TR/html4/loose.dtd">
#
# <html lang="ko">
# <head>
# <meta content="text/html; charset=utf-8" http-equiv="Content-Type"/>
# <meta contents="always" name="referrer">
# <meta content="IE=Edge" http-equiv="X-UA-Compatible"/>
# <title>
# 뉴스 : 네이버 부동산</title>
# <script type="text/javascript">
# document.domain = "naver.com";
#
# var ccsrv="cc.naver.com";
# var g_query = "";
# var nclk_evt = 3;
# </script>
# <link href="https://ssl.pstatic.net/static.land/static/service/css/202011051426/min/news/news.css" rel="stylesheet" type="text/css"/><script type="text/javascript">	document.domain = 'naver.com';</script>
# <script src="https://ssl.pstatic.net/static.land/static/service/js/202011051426/search/flashObject.js" type="text/javascript"></script><script type="text/javascript">
# 	nsc = "land.news_cn";
# 	document.title="분야별뉴스, 뉴스 : 내집마련의 시작, 네이버 부동산";
# </script><style type="text/css">
# .wordwrap
# {
#      word-wrap:break-word;
#      word-break:break-all;
#      -moz-binding: url('/css/wordwrap.xml#wordwrap');
#      overflow: hidden;
# }
# </style>
# <meta content="네이버부동산 " property="me2:post_tag"/>
# <meta content="네이버부동산" property="me2:category1"/>
# <meta content="" property="me2:category2"/>
# <!DOCTYPE HTML PUBLIC "-//W3C//DTD HTML 4.01 Transitional//EN" "http://www.w3.org/TR/html4/loose.dtd">
#
# <!-- og:tag -->
# <link href="http://land.naver.com" rel="canonical"/>
# <meta content="land" property="og:site_name"/>
# <meta content="네이버 부동산" property="og:title"/>
# <meta content="article" property="og:type"/>
# <meta content="네이버 부동산 분야별 뉴스" property="og:description"/>
# <meta content="네이버 부동산 분야별 뉴스" name="description"/>
# <meta content="https://landthumb-phinf.pstatic.net/20201030_229/land_naver_1604037626049TB83t_PNG/%B3%D7%C0%CC%B9%F6_%BA%CE%B5%BF%BB%EA.png" property="og:image">
# <meta content="네이버 부동산" property="og:article:author"/>
# <meta content="https://land.naver.com/news/field.nhn?page=1" property="og:url"/>
# <meta content="http://land.naver.com/" property="og:article:author:url"/>
# <!-- //og:tag -->
# <script type="text/javascript">
# 	photoDomain = "https://landthumb-phinf.pstatic.net";
#
# 	serviceImageUrl = "https://ssl.pstatic.net/static.land/static/service/20191007";
#
# 	today = "20201217";
#
#
# 	function getDefaultImage(width) {
# 		var dfltImgUrl = "";
#
# 		if(width >= 120){
# 			if(width > 206){
# 				dfltImgUrl = serviceImageUrl +"/noimage/noimage_232.gif";
# 			}else if(width > 196){
# 				dfltImgUrl = serviceImageUrl +"/noimage/noimage_206.gif";
# 			}else if(width > 120 ){
# 				dfltImgUrl = serviceImageUrl +"/noimage/noimage_196.gif";
# 			}else{
# 				dfltImgUrl = serviceImageUrl +"/noimage/noimage_120.gif";
# 			}
# 		}else{
# 			if(width > 102){
# 				dfltImgUrl = serviceImageUrl +"/noimage/noimage_120.gif";
# 			}else if(width > 83){
# 				dfltImgUrl = serviceImageUrl +"/noimage/noimage_102.gif";
# 			}else if(width > 63 ){
# 				dfltImgUrl = serviceImageUrl +"/noimage/noimage_083.gif";
# 			}else{
# 				dfltImgUrl = serviceImageUrl +"/noimage/noimage_063.gif";
# 			}
# 		}
# 		return dfltImgUrl;
# 	}
#
# 	function getPhotoInfraImg(photo, type, width) {
# 		if(photo == null || photo == "") {
# 			return getDefaultImage(width);
# 		} else {
# 			if(type == null || type == "" || typeof type == "undefined") {
# 				return photoDomain + "/" + photo;
# 			} else {
# 				return photoDomain + "/" + photo + "?type=" + type;
# 			}
# 		}
# 	}
#
# 	function errorImg(el , dWidth) {
#
# 		var width = dWidth || Number(el.getAttribute("width"));
# 		if(el.src.indexOf("noimage") > -1){
# 			return;
# 		}
# 		el.src = getDefaultImage(width);
# 	}
#
# 	function generatePhotoInfraImgTag(hashAttr, type) {
#
# 		var isEmpty = function (value) {
# 			if (!value || value == null || value == "" || typeof value == "undefined") {
# 				return true;
# 			}
# 			return false;
# 		};
#
# 		var tagAttrs = "";
# 		var attachAttr = function(value, key) {
# 			tagAttrs += " " + key + "=\"" + value + "\"";
# 		};
#
# 		var dfltImgUrl = getDefaultImage(hashAttr.$("width"));
#
# 		if (isEmpty(hashAttr.$("src"))) {
# 			hashAttr.add("src", dfltImgUrl);
# 		} else {
# 			hashAttr.add("src", photoDomain + hashAttr.$("src"));
#
# 			if (!isEmpty(type)) {
# 				hashAttr.add("src", hashAttr.$("src") + "?type=" + type);
# 			}
# 		}
#
# 		hashAttr.forEach(attachAttr);
#
# 		return "<img " + tagAttrs + " onerror=\"errorImg(this)\">";
# 	}
# </script></meta></meta></head>
# <body class="" onload="">
# <div id="wrap">
# <div id="u_skip">
# <a href="#lnb" onclick="document.getElementById('lnb').tabIndex = -1;document.getElementById('lnb').focus();return false;"><span>메인 메뉴로 바로가기</span></a>
# <a href="#container" onclick="document.getElementById('container').tabIndex = -1;document.getElementById('container').focus();return false;"><span>하위 메뉴로 바로가기</span></a>
# <a href="#content" onclick="document.getElementById('content').tabIndex = -1;document.getElementById('content').focus();return false;"><span>본문으로 바로가기</span></a>
# </div>
# <div id="pvframe" style="display:none;"></div>
# <!-- header -->
# <script src="https://ssl.pstatic.net/static.land/static/service/js/202011051426/lib/lcslog.js" type="text/javascript"></script><script src="https://wcs.naver.net/wcslog.js" type="text/javascript"></script>
# <script type="text/javascript">
# 	lcs_do();
#
# 	if(!wcs_add) var wcs_add = {};
# 	wcs_add["wa"] = "60717a12f2b3c8";
# 	if(typeof wcs_do !== 'undefined') wcs_do();
# </script>
# <div class="header_one" id="header">
# <div class="gnb_wrap">
# <div class="inner_wrap">
# <div class="item_area NE=a:STA">
# <h1 class="logo_area">
# <a class="logo_naver NPI=a:naverlogo" href="http://www.naver.com/"><i class="icon">NAVER</i></a>
# <a class="logo_land NPI=a:land" href="http://land.naver.com/"><i class="icon">부동산</i></a>
# </h1>
# <div class="inner_gnb_search">
# <h2 class="blind">검색영역</h2>
# <fieldset>
# <legend>검색</legend>
# <!-- [D] 입력위해 focus 가지면 sta_text_ovr 추가 -->
# <input name="where" type="hidden" value="nexearch"/>
# <input name="sm" type="hidden" value="top_hty"/>
# <input name="fbm" type="hidden" value="1"/>
# <input id="serviceInternalSearchQuery" name="query" type="hidden" value=""/>
# <input id="internalSearchURL" name="internalSearchURL" type="hidden" value="https://land.naver.com"/>
# <input accesskey="s" class="search_input sta_search_text" id="queryInputHeader" onfocus="searchInputBoxFocus(this);" onkeyup="serviceInternalSearchEnterCheck(event,0);" query="" searchareaclicked="false" searchtype="Promotion" title="검색" type="text" value=""/>
# <a class="search_button type_inside NPI=a:search" href="#" onclick="serviceInternalSearch();return false;"><i class="icon">검색</i></a>
# <a class="search_button type_integration NPI=a:nx" href="#" onclick="serviceInternalTotalSearch();return false;" title="새창 열림"><i class="icon">통합검색</i></a>
# </fieldset>
# </div>
# </div>
# <div class="gnb_area">
# <div id="gnb">
# <script charset="utf-8" src="https://ssl.pstatic.net/static.gn/templates/gnb_utf8.nhn?20201217" type="text/javascript"></script>
# </div>
# </div>
# </div>
# </div>
# <div class="nav_wrap" id="lnb">
# <h2 class="blind">메인메뉴</h2>
# <div class="inner_wrap">
# <!-- [D] 활성화 클래스 on -->
# <ul class="nav_list NE=a:LNB">
# <li class="menu main_home">
# <a class="NPI=a:home" href="/">부동산홈</a>
# </li>
# <li class="menu main_article_beta">
# <a class="NPI=a:article_beta" href="https://new.land.naver.com/complexes">매물베타</a>
# </li>
# <li class="menu main_isale">
# <a class="NPI=a:sale" href="https://isale.land.naver.com/iSale/Map/">분양</a>
# </li>
# <li class="menu main_news on">
# <a class="NPI=a:news" href="/news/">뉴스</a>
# </li>
# <li class="menu main_community">
# <a class="NPI=a:community" href="/community/">커뮤니티</a>
# </li>
# <li class="menu main_auction">
# <a class="NPI=a:auction" href="/auction/">경매</a>
# </li>
# <li class="menu main_mypage">
# <a class="NPI=a:mypage" href="https://new.land.naver.com/interests">MY페이지</a>
# </li>
# <!--[if lte IE 9]>
# 						<li id="_ieVerCheck" class="hidden ie9"></li>
# 					<![endif]-->
# </ul>
# <div class="button_area NE=a:LNB">
# <a class="type_admin NPI=a:landad" href="http://landad.naver.com/" target="_blank">부동산관리센터</a>
# </div>
# </div>
# </div>
# <div class="sub_nav_wrap">
# <h2 class="blind">서브메뉴</h2>
# <div class="inner_wrap">
# <!-- [D] 활성화 클래스 on -->
# <ul class="sub_nav_list NE=a:LNB">
# <li class="menu news_headline"><a class="on" href="/news/headline.nhn">주요뉴스</a></li>
# <li class="menu news_region"><a class="on" href="/news/region.nhn">우리동네뉴스</a></li>
# <li class="menu news_issue"><a class="on" href="/news/hotIssue.nhn">핫이슈</a></li>
# <li class="menu news_field on"><a class="on" href="/news/field.nhn">분야별뉴스</a></li>
# <li class="menu news_breaking"><a class="on" href="/news/breaking.nhn">실시간속보</a></li>
# <li class="menu news_expert"><a class="on" href="/news/expertColumn.nhn">부동산칼럼</a></li>
# <li class="menu news_magazine"><a class="on" href="/news/magazine.nhn">매거진</a></li>
# <li class="menu news_trend"><a class="on" href="/news/trendReport.nhn">동향보고서</a></li>
# </ul>
# </div>
# </div>
# </div>
# <!-- //header --><!--하위 컨텐츠 및 Aside Component 영역 List Container -->
# <div id="container">
# <div id="content">
# <h2 class="h_news field" tabindex="0"><span>분야별 뉴스</span></h2>
# <div class="section_field NEI=a:cat.title">
# <a class="NP=r:1,i:10" href="#"><strong>시장동향</strong></a>
# <span class="bar">|</span>
# <a class="NP=r:2,i:20" href="?news_type_cd=20">정책/제도</a>
# <span class="bar">|</span>
# <a class="NP=r:3,i:30" href="?news_type_cd=30">개발정보</a>
# <span class="bar">|</span>
# <a class="NP=r:4,i:40" href="?news_type_cd=40">분양</a>
# <span class="bar">|</span>
# <a class="NP=r:5,i:50" href="?news_type_cd=50">업계동향</a>
# <span class="bar">|</span>
# <a class="NP=r:6,i:60" href="?news_type_cd=60">부동산금융</a>
# <span class="bar">|</span>
# <a class="NP=r:7,i:70" href="?news_type_cd=70">경매/공매</a>
# <span class="bar">|</span>
# <a class="NP=r:8,i:80" href="?news_type_cd=80">기타</a>
# </div>
# <div class="section_headline">
# <ul class="headline_list NEI=a:lst.title">
# <li>
# <dl>
# <dt class="photo"><a class="NP=r:1,i:014_0004548354" href="/news/newsRead.nhn?type=field&amp;news_type_cd=10&amp;prsco_id=014&amp;arti_id=0004548354"><img alt="규제지역 집값 다시 올랐다.." onerror="this.src='https://ssl.pstatic.net/static.land/static/service/20191007/noimage/noimage_102.gif'" src="https://s.pstatic.net/imgnews/image/thumb100/014/2020/12/16/4548354.jpg" 교란"="" 부동산="" 사진"="" 시장="" 정책이=""/></a></dt>
# <dt><a class="NP=r:1,i:014_0004548354" href="/news/newsRead.nhn?type=field&amp;news_type_cd=10&amp;prsco_id=014&amp;arti_id=0004548354">규제지역 집값 다시 올랐다.."부동산 정책이 시장 교란"</a></dt>
# <dd tabindex="0">
# 						[파이낸셜뉴스]6·17 대책 당시 규제지역으로 묶인 수도권 지역들의 집값이 다시 반등하면서 '규제 무용론'이 불거지고 있다. 정부가 11·19 전세대책을 내놨지만 오히려 공급에 한계를 드러내...<span class="writing">파이낸셜뉴스</span>
# <span class="date">2020.12.16</span>
# </dd>
# </dl>
# </li>
# <li>
# <dl>
# <dt class="photo"><a class="NP=r:2,i:011_0003842946" href="/news/newsRead.nhn?type=field&amp;news_type_cd=10&amp;prsco_id=011&amp;arti_id=0003842946"><img alt="2030세대 ‘오직 아파트’ ···단독·연립과 가격차 ‘역대급 사진" onerror="this.src='https://ssl.pstatic.net/static.land/static/service/20191007/noimage/noimage_102.gif'" src="https://s.pstatic.net/imgnews/image/thumb100/011/2020/12/16/3842946.jpg"/></a></dt>
# <dt><a class="NP=r:2,i:011_0003842946" href="/news/newsRead.nhn?type=field&amp;news_type_cd=10&amp;prsco_id=011&amp;arti_id=0003842946">2030세대 ‘오직 아파트’ ···단독·연립과 가격차 ‘역대급</a></dt>
# <dd tabindex="0">
# 						[서울경제] 서울 아파트값과 단독·연립주택 가격 격차가 역대 최대 수준으로 벌어진 것으로 나타났다. 시장에서 ‘아파트 편애’ 현상이 심화한 것이다. 16일 KB부동산 월간 주택가격동향 시...<span class="writing">서울경제</span>
# <span class="date">2020.12.16</span>
# </dd>
# </dl>
# </li>
# <li>
# <dl>
# <dt class="photo"><a class="NP=r:3,i:016_0001766721" href="/news/newsRead.nhn?type=field&amp;news_type_cd=10&amp;prsco_id=016&amp;arti_id=0001766721"><img alt="“무주택자는 치솟는 전셋값, 유주택자는 세금때문에 못살겠다”…2020 부동산에선 누구도 행복하지 않았다 [부동산360] 사진" onerror="this.src='https://ssl.pstatic.net/static.land/static/service/20191007/noimage/noimage_102.gif'" src="https://s.pstatic.net/imgnews/image/thumb100/016/2020/12/16/1766721.jpg"/></a></dt>
# <dt><a class="NP=r:3,i:016_0001766721" href="/news/newsRead.nhn?type=field&amp;news_type_cd=10&amp;prsco_id=016&amp;arti_id=0001766721">“무주택자는 치솟는 전셋값, 유주택자는 세금때문에 못살겠다”…2020 부동산에선 누구도 행복하지 않았다 [부동산360]</a></dt>
# <dd tabindex="0">
# 						[헤럴드경제=민상식 기자] 올해 부동산 시장에서는 누구도 웃지 못했다. 보유세(재산세·종부세), 양도세 등 부동산 세금이 일제히 오르면서 유주택자들은 “세금 때문에 못살겠다”는 불만이...<span class="writing">헤럴드경제</span>
# <span class="date">2020.12.16</span>
# </dd>
# </dl>
# </li>
# <li>
# <dl>
# <dt class="photo"><a class="NP=r:4,i:421_0005054101" href="/news/newsRead.nhn?type=field&amp;news_type_cd=10&amp;prsco_id=421&amp;arti_id=0005054101"><img alt="전국 주택 매매시장 소비심리, 5년7개월 만에 최고 사진" onerror="this.src='https://ssl.pstatic.net/static.land/static/service/20191007/noimage/noimage_102.gif'" src="https://s.pstatic.net/imgnews/image/thumb100/421/2020/12/16/5054101.jpg"/></a></dt>
# <dt><a class="NP=r:4,i:421_0005054101" href="/news/newsRead.nhn?type=field&amp;news_type_cd=10&amp;prsco_id=421&amp;arti_id=0005054101">전국 주택 매매시장 소비심리, 5년7개월 만에 최고</a></dt>
# <dd tabindex="0">
# 						(서울=뉴스1) 노해철 기자 = 전세 시장 불안이 매매시장으로 번지면서 지난달 전국 주택 매매시장 소비심리지수는 5년7개월 만에 최고치를 기록했다. 16일 국토연구원 부동산시장연구센터에 ...<span class="writing">뉴스1</span>
# <span class="date">2020.12.16</span>
# </dd>
# </dl>
# </li>
# <li>
# <dl>
# <dt class="photo"><a class="NP=r:5,i:417_0000632528" href="/news/newsRead.nhn?type=field&amp;news_type_cd=10&amp;prsco_id=417&amp;arti_id=0000632528"><img alt="중대형 아파트에 쏠린 '로또 청약' 열풍… 이유는? 사진" onerror="this.src='https://ssl.pstatic.net/static.land/static/service/20191007/noimage/noimage_102.gif'" src="https://s.pstatic.net/imgnews/image/thumb100/417/2020/12/16/632528.jpg"/></a></dt>
# <dt><a class="NP=r:5,i:417_0000632528" href="/news/newsRead.nhn?type=field&amp;news_type_cd=10&amp;prsco_id=417&amp;arti_id=0000632528">중대형 아파트에 쏠린 '로또 청약' 열풍… 이유는?</a></dt>
# <dd tabindex="0">
# 						이른바 '로또 분양' 기대감으로 청약 경쟁률이 무섭게 치솟은 가운데 추첨제 물량이 있는 중대형 면적에 대한 인기가 뜨겁다. 16일 부동산분석업체 부동산인포에 따르면 올해 수도권 청약 단...<span class="writing">머니S</span>
# <span class="date">2020.12.16</span>
# </dd>
# </dl>
# </li>
# <li>
# <dl>
# <dt class="photo"><a class="NP=r:6,i:003_0010245632" href="/news/newsRead.nhn?type=field&amp;news_type_cd=10&amp;prsco_id=003&amp;arti_id=0010245632"><img alt="전세난이 부른 새 아파트 인기…입주경기지수 '역대 최고' 사진" onerror="this.src='https://ssl.pstatic.net/static.land/static/service/20191007/noimage/noimage_102.gif'" src="https://s.pstatic.net/imgnews/image/thumb100/003/2020/12/16/10245632.jpg"/></a></dt>
# <dt><a class="NP=r:6,i:003_0010245632" href="/news/newsRead.nhn?type=field&amp;news_type_cd=10&amp;prsco_id=003&amp;arti_id=0010245632">전세난이 부른 새 아파트 인기…입주경기지수 '역대 최고'</a></dt>
# <dd tabindex="0">
# 						[서울=뉴시스] 박성환 기자 = 전세 수급 차질과 입주 물량 감소 등으로 아파트 입주경기실사지수(HOSI)가 조사 시작 이래 최고치를 기록했다. 전세난이 심해지면서 입주를 시작한 아파트의 ...<span class="writing">뉴시스</span>
# <span class="date">2020.12.16</span>
# </dd>
# </dl>
# </li>
# <li>
# <dl>
# <dt class="photo"><a class="NP=r:7,i:003_0010245595" href="/news/newsRead.nhn?type=field&amp;news_type_cd=10&amp;prsco_id=003&amp;arti_id=0010245595"><img alt="" onerror="this.src='https://ssl.pstatic.net/static.land/static/service/20191007/noimage/noimage_102.gif'" src="https://s.pstatic.net/imgnews/image/thumb100/003/2020/12/16/10245595.jpg" 고조="" 데"…저금리·전세난에="" 부동산="" 불안="" 비수기인="" 사진"="" 집값=""/></a></dt>
# <dt><a class="NP=r:7,i:003_0010245595" href="/news/newsRead.nhn?type=field&amp;news_type_cd=10&amp;prsco_id=003&amp;arti_id=0010245595">"부동산 비수기인 데"…저금리·전세난에 집값 불안 고조</a></dt>
# <dd tabindex="0">
# 						[서울=뉴시스] 이인준 기자 = 전국 아파트 매매시장이 저금리와 전세대란에 '불장'(상승장)으로 급격하게 전환되자, 부동산 비수기임에도 집값 상승에 대한 불안감이 고조되고 있다. 전세시...<span class="writing">뉴시스</span>
# <span class="date">2020.12.16</span>
# </dd>
# </dl>
# </li>
# <li>
# <dl>
# <dt class="photo"><a class="NP=r:8,i:277_0004811452" href="/news/newsRead.nhn?type=field&amp;news_type_cd=10&amp;prsco_id=277&amp;arti_id=0004811452"><img alt="전세 불안에 전국 아파트 입주경기실사지수 최고치 사진" onerror="this.src='https://ssl.pstatic.net/static.land/static/service/20191007/noimage/noimage_102.gif'" src="https://s.pstatic.net/imgnews/image/thumb100/277/2020/12/16/4811452.jpg"/></a></dt>
# <dt><a class="NP=r:8,i:277_0004811452" href="/news/newsRead.nhn?type=field&amp;news_type_cd=10&amp;prsco_id=277&amp;arti_id=0004811452">전세 불안에 전국 아파트 입주경기실사지수 최고치</a></dt>
# <dd tabindex="0">
# 						[아시아경제 임온유 기자] 전세 수급 차질과 입주 물량 감소로 불안 심리가 커지면서 전국 아파트 입주경기실사지수(HOSI)가 조사 시작 이래 최고치를 기록했다. 16일 주택산업연구원에 따르...<span class="writing">아시아경제</span>
# <span class="date">2020.12.16</span>
# </dd>
# </dl>
# </li>
# <li>
# <dl>
# <dt class="photo"><a class="NP=r:9,i:016_0001766653" href="/news/newsRead.nhn?type=field&amp;news_type_cd=10&amp;prsco_id=016&amp;arti_id=0001766653"><img alt="“서울 무권리금 상가 비율, 올 역대 최악 전망” 사진" onerror="this.src='https://ssl.pstatic.net/static.land/static/service/20191007/noimage/noimage_102.gif'" src="https://s.pstatic.net/imgnews/image/thumb100/016/2020/12/16/1766653.jpg"/></a></dt>
# <dt><a class="NP=r:9,i:016_0001766653" href="/news/newsRead.nhn?type=field&amp;news_type_cd=10&amp;prsco_id=016&amp;arti_id=0001766653">“서울 무권리금 상가 비율, 올 역대 최악 전망”</a></dt>
# <dd tabindex="0">
# 						‘임대료 멈춤법’이 큰 논란이 되고 있는 가운데, 2017년 이후로 서울시에서 권리금을 받는 상가의 비중은 꾸준히 감소하고 있는 것으로 나타났다. 무권리금 상가가 늘어난다는 것은 그만큼...<span class="writing">헤럴드경제</span>
# <span class="date">2020.12.16</span>
# </dd>
# </dl>
# </li>
# <li>
# <dl>
# <dt class="photo"><a class="NP=r:10,i:016_0001766652" href="/news/newsRead.nhn?type=field&amp;news_type_cd=10&amp;prsco_id=016&amp;arti_id=0001766652"><img alt="“세금은 반만, 이자유예는 금융사가 알아서…” 실속없는 세금멈춤법 사진" onerror="this.src='https://ssl.pstatic.net/static.land/static/service/20191007/noimage/noimage_102.gif'" src="https://s.pstatic.net/imgnews/image/thumb100/016/2020/12/16/1766652.jpg"/></a></dt>
# <dt><a class="NP=r:10,i:016_0001766652" href="/news/newsRead.nhn?type=field&amp;news_type_cd=10&amp;prsco_id=016&amp;arti_id=0001766652">“세금은 반만, 이자유예는 금융사가 알아서…” 실속없는 세금멈춤법</a></dt>
# <dd tabindex="0">
# 						코로나19로 타격을 입은 자영업자와 소상공인의 임대료 부담을 덜어주기 위한 움직임이 정부와 여당 중심으로 본격화하고 있다. 더불어민주당은 ‘공정 임대료’제도 공론화에 나섰고, 임대...<span class="writing">헤럴드경제</span>
# <span class="date">2020.12.16</span>
# </dd>
# </dl>
# </li>
# <li>
# <dl>
# <dt class="photo"><a class="NP=r:11,i:277_0004811429" href="/news/newsRead.nhn?type=field&amp;news_type_cd=10&amp;prsco_id=277&amp;arti_id=0004811429"><img alt="'임대료 멈춤법'에 또 갈라진 임대인-임차인…갈등만 커진다 사진" onerror="this.src='https://ssl.pstatic.net/static.land/static/service/20191007/noimage/noimage_102.gif'" src="https://s.pstatic.net/imgnews/image/thumb100/277/2020/12/16/4811429.jpg"/></a></dt>
# <dt><a class="NP=r:11,i:277_0004811429" href="/news/newsRead.nhn?type=field&amp;news_type_cd=10&amp;prsco_id=277&amp;arti_id=0004811429">'임대료 멈춤법'에 또 갈라진 임대인-임차인…갈등만 커진다</a></dt>
# <dd tabindex="0">
# 						[아시아경제 문제원 기자] 정부와 여당이 신종 코로나바이러스감염증(코로나19) 확산으로 힘들어진 임차인을 위해 상가 임대료를 강제로 인하하려는 움짐임을 보이자 시장의 혼란이 커지고 ...<span class="writing">아시아경제</span>
# <span class="date">2020.12.16</span>
# </dd>
# </dl>
# </li>
# <li>
# <dl>
# <dt class="photo"><a class="NP=r:12,i:277_0004811336" href="/news/newsRead.nhn?type=field&amp;news_type_cd=10&amp;prsco_id=277&amp;arti_id=0004811336"><img alt="서울 외곽 9억 이상 아파트 3배로 급증…" onerror="this.src='https://ssl.pstatic.net/static.land/static/service/20191007/noimage/noimage_102.gif'" src="https://s.pstatic.net/imgnews/image/thumb100/277/2020/12/16/4811336.jpg" 그림의떡"="" 내집마련,="" 사진"=""/></a></dt>
# <dt><a class="NP=r:12,i:277_0004811336" href="/news/newsRead.nhn?type=field&amp;news_type_cd=10&amp;prsco_id=277&amp;arti_id=0004811336">서울 외곽 9억 이상 아파트 3배로 급증…"내집마련, 그림의떡"</a></dt>
# <dd tabindex="0">
# 						[아시아경제 임온유 기자] 올해 서울 외곽 지역에서 고가 주택 기준인 9억원 이상 아파트 매매 거래량이 지난해보다 세 배 가까이 는 것으로 확인됐다. 특히 관악구의 경우 27배나 급증했다....<span class="writing">아시아경제</span>
# <span class="date">2020.12.16</span>
# </dd>
# </dl>
# </li>
# <li>
# <dl>
# <dt class="photo"><a class="NP=r:13,i:366_0000636336" href="/news/newsRead.nhn?type=field&amp;news_type_cd=10&amp;prsco_id=366&amp;arti_id=0000636336"><img alt="임대료 멈춤법 급물살에… 자영업자는 “서둘러달라” 건물주는 “절반 깎으면 우리도 망해” 사진" onerror="this.src='https://ssl.pstatic.net/static.land/static/service/20191007/noimage/noimage_102.gif'" src="https://s.pstatic.net/imgnews/image/thumb100/366/2020/12/16/636336.jpg"/></a></dt>
# <dt><a class="NP=r:13,i:366_0000636336" href="/news/newsRead.nhn?type=field&amp;news_type_cd=10&amp;prsco_id=366&amp;arti_id=0000636336">임대료 멈춤법 급물살에… 자영업자는 “서둘러달라” 건물주는 “절반 깎으면 우리도 망해”</a></dt>
# <dd tabindex="0">
# 						여당이 내놓은 상가건물 임대차보호법 개정안, 이른바 ‘임대료 멈춤법’에 대한 논의가 급물살을 타면서 자영업자들과 임대인의 의견이 팽팽하게 맞서고 있다. 신종 코로나바이러스 감염증(...<span class="writing">조선비즈</span>
# <span class="date">2020.12.16</span>
# </dd>
# </dl>
# </li>
# <li>
# <dl>
# <dt class="photo"><a class="NP=r:14,i:421_0005053361" href="/news/newsRead.nhn?type=field&amp;news_type_cd=10&amp;prsco_id=421&amp;arti_id=0005053361"><img alt="장애인명의로 아파트 14채 당첨된 장애인 대표, 웃돈 '4억' 챙겼다 사진" onerror="this.src='https://ssl.pstatic.net/static.land/static/service/20191007/noimage/noimage_102.gif'" src="https://s.pstatic.net/imgnews/image/thumb100/421/2020/12/16/5053361.jpg"/></a></dt>
# <dt><a class="NP=r:14,i:421_0005053361" href="/news/newsRead.nhn?type=field&amp;news_type_cd=10&amp;prsco_id=421&amp;arti_id=0005053361">장애인명의로 아파트 14채 당첨된 장애인 대표, 웃돈 '4억' 챙겼다</a></dt>
# <dd tabindex="0">
# 						(세종=뉴스1) 김희준 기자 = 국토교통부가 장애인의 명의를 빌려 아파트 특별공급에 당첨된 장애인 대표 A씨 등을 검찰에 입건했다. 고시원 위장전입을 통한 부정청약자도 적발했다. 16일 국...<span class="writing">뉴스1</span>
# <span class="date">2020.12.16</span>
# </dd>
# </dl>
# </li>
# <li>
# <dl>
# <dt class="photo"><a class="NP=r:15,i:018_0004808632" href="/news/newsRead.nhn?type=field&amp;news_type_cd=10&amp;prsco_id=018&amp;arti_id=0004808632"><img alt="이동주 " onerror="this.src='https://ssl.pstatic.net/static.land/static/service/20191007/noimage/noimage_102.gif'" src="https://s.pstatic.net/imgnews/image/thumb100/018/2020/12/16/4808632.jpg" 멈춤법,="" 사진"="" 생계형="" 이익"="" 임대료="" 임대인에도=""/></a></dt>
# <dt><a class="NP=r:15,i:018_0004808632" href="/news/newsRead.nhn?type=field&amp;news_type_cd=10&amp;prsco_id=018&amp;arti_id=0004808632">이동주 "임대료 멈춤법, 생계형 임대인에도 이익"</a></dt>
# <dd tabindex="0">
# 						[이데일리 신수정 기자]‘임대료 멈춤법’을 발의한 이동주 더불어민주당 의원이 임대료를 감면해 주는 것이 장기적으로는 생계형 임대인에게도 도움이 될 수 있다고 주장했다. 16일 이동주 ...<span class="writing">이데일리</span>
# <span class="date">2020.12.16</span>
# </dd>
# </dl>
# </li>
# <li>
# <dl>
# <dt class="photo"><a class="NP=r:16,i:018_0004808612" href="/news/newsRead.nhn?type=field&amp;news_type_cd=10&amp;prsco_id=018&amp;arti_id=0004808612"><img alt="" onerror="this.src='https://ssl.pstatic.net/static.land/static/service/20191007/noimage/noimage_102.gif'" src="https://s.pstatic.net/imgnews/image/thumb100/018/2020/12/16/4808612.jpg" 그="" 나갔네요"…‘부동산실장’="" 낚시영업="" 매물="" 방금="" 사진"="" 속출="" 앞세운=""/></a></dt>
# <dt><a class="NP=r:16,i:018_0004808612" href="/news/newsRead.nhn?type=field&amp;news_type_cd=10&amp;prsco_id=018&amp;arti_id=0004808612">"방금 그 매물 나갔네요"…‘부동산실장’ 앞세운 낚시영업 속출</a></dt>
# <dd tabindex="0">
# 						중개보조원 앞세운 허위매물 영업 더 교묘해져정부·플랫폼 강력 모니터링 촉구…“강한 처벌 필요”[이데일리 정두리 기자] “문의하신 매물은 방금 계약이 됐다고 하네요. 비슷한 조건의 더...<span class="writing">이데일리</span>
# <span class="date">2020.12.16</span>
# </dd>
# </dl>
# </li>
# <li>
# <dl>
# <dt class="photo"><a class="NP=r:17,i:009_0004717332" href="/news/newsRead.nhn?type=field&amp;news_type_cd=10&amp;prsco_id=009&amp;arti_id=0004717332"><img alt="서울 아파트값, 단독주택보다 1억 이상 비싸…역대 최대폭 차이 사진" onerror="this.src='https://ssl.pstatic.net/static.land/static/service/20191007/noimage/noimage_102.gif'" src="https://s.pstatic.net/imgnews/image/thumb100/009/2020/12/16/4717332.jpg"/></a></dt>
# <dt><a class="NP=r:17,i:009_0004717332" href="/news/newsRead.nhn?type=field&amp;news_type_cd=10&amp;prsco_id=009&amp;arti_id=0004717332">서울 아파트값, 단독주택보다 1억 이상 비싸…역대 최대폭 차이</a></dt>
# <dd tabindex="0">
# 						서울 아파트 가격 급등으로 단독·연립주택과의 가격 차이가 역대 최대 수준으로 벌어진 것으로 집계됐다. . 16일 KB국민은행 월간 주택가격동향 통계에 따르면, 지난달 기준 서울 아파트 평...<span class="writing">매일경제</span>
# <span class="date">2020.12.16</span>
# </dd>
# </dl>
# </li>
# <li>
# <dl>
# <dt class="photo"><a class="NP=r:18,i:016_0001766347" href="/news/newsRead.nhn?type=field&amp;news_type_cd=10&amp;prsco_id=016&amp;arti_id=0001766347"><img alt="문닫는 식당·카페…서울 주요상권서 나란히 쇠퇴의 길로 [부동산360] 사진" onerror="this.src='https://ssl.pstatic.net/static.land/static/service/20191007/noimage/noimage_102.gif'" src="https://s.pstatic.net/imgnews/image/thumb100/016/2020/12/16/1766347.jpg"/></a></dt>
# <dt><a class="NP=r:18,i:016_0001766347" href="/news/newsRead.nhn?type=field&amp;news_type_cd=10&amp;prsco_id=016&amp;arti_id=0001766347">문닫는 식당·카페…서울 주요상권서 나란히 쇠퇴의 길로 [부동산360]</a></dt>
# <dd tabindex="0">
# 						[헤럴드경제=김은희 기자] 신종 코로나바이러스 감염증(코로나19) 여파로 문 닫는 식당과 카페가 늘어나면서 서울 주요 상권에서 음식업이 업종 쇠퇴의 길에 접어들고 있는 것으로 확인됐다....<span class="writing">헤럴드경제</span>
# <span class="date">2020.12.16</span>
# </dd>
# </dl>
# </li>
# <li>
# <dl>
# <dt class="photo"><a class="NP=r:19,i:014_0004547936" href="/news/newsRead.nhn?type=field&amp;news_type_cd=10&amp;prsco_id=014&amp;arti_id=0004547936"><img alt="4억5000만원 쓴 문 대통령 임대주택 방문… 입주민은 " onerror="this.src='https://ssl.pstatic.net/static.land/static/service/20191007/noimage/noimage_102.gif'" src="https://s.pstatic.net/imgnews/image/thumb100/014/2020/12/16/4547936.jpg" 사진"="" 쇼룸"=""/></a></dt>
# <dt><a class="NP=r:19,i:014_0004547936" href="/news/newsRead.nhn?type=field&amp;news_type_cd=10&amp;prsco_id=014&amp;arti_id=0004547936">4억5000만원 쓴 문 대통령 임대주택 방문… 입주민은 "쇼룸"</a></dt>
# <dd tabindex="0">
# 						[파이낸셜뉴스] 문재인 대통령의 경기 화성동탄 임대주택 방문을 위해 4억5000만원이 사용된 것으로 나타났다. 하지만 정작 같은 단지의 4집 중 1집은 비어있고, 입주민들의 하자보수에 대한...<span class="writing">파이낸셜뉴스</span>
# <span class="date">2020.12.16</span>
# </dd>
# </dl>
# </li>
# <li>
# <dl>
# <dt class="photo"><a class="NP=r:20,i:029_0002643310" href="/news/newsRead.nhn?type=field&amp;news_type_cd=10&amp;prsco_id=029&amp;arti_id=0002643310"><img alt="아파트값만 왕창 띄운 문정부…연립주택 3채 구매할 돈과 맞먹어 사진" onerror="this.src='https://ssl.pstatic.net/static.land/static/service/20191007/noimage/noimage_102.gif'" src="https://s.pstatic.net/imgnews/image/thumb100/029/2020/12/16/2643310.jpg"/></a></dt>
# <dt><a class="NP=r:20,i:029_0002643310" href="/news/newsRead.nhn?type=field&amp;news_type_cd=10&amp;prsco_id=029&amp;arti_id=0002643310">아파트값만 왕창 띄운 문정부…연립주택 3채 구매할 돈과 맞먹어</a></dt>
# <dd tabindex="0">
# 						[디지털타임스 박상길 기자] 서울 아파트 가격이 급등하면서 단독·연립주택과의 가격 차가 가장 많이 벌어졌다. 서울 아파트 1채 가격이면 연립주택을 3채는 살 수 있다. 16일 KB국민은행 부...<span class="writing">디지털타임스</span>
# <span class="date">2020.12.16</span>
# </dd>
# </dl>
# </li>
# </ul>
# </div>
# <div class="paginate paginate_line NEI=a:lst.page">
# <a class="NP=r:1" href="javascript:goPage(1)" style="margin-right:0px; padding:0px 0px 0px 0px; background:#fff;"><strong>1</strong></a>
# <a class="NP=r:2" href="javascript:goPage(2)">2</a>
# <a class="NP=r:3" href="javascript:goPage(3)">3</a>
# <a class="next NP=r:2" href="javascript:goPage(2)">다음페이지 </a>
# </div>
# <div class="paginate_day NEI=a:lst.date">
# <span class="viewday" tabindex="0">12월16일(수)</span>
# <span class="devidebar">·</span>
# <a class="NP=r:2,i=20201215" href="?bss_ymd=20201215&amp;news_type_cd=10">12월15일(화)</a>
# <span class="devidebar">·</span>
# <a class="NP=r:3,i=20201214" href="?bss_ymd=20201214&amp;news_type_cd=10">12월14일(월)</a>
# <span class="devidebar">·</span>
# <a class="NP=r:4,i=20201211" href="?bss_ymd=20201211&amp;news_type_cd=10">12월11일(금)</a>
# <span class="devidebar">·</span>
# <a class="NP=r:5,i=20201210" href="?bss_ymd=20201210&amp;news_type_cd=10">12월10일(목)</a>
# </div>
# </div>
# <hr/>
# <div class="aside">
# <!-- DA BANNER -->
# <div id="da_280240" name="da_280240">
# <iframe align="middle" data-veta-preview="land_new" frameborder="0" height="240" id="f280240" marginheight="0" marginwidth="0" name="f280240" scrolling="no" src="https://veta.naver.com/fxshow?su=SU10354&amp;rui=20201217092011433" title="광고" width="280"></iframe>
# </div>
# <!-- //og:tag --><div class="section_aside line NE=a:rhi">
# <h3 class="tit_h3 h_issue">
# <span>이슈</span>
# <strong tabindex="0">11.19 전세대책</strong>
# </h3>
# <ul class="issue_list NI=a:list">
# <li><a class="NP=r:1,i:011_0003841163" href="/news/newsRead.nhn?source=aside&amp;type=issueView&amp;isu_no=102132&amp;prsco_id=011&amp;arti_id=0003841163">원룸 곳곳 넘쳐나는데···정부 전세대책...</a></li>
# <li><a class="NP=r:2,i:009_0004714641" href="/news/newsRead.nhn?source=aside&amp;type=issueView&amp;isu_no=102132&amp;prsco_id=009&amp;arti_id=0004714641">11·19 대책 후 경기 김포·부산 해운대 ...</a></li>
# <li><a class="NP=r:3,i:015_0004464612" href="/news/newsRead.nhn?source=aside&amp;type=issueView&amp;isu_no=102132&amp;prsco_id=015&amp;arti_id=0004464612">11·19대책 후폭풍…김포 거래량 '반토막...</a></li>
# <li><a class="NP=r:4,i:016_0001761685" href="/news/newsRead.nhn?source=aside&amp;type=issueView&amp;isu_no=102132&amp;prsco_id=016&amp;arti_id=0001761685">전세대책, 불안감만 더 키웠나…서울 아...</a></li>
# <li><a class="NP=r:5,i:119_0002449045" href="/news/newsRead.nhn?source=aside&amp;type=issueView&amp;isu_no=102132&amp;prsco_id=119&amp;arti_id=0002449045">정부 실책 전세대란에 ‘부동산 예산’ ...</a></li>
# </ul>
# <a class="btn_more NPI=a:more" href="/news/issueView.nhn?isu_no=102132">더보기</a>
# </div>
# <div class="section_aside line NE=a:rln" id="region_news_control">
# <h3 class="tit_h3 h_area"><span tabindex="0">우리동네뉴스</span></h3>
# <p class="category area1" id="region_select_area">
# <a class="total NPI=a:all" href="#" onclick="setAreaByAside('total');return false;" rcode="total"><strong>종합</strong></a>
# <span class="area1">
# <span class="bar">|</span>
# <a class="NPI=a:region,i:1100000000" href="#" onclick="setAreaByAside('1100000000');return false;" rcode="1100000000">서울</a>
# <span class="bar">|</span>
# <a class="NPI=a:region,i:4100000000" href="#" onclick="setAreaByAside('4100000000');return false;" rcode="4100000000">경기</a>
# <span class="bar">|</span>
# <a class="NPI=a:region,i:2800000000" href="#" onclick="setAreaByAside('2800000000');return false;" rcode="2800000000">인천</a>
# <span class="bar">|</span>
# <a class="NPI=a:region,i:2600000000" href="#" onclick="setAreaByAside('2600000000');return false;" rcode="2600000000">부산</a>
# </span>
# <span class="area2">
# <span class="bar">|</span>
# <a class="NPI=a:region,i:3000000000" href="#" onclick="setAreaByAside('3000000000');return false;" rcode="3000000000">대전</a>
# <span class="bar">|</span>
# <a class="NPI=a:region,i:2700000000" href="#" onclick="setAreaByAside('2700000000');return false;" rcode="2700000000">대구</a>
# <span class="bar">|</span>
# <a class="NPI=a:region,i:3100000000" href="#" onclick="setAreaByAside('3100000000');return false;" rcode="3100000000">울산</a>
# <span class="bar">|</span>
# <a class="NPI=a:region,i:3600000000" href="#" onclick="setAreaByAside('3600000000');return false;" rcode="3600000000">세종</a>
# </span>
# <span class="area3">
# <span class="bar">|</span>
# <a class="NPI=a:region,i:2900000000" href="#" onclick="setAreaByAside('2900000000');return false;" rcode="2900000000">광주</a>
# <span class="bar">|</span>
# <a class="NPI=a:region,i:4200000000" href="#" onclick="setAreaByAside('4200000000');return false;" rcode="4200000000">강원</a>
# <span class="bar">|</span>
# <a class="NPI=a:region,i:4300000000" href="#" onclick="setAreaByAside('4300000000');return false;" rcode="4300000000">충북</a>
# <span class="bar">|</span>
# <a class="NPI=a:region,i:4400000000" href="#" onclick="setAreaByAside('4400000000');return false;" rcode="4400000000">충남</a>
# </span>
# <span class="area4">
# <span class="bar">|</span>
# <a class="NPI=a:region,i:4700000000" href="#" onclick="setAreaByAside('4700000000');return false;" rcode="4700000000">경북</a>
# <span class="bar">|</span>
# <a class="NPI=a:region,i:4800000000" href="#" onclick="setAreaByAside('4800000000');return false;" rcode="4800000000">경남</a>
# <span class="bar">|</span>
# <a class="NPI=a:region,i:4500000000" href="#" onclick="setAreaByAside('4500000000');return false;" rcode="4500000000">전북</a>
# <span class="bar">|</span>
# <a class="NPI=a:region,i:4600000000" href="#" onclick="setAreaByAside('4600000000');return false;" rcode="4600000000">전남</a>
# </span>
# <span class="area5">
# <span class="bar">|</span>
# <a class="NPI=a:region,i:5000000000" href="#" onclick="setAreaByAside('5000000000');return false;" rcode="5000000000">제주</a>
# <span class="btn_area">
# <a class="btn prev NPI=a:prev" href="#" onclick="moveAreaSelect(-1);return false;"><span>이전</span></a>
# <a class="btn next NPI=a:next" href="#" onclick="moveAreaSelect(1);return false;"><span>다음</span></a>
# </span>
# </span></p>
# <div class="area_on NI=a:list" id="total_news">
# <ul class="category_list">
# <li>
# <a class="area NP=r:1,i:421_0005053345" href="region.nhn?city_no=1100000000&amp;dvsn_no=1156000000">[영등포구]</a>
# <a class="NP=r:1,i:421_0005053345" href="/news/newsRead.nhn?source=aside&amp;type=region&amp;city_no=1100000000&amp;dvsn_no=1156000000&amp;prsco_id=421&amp;arti_id=0005053345">
# 						서울 영등포구 '쪽방촌 정...</a>
# </li>
# <li>
# <a class="area NP=r:2,i:417_0000632315" href="region.nhn?city_no=1100000000&amp;dvsn_no=1130500000">[강북구]</a>
# <a class="NP=r:2,i:417_0000632315" href="/news/newsRead.nhn?source=aside&amp;type=region&amp;city_no=1100000000&amp;dvsn_no=1130500000&amp;prsco_id=417&amp;arti_id=0000632315">
# 						서울 최고도지역 우이동 55...</a>
# </li>
# <li>
# <a class="area NP=r:3,i:001_0012083601" href="region.nhn?city_no=3000000000&amp;dvsn_no=3017000000">[서구]</a>
# <a class="NP=r:3,i:001_0012083601" href="/news/newsRead.nhn?source=aside&amp;type=region&amp;city_no=3000000000&amp;dvsn_no=3017000000&amp;prsco_id=001&amp;arti_id=0012083601">
# 						대전시 2023년까지 5만6천...</a>
# </li>
# <li>
# <a class="area NP=r:4,i:018_0004808524" href="region.nhn?city_no=1100000000&amp;dvsn_no=1159000000">[동작구]</a>
# <a class="NP=r:4,i:018_0004808524" href="/news/newsRead.nhn?source=aside&amp;type=region&amp;city_no=1100000000&amp;dvsn_no=1159000000&amp;prsco_id=018&amp;arti_id=0004808524">
# 						동작구 본동종합사회복지관...</a>
# </li>
# <li>
# <a class="area NP=r:5,i:421_0005051466" href="region.nhn?city_no=4300000000&amp;dvsn_no=4313000000">[충주시]</a>
# <a class="NP=r:5,i:421_0005051466" href="/news/newsRead.nhn?source=aside&amp;type=region&amp;city_no=4300000000&amp;dvsn_no=4313000000&amp;prsco_id=421&amp;arti_id=0005051466">
# 						국토부, 수소충전 복합기지...</a>
# </li>
# <li>
# <a class="area NP=r:6,i:277_0004810510" href="region.nhn?city_no=1100000000&amp;dvsn_no=1171000000">[송파구]</a>
# <a class="NP=r:6,i:277_0004810510" href="/news/newsRead.nhn?source=aside&amp;type=region&amp;city_no=1100000000&amp;dvsn_no=1171000000&amp;prsco_id=277&amp;arti_id=0004810510">
# 						서울시, 문정역 인근에 '역...</a>
# </li>
# <li>
# <a class="area NP=r:7,i:001_0012075348" href="region.nhn?city_no=4500000000&amp;dvsn_no=4575000000">[임실군]</a>
# <a class="NP=r:7,i:001_0012075348" href="/news/newsRead.nhn?source=aside&amp;type=region&amp;city_no=4500000000&amp;dvsn_no=4575000000&amp;prsco_id=001&amp;arti_id=0012075348">
# 						"좋은 일에 부동산 쓰라"…...</a>
# </li>
# <li>
# <a class="area NP=r:8,i:018_0004805411" href="region.nhn?city_no=1100000000&amp;dvsn_no=1174000000">[강동구]</a>
# <a class="NP=r:8,i:018_0004805411" href="/news/newsRead.nhn?source=aside&amp;type=region&amp;city_no=1100000000&amp;dvsn_no=1174000000&amp;prsco_id=018&amp;arti_id=0004805411">
# 						[동네방네]강동구, 골목길 ...</a>
# </li>
# <li>
# <a class="area NP=r:9,i:003_0010236514" href="region.nhn?city_no=2600000000&amp;dvsn_no=2635000000">[해운대구]</a>
# <a class="NP=r:9,i:003_0010236514" href="/news/newsRead.nhn?source=aside&amp;type=region&amp;city_no=2600000000&amp;dvsn_no=2635000000&amp;prsco_id=003&amp;arti_id=0010236514">
# 						부산시 ‘센텀2지구 도시첨...</a>
# </li>
# <li>
# <a class="area NP=r:10,i:001_0012071273" href="region.nhn?city_no=4800000000&amp;dvsn_no=4812100000">[창원시]</a>
# <a class="NP=r:10,i:001_0012071273" href="/news/newsRead.nhn?source=aside&amp;type=region&amp;city_no=4800000000&amp;dvsn_no=4812100000&amp;prsco_id=001&amp;arti_id=0012071273">
# 						"집 걱정 없이 일하세요"…...</a>
# </li>
# </ul>
# </div>
# <div class="area_off NI=a:list" id="area_news">
# <ul class="category_list" id="region_news_area">
# <script defer="defer" id="region_news_template" type="text/template">
# 				{for idx:news in newsList}
# 					{if idx < 10 }
# 					<li>
# 						<a href="region.nhn?city_no={=current}&dvsn_no={=news.cortar1_no}" class="area NP=r:{=idx+1},i={=news.prsco_id}_{=news.arti_id}">[{js splitRegionName(=news.dvsn_nm,0)}]</a>
# 						<a href="/news/newsRead.nhn?source=aside&type=region&city_no={=current}&dvsn_no={=news.cortar1_no}&prsco_id={=news.prsco_id}&arti_id={=news.arti_id}" class="NP=r:{=idx+1},i={=news.prsco_id}_{=news.arti_id}">{js cutStringByPixel(=news.ttl,160,'...')}</a>
# 					</li>
# 					{/if}
# 				{/for}
# 			</script>
# </ul>
# </div>
# <a class="btn_more NPI=a:more" href="#" onclick="goRegionNews();return false">더보기</a>
# </div>
# </div>
# </div><!-- footer -->
# <script language="javascript" src="https://ssl.pstatic.net/static/common/js/cs_ops_webncc.js" type="text/javascript"></script>
# <div id="footer">
# <div class="footwrap NE=a:fot">
# <fieldset>
# <legend class="blind">검색</legend>
# <div class="sta_search_box NE=a:lsc">
# <input accesskey="s" class="sta_search_text" id="queryInputFooter" onfocus="searchInputBoxFocus(this);" onkeyup="serviceInternalSearchEnterCheck(event,1);" query="" searchareaclicked="false" searchtype="Promotion" title="검색" type="text" value=""/>
# <a class="btn_search NPI=a:search" href="#" onclick="serviceInternalSearchFooter();return false;">검색</a>
# <a class="btn_search2 NPI=a:nx" href="#" onclick="serviceInternalTotalSearchFooter();return false;" title="새창 열림">통합검색</a>
# </div>
# </fieldset>
# <ul class="NE=a:fot">
# <li class="first"><a class="NPI=a:service" href="http://www.naver.com/policy/service.html">이용약관</a></li>
# <li><a href="/index/declaredArticlePolicy.nhn">매물신고운영</a></li>
# <li><a class="NPI=a:privacy" href="http://www.naver.com/rules/privacy.html" target="_blank" title="새창 열림"><strong>개인정보처리방침 </strong></a></li>
# <li><a class="NPI=a:help" href="#" onclick="OPS.viewOPS('ops', {url : 'https://help.naver.com/support/alias/land/landmain.naver'}); return false;" title="새창 열림">부동산 고객센터</a></li>
# </ul>
# <p class="info" tabindex="0">네이버부동산에서 제공하는 부동산 정보는 각 콘텐츠 제공업체로부터 받는 정보로 참고용입니다.<br/>
#                                          정보의 정확성이나 신뢰성을 보증하지 않으며, 서비스 이용의 결과에 대해서 어떠한 법적인 책임을 지지 않습니다. 게시된 정보는 무단으로 배포할 수 없습니다.</p>
# <address>
# <a class="logo N=a:fot.nbpcorp" href="http://www.navercorp.com/ko/index.nhn" target="_blank"><span class="blind">NAVER</span></a>
# <em>Copyright ⓒ</em> <a href="http://www.navercorp.com/ko/index.nhn" target="_blank">NAVER Corp.</a> <span>All Rights Reserved.</span>
# </address>
# </div>
# </div>
# <!-- //footer --></div>
# </body>
# <script src="https://ssl.pstatic.net/static.land/static/service/js/202011051426/min/news/news.jindo.js" type="text/javascript"></script><script src="https://ssl.pstatic.net/static.land/static/service/js/202011051426/min/news/news.util.js" type="text/javascript"></script><script src="https://ssl.pstatic.net/static.land/static/service/js/202011051426/min/news/news.js" type="text/javascript"></script><script type="text/javascript">
# var oDatePickerdate1,
# oDatePickerdate2;
#
# //뉴스홈 우측하단 rolling 부분
# if(typeof(rolling) == "function"){
# 	rolling();
# }
#
# //이벤트 Listener 함수 호출
# nclk_do();
#
#
#
# // 전문가칼럼 등록기간
# if ($('writer_sel') != null){
# 	var writerSel = new ISelectBox($("writer_sel"),{ width : "172", height : false, bUseDefaultOption : false });
# 	dateShow_date1();dateShow_date2();
# }
#
# // 실시간 속보 뉴스 검색
# if ($('searchForm') != null){
# 	var sdate1 = $("date1");
# 	var sdate2 = $("date2");
# }
#
# if ($('issue_sel') != null){
# 	new ISelectBox($('issue_sel'),{ width : "229", height : false, bUseDefaultOption : false });
# }
# </script>
# </html><!DOCTYPE HTML PUBLIC "-//W3C//DTD HTML 4.01 Transitional//EN" "http://www.w3.org/TR/html4/loose.dtd">
#
# <html lang="ko">
# <head>
# <meta content="text/html; charset=utf-8" http-equiv="Content-Type"/>
# <meta contents="always" name="referrer">
# <meta content="IE=Edge" http-equiv="X-UA-Compatible"/>
# <title>
# 뉴스 : 네이버 부동산</title>
# <script type="text/javascript">
# document.domain = "naver.com";
#
# var ccsrv="cc.naver.com";
# var g_query = "";
# var nclk_evt = 3;
# </script>
# <link href="https://ssl.pstatic.net/static.land/static/service/css/202011051426/min/news/news.css" rel="stylesheet" type="text/css"/><script type="text/javascript">	document.domain = 'naver.com';</script>
# <script src="https://ssl.pstatic.net/static.land/static/service/js/202011051426/search/flashObject.js" type="text/javascript"></script><script type="text/javascript">
# 	nsc = "land.news_cn";
# 	document.title="분야별뉴스, 뉴스 : 내집마련의 시작, 네이버 부동산";
# </script><style type="text/css">
# .wordwrap
# {
#      word-wrap:break-word;
#      word-break:break-all;
#      -moz-binding: url('/css/wordwrap.xml#wordwrap');
#      overflow: hidden;
# }
# </style>
# <meta content="네이버부동산 " property="me2:post_tag"/>
# <meta content="네이버부동산" property="me2:category1"/>
# <meta content="" property="me2:category2"/>
# <!DOCTYPE HTML PUBLIC "-//W3C//DTD HTML 4.01 Transitional//EN" "http://www.w3.org/TR/html4/loose.dtd">
#
# <!-- og:tag -->
# <link href="http://land.naver.com" rel="canonical"/>
# <meta content="land" property="og:site_name"/>
# <meta content="네이버 부동산" property="og:title"/>
# <meta content="article" property="og:type"/>
# <meta content="네이버 부동산 분야별 뉴스" property="og:description"/>
# <meta content="네이버 부동산 분야별 뉴스" name="description"/>
# <meta content="https://landthumb-phinf.pstatic.net/20201030_229/land_naver_1604037626049TB83t_PNG/%B3%D7%C0%CC%B9%F6_%BA%CE%B5%BF%BB%EA.png" property="og:image">
# <meta content="네이버 부동산" property="og:article:author"/>
# <meta content="https://land.naver.com/news/field.nhn?page=2" property="og:url"/>
# <meta content="http://land.naver.com/" property="og:article:author:url"/>
# <!-- //og:tag -->
# <script type="text/javascript">
# 	photoDomain = "https://landthumb-phinf.pstatic.net";
#
# 	serviceImageUrl = "https://ssl.pstatic.net/static.land/static/service/20191007";
#
# 	today = "20201217";
#
#
# 	function getDefaultImage(width) {
# 		var dfltImgUrl = "";
#
# 		if(width >= 120){
# 			if(width > 206){
# 				dfltImgUrl = serviceImageUrl +"/noimage/noimage_232.gif";
# 			}else if(width > 196){
# 				dfltImgUrl = serviceImageUrl +"/noimage/noimage_206.gif";
# 			}else if(width > 120 ){
# 				dfltImgUrl = serviceImageUrl +"/noimage/noimage_196.gif";
# 			}else{
# 				dfltImgUrl = serviceImageUrl +"/noimage/noimage_120.gif";
# 			}
# 		}else{
# 			if(width > 102){
# 				dfltImgUrl = serviceImageUrl +"/noimage/noimage_120.gif";
# 			}else if(width > 83){
# 				dfltImgUrl = serviceImageUrl +"/noimage/noimage_102.gif";
# 			}else if(width > 63 ){
# 				dfltImgUrl = serviceImageUrl +"/noimage/noimage_083.gif";
# 			}else{
# 				dfltImgUrl = serviceImageUrl +"/noimage/noimage_063.gif";
# 			}
# 		}
# 		return dfltImgUrl;
# 	}
#
# 	function getPhotoInfraImg(photo, type, width) {
# 		if(photo == null || photo == "") {
# 			return getDefaultImage(width);
# 		} else {
# 			if(type == null || type == "" || typeof type == "undefined") {
# 				return photoDomain + "/" + photo;
# 			} else {
# 				return photoDomain + "/" + photo + "?type=" + type;
# 			}
# 		}
# 	}
#
# 	function errorImg(el , dWidth) {
#
# 		var width = dWidth || Number(el.getAttribute("width"));
# 		if(el.src.indexOf("noimage") > -1){
# 			return;
# 		}
# 		el.src = getDefaultImage(width);
# 	}
#
# 	function generatePhotoInfraImgTag(hashAttr, type) {
#
# 		var isEmpty = function (value) {
# 			if (!value || value == null || value == "" || typeof value == "undefined") {
# 				return true;
# 			}
# 			return false;
# 		};
#
# 		var tagAttrs = "";
# 		var attachAttr = function(value, key) {
# 			tagAttrs += " " + key + "=\"" + value + "\"";
# 		};
#
# 		var dfltImgUrl = getDefaultImage(hashAttr.$("width"));
#
# 		if (isEmpty(hashAttr.$("src"))) {
# 			hashAttr.add("src", dfltImgUrl);
# 		} else {
# 			hashAttr.add("src", photoDomain + hashAttr.$("src"));
#
# 			if (!isEmpty(type)) {
# 				hashAttr.add("src", hashAttr.$("src") + "?type=" + type);
# 			}
# 		}
#
# 		hashAttr.forEach(attachAttr);
#
# 		return "<img " + tagAttrs + " onerror=\"errorImg(this)\">";
# 	}
# </script></meta></meta></head>
# <body class="" onload="">
# <div id="wrap">
# <div id="u_skip">
# <a href="#lnb" onclick="document.getElementById('lnb').tabIndex = -1;document.getElementById('lnb').focus();return false;"><span>메인 메뉴로 바로가기</span></a>
# <a href="#container" onclick="document.getElementById('container').tabIndex = -1;document.getElementById('container').focus();return false;"><span>하위 메뉴로 바로가기</span></a>
# <a href="#content" onclick="document.getElementById('content').tabIndex = -1;document.getElementById('content').focus();return false;"><span>본문으로 바로가기</span></a>
# </div>
# <div id="pvframe" style="display:none;"></div>
# <!-- header -->
# <script src="https://ssl.pstatic.net/static.land/static/service/js/202011051426/lib/lcslog.js" type="text/javascript"></script><script src="https://wcs.naver.net/wcslog.js" type="text/javascript"></script>
# <script type="text/javascript">
# 	lcs_do();
#
# 	if(!wcs_add) var wcs_add = {};
# 	wcs_add["wa"] = "60717a12f2b3c8";
# 	if(typeof wcs_do !== 'undefined') wcs_do();
# </script>
# <div class="header_one" id="header">
# <div class="gnb_wrap">
# <div class="inner_wrap">
# <div class="item_area NE=a:STA">
# <h1 class="logo_area">
# <a class="logo_naver NPI=a:naverlogo" href="http://www.naver.com/"><i class="icon">NAVER</i></a>
# <a class="logo_land NPI=a:land" href="http://land.naver.com/"><i class="icon">부동산</i></a>
# </h1>
# <div class="inner_gnb_search">
# <h2 class="blind">검색영역</h2>
# <fieldset>
# <legend>검색</legend>
# <!-- [D] 입력위해 focus 가지면 sta_text_ovr 추가 -->
# <input name="where" type="hidden" value="nexearch">
# <input name="sm" type="hidden" value="top_hty">
# <input name="fbm" type="hidden" value="1"/>
# <input id="serviceInternalSearchQuery" name="query" type="hidden" value=""/>
# <input id="internalSearchURL" name="internalSearchURL" type="hidden" value="https://land.naver.com"/>
# <input accesskey="s" class="search_input sta_search_text" id="queryInputHeader" onfocus="searchInputBoxFocus(this);" onkeyup="serviceInternalSearchEnterCheck(event,0);" query="" searchareaclicked="false" searchtype="Promotion" title="검색" type="text" value=""/>
# <a class="search_button type_inside NPI=a:search" href="#" onclick="serviceInternalSearch();return false;"><i class="icon">검색</i></a>
# <a class="search_button type_integration NPI=a:nx" href="#" onclick="serviceInternalTotalSearch();return false;" title="새창 열림"><i class="icon">통합검색</i></a>
# </input></input></fieldset>
# </div>
# </div>
# <div class="gnb_area">
# <div id="gnb">
# <script charset="utf-8" src="https://ssl.pstatic.net/static.gn/templates/gnb_utf8.nhn?20201217" type="text/javascript"></script>
# </div>
# </div>
# </div>
# </div>
# <div class="nav_wrap" id="lnb">
# <h2 class="blind">메인메뉴</h2>
# <div class="inner_wrap">
# <!-- [D] 활성화 클래스 on -->
# <ul class="nav_list NE=a:LNB">
# <li class="menu main_home">
# <a class="NPI=a:home" href="/">부동산홈</a>
# </li>
# <li class="menu main_article_beta">
# <a class="NPI=a:article_beta" href="https://new.land.naver.com/complexes">매물베타</a>
# </li>
# <li class="menu main_isale">
# <a class="NPI=a:sale" href="https://isale.land.naver.com/iSale/Map/">분양</a>
# </li>
# <li class="menu main_news on">
# <a class="NPI=a:news" href="/news/">뉴스</a>
# </li>
# <li class="menu main_community">
# <a class="NPI=a:community" href="/community/">커뮤니티</a>
# </li>
# <li class="menu main_auction">
# <a class="NPI=a:auction" href="/auction/">경매</a>
# </li>
# <li class="menu main_mypage">
# <a class="NPI=a:mypage" href="https://new.land.naver.com/interests">MY페이지</a>
# </li>
# <!--[if lte IE 9]>
# 						<li id="_ieVerCheck" class="hidden ie9"></li>
# 					<![endif]-->
# </ul>
# <div class="button_area NE=a:LNB">
# <a class="type_admin NPI=a:landad" href="http://landad.naver.com/" target="_blank">부동산관리센터</a>
# </div>
# </div>
# </div>
# <div class="sub_nav_wrap">
# <h2 class="blind">서브메뉴</h2>
# <div class="inner_wrap">
# <!-- [D] 활성화 클래스 on -->
# <ul class="sub_nav_list NE=a:LNB">
# <li class="menu news_headline"><a class="on" href="/news/headline.nhn">주요뉴스</a></li>
# <li class="menu news_region"><a class="on" href="/news/region.nhn">우리동네뉴스</a></li>
# <li class="menu news_issue"><a class="on" href="/news/hotIssue.nhn">핫이슈</a></li>
# <li class="menu news_field on"><a class="on" href="/news/field.nhn">분야별뉴스</a></li>
# <li class="menu news_breaking"><a class="on" href="/news/breaking.nhn">실시간속보</a></li>
# <li class="menu news_expert"><a class="on" href="/news/expertColumn.nhn">부동산칼럼</a></li>
# <li class="menu news_magazine"><a class="on" href="/news/magazine.nhn">매거진</a></li>
# <li class="menu news_trend"><a class="on" href="/news/trendReport.nhn">동향보고서</a></li>
# </ul>
# </div>
# </div>
# </div>
# <!-- //header --><!--하위 컨텐츠 및 Aside Component 영역 List Container -->
# <div id="container">
# <div id="content">
# <h2 class="h_news field" tabindex="0"><span>분야별 뉴스</span></h2>
# <div class="section_field NEI=a:cat.title">
# <a class="NP=r:1,i:10" href="#"><strong>시장동향</strong></a>
# <span class="bar">|</span>
# <a class="NP=r:2,i:20" href="?news_type_cd=20">정책/제도</a>
# <span class="bar">|</span>
# <a class="NP=r:3,i:30" href="?news_type_cd=30">개발정보</a>
# <span class="bar">|</span>
# ...
# <li class="menu news_issue"><a class="on" href="/news/hotIssue.nhn">핫이슈</a></li>
# <li class="menu news_field on"><a class="on" href="/news/field.nhn">분야별뉴스</a></li>
# <li class="menu news_breaking"><a class="on" href="/news/breaking.nhn">실시간속보</a></li>
# <li class="menu news_expert"><a class="on" href="/news/expertColumn.nhn">부동산칼럼</a></li>
# <li class="menu news_magazine"><a class="on" href="/news/magazine.nhn">매거진</a></li>
# <li class="menu news_trend"><a class="on" href="/news/trendReport.nhn">동향보고서</a></li>
# </ul>
# </div>
# </div>
# </div>
# <!-- //header --><!--하위 컨텐츠 및 Aside Component 영역 List Container -->
# <div id="container">
# <div id="content">
# <h2 class="h_news field" tabindex="0"><span>분야별 뉴스</span></h2>
# <div class="section_field NEI=a:cat.title">
# <a class="NP=r:1,i:10" href="#"><strong>시장동향</strong></a>
# <span class="bar">|</span>
# <a class="NP=r:2,i:20" href="?news_type_cd=20">정책/제도</a>
# <span class="bar">|</span>
# <a class="NP=r:3,i:30" href="?news_type_cd=30">개발정보</a>
# <span class="bar">|</span>
# <a class="NP=r:4,i:40" href="?news_type_cd=40">분양</a>
# <span class="bar">|</span>
# <a class="NP=r:5,i:50" href="?news_type_cd=50">업계동향</a>
# <span class="bar">|</span>
# <a class="NP=r:6,i:60" href="?news_type_cd=60">부동산금융</a>
# <span class="bar">|</span>
# <a class="NP=r:7,i:70" href="?news_type_cd=70">경매/공매</a>
# <span class="bar">|</span>
# <a class="NP=r:8,i:80" href="?news_type_cd=80">기타</a>
# </div>
# <div class="section_headline">
# <ul class="headline_list NEI=a:lst.title">
# <li>
# <dl>
# <dt class="photo"><a class="NP=r:1,i:023_0003583577" href="/news/newsRead.nhn?type=field&amp;news_type_cd=10&amp;prsco_id=023&amp;arti_id=0003583577"><img alt="‘수도권 마지막 비규제’ 파주, 집값 상승률 1위 사진" onerror="this.src='https://ssl.pstatic.net/static.land/static/service/20191007/noimage/noimage_102.gif'" src="https://s.pstatic.net/imgnews/image/thumb100/023/2020/12/16/3583577.jpg"/></a></dt>
# <dt><a class="NP=r:1,i:023_0003583577" href="/news/newsRead.nhn?type=field&amp;news_type_cd=10&amp;prsco_id=023&amp;arti_id=0003583577">‘수도권 마지막 비규제’ 파주, 집값 상승률 1위</a></dt>
# <dd tabindex="0">
# 						김포 규제에 풍선 효과… 두더지잡기식 대책 후유증 심각 부동산 시장에 대한 정부의 ‘두더지 잡기’식 뒷북 처방이 이어지는 가운데 서울 등 수도권을 넘어 지방 대도시까지 집값 상승세가...<span class="writing">조선일보</span>
# <span class="date">2020.12.16</span>
# </dd>
# </dl>
# </li>
# <li>
# <dl>
# <dt><a class="NP=r:2,i:022_0003533514" href="/news/newsRead.nhn?type=field&amp;news_type_cd=10&amp;prsco_id=022&amp;arti_id=0003533514">내년부터 건설사가 입주 전 전용부분 하자조치 의무화</a></dt>
# <dd tabindex="0">
# 						내년부터 아파트 입주 예정자가 사전방문 때 발견한 전용 부분의 하자는 건설사가 입주일 전까지 보수공사 등의 조치를 해줘야 한다.     정부는 15일 오전 국무회의를 열어 이 같은 내용이 ...<span class="writing">세계일보</span>
# <span class="date">2020.12.16</span>
# </dd>
# </dl>
# </li>
# <li>
# <dl>
# <dt><a class="NP=r:3,i:087_0000824732" href="/news/newsRead.nhn?type=field&amp;news_type_cd=10&amp;prsco_id=087&amp;arti_id=0000824732">아파트 분양사업실적 사상 최고</a></dt>
# <dd tabindex="0">
# 						HSSI 실적치 전월 比 25p 상승 예상분양률 73.8% 역대 최고 강원지역 아파트 분양사업실적이 사상 최고치를 기록하며 침체됐던 분양경기가 되살아나고 있다. 15일 주택산업연구원에 따르면 ...<span class="writing">강원일보</span>
# <span class="date">2020.12.16</span>
# </dd>
# </dl>
# </li>
# </ul>
# </div>
# <div class="paginate paginate_line NEI=a:lst.page">
# <a class="pre NP=r:2" href="javascript:goPage(2)">이전페이지</a>
# <a class="NP=r:1" href="javascript:goPage(1)">1</a>
# <a class="NP=r:2" href="javascript:goPage(2)">2</a>
# <a class="NP=r:3" href="javascript:goPage(3)" style="margin-right:0px; padding:0px 0px 0px 0px; background:#fff;"><strong>3</strong></a>
# </div>
# <div class="paginate_day NEI=a:lst.date">
# <span class="viewday" tabindex="0">12월16일(수)</span>
# <span class="devidebar">·</span>
# <a class="NP=r:2,i=20201215" href="?bss_ymd=20201215&amp;news_type_cd=10">12월15일(화)</a>
# <span class="devidebar">·</span>
# <a class="NP=r:3,i=20201214" href="?bss_ymd=20201214&amp;news_type_cd=10">12월14일(월)</a>
# <span class="devidebar">·</span>
# <a class="NP=r:4,i=20201211" href="?bss_ymd=20201211&amp;news_type_cd=10">12월11일(금)</a>
# <span class="devidebar">·</span>
# <a class="NP=r:5,i=20201210" href="?bss_ymd=20201210&amp;news_type_cd=10">12월10일(목)</a>
# </div>
# </div>
# <hr/>
# <div class="aside">
# <!-- DA BANNER -->
# <div id="da_280240" name="da_280240">
# <iframe align="middle" data-veta-preview="land_new" frameborder="0" height="240" id="f280240" marginheight="0" marginwidth="0" name="f280240" scrolling="no" src="https://veta.naver.com/fxshow?su=SU10354&amp;rui=20201217092011615" title="광고" width="280"></iframe>
# </div>
# <!-- //og:tag --><div class="section_aside line NE=a:rhi">
# <h3 class="tit_h3 h_issue">
# <span>이슈</span>
# <strong tabindex="0">11.19 전세대책</strong>
# </h3>
# <ul class="issue_list NI=a:list">
# <li><a class="NP=r:1,i:011_0003841163" href="/news/newsRead.nhn?source=aside&amp;type=issueView&amp;isu_no=102132&amp;prsco_id=011&amp;arti_id=0003841163">원룸 곳곳 넘쳐나는데···정부 전세대책...</a></li>
# <li><a class="NP=r:2,i:009_0004714641" href="/news/newsRead.nhn?source=aside&amp;type=issueView&amp;isu_no=102132&amp;prsco_id=009&amp;arti_id=0004714641">11·19 대책 후 경기 김포·부산 해운대 ...</a></li>
# <li><a class="NP=r:3,i:015_0004464612" href="/news/newsRead.nhn?source=aside&amp;type=issueView&amp;isu_no=102132&amp;prsco_id=015&amp;arti_id=0004464612">11·19대책 후폭풍…김포 거래량 '반토막...</a></li>
# <li><a class="NP=r:4,i:016_0001761685" href="/news/newsRead.nhn?source=aside&amp;type=issueView&amp;isu_no=102132&amp;prsco_id=016&amp;arti_id=0001761685">전세대책, 불안감만 더 키웠나…서울 아...</a></li>
# <li><a class="NP=r:5,i:119_0002449045" href="/news/newsRead.nhn?source=aside&amp;type=issueView&amp;isu_no=102132&amp;prsco_id=119&amp;arti_id=0002449045">정부 실책 전세대란에 ‘부동산 예산’ ...</a></li>
# </ul>
# <a class="btn_more NPI=a:more" href="/news/issueView.nhn?isu_no=102132">더보기</a>
# </div>
# <div class="section_aside line NE=a:rln" id="region_news_control">
# <h3 class="tit_h3 h_area"><span tabindex="0">우리동네뉴스</span></h3>
# <p class="category area1" id="region_select_area">
# <a class="total NPI=a:all" href="#" onclick="setAreaByAside('total');return false;" rcode="total"><strong>종합</strong></a>
# <span class="area1">
# <span class="bar">|</span>
# <a class="NPI=a:region,i:1100000000" href="#" onclick="setAreaByAside('1100000000');return false;" rcode="1100000000">서울</a>
# <span class="bar">|</span>
# <a class="NPI=a:region,i:4100000000" href="#" onclick="setAreaByAside('4100000000');return false;" rcode="4100000000">경기</a>
# <span class="bar">|</span>
# <a class="NPI=a:region,i:2800000000" href="#" onclick="setAreaByAside('2800000000');return false;" rcode="2800000000">인천</a>
# <span class="bar">|</span>
# <a class="NPI=a:region,i:2600000000" href="#" onclick="setAreaByAside('2600000000');return false;" rcode="2600000000">부산</a>
# </span>
# <span class="area2">
# <span class="bar">|</span>
# <a class="NPI=a:region,i:3000000000" href="#" onclick="setAreaByAside('3000000000');return false;" rcode="3000000000">대전</a>
# <span class="bar">|</span>
# <a class="NPI=a:region,i:2700000000" href="#" onclick="setAreaByAside('2700000000');return false;" rcode="2700000000">대구</a>
# <span class="bar">|</span>
# <a class="NPI=a:region,i:3100000000" href="#" onclick="setAreaByAside('3100000000');return false;" rcode="3100000000">울산</a>
# <span class="bar">|</span>
# <a class="NPI=a:region,i:3600000000" href="#" onclick="setAreaByAside('3600000000');return false;" rcode="3600000000">세종</a>
# </span>
# <span class="area3">
# <span class="bar">|</span>
# <a class="NPI=a:region,i:2900000000" href="#" onclick="setAreaByAside('2900000000');return false;" rcode="2900000000">광주</a>
# <span class="bar">|</span>
# <a class="NPI=a:region,i:4200000000" href="#" onclick="setAreaByAside('4200000000');return false;" rcode="4200000000">강원</a>
# <span class="bar">|</span>
# <a class="NPI=a:region,i:4300000000" href="#" onclick="setAreaByAside('4300000000');return false;" rcode="4300000000">충북</a>
# <span class="bar">|</span>
# <a class="NPI=a:region,i:4400000000" href="#" onclick="setAreaByAside('4400000000');return false;" rcode="4400000000">충남</a>
# </span>
# <span class="area4">
# <span class="bar">|</span>
# <a class="NPI=a:region,i:4700000000" href="#" onclick="setAreaByAside('4700000000');return false;" rcode="4700000000">경북</a>
# <span class="bar">|</span>
# <a class="NPI=a:region,i:4800000000" href="#" onclick="setAreaByAside('4800000000');return false;" rcode="4800000000">경남</a>
# <span class="bar">|</span>
# <a class="NPI=a:region,i:4500000000" href="#" onclick="setAreaByAside('4500000000');return false;" rcode="4500000000">전북</a>
# <span class="bar">|</span>
# <a class="NPI=a:region,i:4600000000" href="#" onclick="setAreaByAside('4600000000');return false;" rcode="4600000000">전남</a>
# </span>
# <span class="area5">
# <span class="bar">|</span>
# <a class="NPI=a:region,i:5000000000" href="#" onclick="setAreaByAside('5000000000');return false;" rcode="5000000000">제주</a>
# <span class="btn_area">
# <a class="btn prev NPI=a:prev" href="#" onclick="moveAreaSelect(-1);return false;"><span>이전</span></a>
# <a class="btn next NPI=a:next" href="#" onclick="moveAreaSelect(1);return false;"><span>다음</span></a>
# </span>
# </span></p>
# <div class="area_on NI=a:list" id="total_news">
# <ul class="category_list">
# <li>
# <a class="area NP=r:1,i:421_0005053345" href="region.nhn?city_no=1100000000&amp;dvsn_no=1156000000">[영등포구]</a>
# <a class="NP=r:1,i:421_0005053345" href="/news/newsRead.nhn?source=aside&amp;type=region&amp;city_no=1100000000&amp;dvsn_no=1156000000&amp;prsco_id=421&amp;arti_id=0005053345">
# 						서울 영등포구 '쪽방촌 정...</a>
# </li>
# <li>
# <a class="area NP=r:2,i:417_0000632315" href="region.nhn?city_no=1100000000&amp;dvsn_no=1130500000">[강북구]</a>
# <a class="NP=r:2,i:417_0000632315" href="/news/newsRead.nhn?source=aside&amp;type=region&amp;city_no=1100000000&amp;dvsn_no=1130500000&amp;prsco_id=417&amp;arti_id=0000632315">
# 						서울 최고도지역 우이동 55...</a>
# </li>
# <li>
# <a class="area NP=r:3,i:001_0012083601" href="region.nhn?city_no=3000000000&amp;dvsn_no=3017000000">[서구]</a>
# <a class="NP=r:3,i:001_0012083601" href="/news/newsRead.nhn?source=aside&amp;type=region&amp;city_no=3000000000&amp;dvsn_no=3017000000&amp;prsco_id=001&amp;arti_id=0012083601">
# 						대전시 2023년까지 5만6천...</a>
# </li>
# <li>
# <a class="area NP=r:4,i:018_0004808524" href="region.nhn?city_no=1100000000&amp;dvsn_no=1159000000">[동작구]</a>
# <a class="NP=r:4,i:018_0004808524" href="/news/newsRead.nhn?source=aside&amp;type=region&amp;city_no=1100000000&amp;dvsn_no=1159000000&amp;prsco_id=018&amp;arti_id=0004808524">
# 						동작구 본동종합사회복지관...</a>
# </li>
# <li>
# <a class="area NP=r:5,i:421_0005051466" href="region.nhn?city_no=4300000000&amp;dvsn_no=4313000000">[충주시]</a>
# <a class="NP=r:5,i:421_0005051466" href="/news/newsRead.nhn?source=aside&amp;type=region&amp;city_no=4300000000&amp;dvsn_no=4313000000&amp;prsco_id=421&amp;arti_id=0005051466">
# 						국토부, 수소충전 복합기지...</a>
# </li>
# <li>
# <a class="area NP=r:6,i:277_0004810510" href="region.nhn?city_no=1100000000&amp;dvsn_no=1171000000">[송파구]</a>
# <a class="NP=r:6,i:277_0004810510" href="/news/newsRead.nhn?source=aside&amp;type=region&amp;city_no=1100000000&amp;dvsn_no=1171000000&amp;prsco_id=277&amp;arti_id=0004810510">
# 						서울시, 문정역 인근에 '역...</a>
# </li>
# <li>
# <a class="area NP=r:7,i:001_0012075348" href="region.nhn?city_no=4500000000&amp;dvsn_no=4575000000">[임실군]</a>
# <a class="NP=r:7,i:001_0012075348" href="/news/newsRead.nhn?source=aside&amp;type=region&amp;city_no=4500000000&amp;dvsn_no=4575000000&amp;prsco_id=001&amp;arti_id=0012075348">
# 						"좋은 일에 부동산 쓰라"…...</a>
# </li>
# <li>
# <a class="area NP=r:8,i:018_0004805411" href="region.nhn?city_no=1100000000&amp;dvsn_no=1174000000">[강동구]</a>
# <a class="NP=r:8,i:018_0004805411" href="/news/newsRead.nhn?source=aside&amp;type=region&amp;city_no=1100000000&amp;dvsn_no=1174000000&amp;prsco_id=018&amp;arti_id=0004805411">
# 						[동네방네]강동구, 골목길 ...</a>
# </li>
# <li>
# <a class="area NP=r:9,i:003_0010236514" href="region.nhn?city_no=2600000000&amp;dvsn_no=2635000000">[해운대구]</a>
# <a class="NP=r:9,i:003_0010236514" href="/news/newsRead.nhn?source=aside&amp;type=region&amp;city_no=2600000000&amp;dvsn_no=2635000000&amp;prsco_id=003&amp;arti_id=0010236514">
# 						부산시 ‘센텀2지구 도시첨...</a>
# </li>
# <li>
# <a class="area NP=r:10,i:001_0012071273" href="region.nhn?city_no=4800000000&amp;dvsn_no=4812100000">[창원시]</a>
# <a class="NP=r:10,i:001_0012071273" href="/news/newsRead.nhn?source=aside&amp;type=region&amp;city_no=4800000000&amp;dvsn_no=4812100000&amp;prsco_id=001&amp;arti_id=0012071273">
# 						"집 걱정 없이 일하세요"…...</a>
# </li>
# </ul>
# </div>
# <div class="area_off NI=a:list" id="area_news">
# <ul class="category_list" id="region_news_area">
# <script defer="defer" id="region_news_template" type="text/template">
# 				{for idx:news in newsList}
# 					{if idx < 10 }
# 					<li>
# 						<a href="region.nhn?city_no={=current}&dvsn_no={=news.cortar1_no}" class="area NP=r:{=idx+1},i={=news.prsco_id}_{=news.arti_id}">[{js splitRegionName(=news.dvsn_nm,0)}]</a>
# 						<a href="/news/newsRead.nhn?source=aside&type=region&city_no={=current}&dvsn_no={=news.cortar1_no}&prsco_id={=news.prsco_id}&arti_id={=news.arti_id}" class="NP=r:{=idx+1},i={=news.prsco_id}_{=news.arti_id}">{js cutStringByPixel(=news.ttl,160,'...')}</a>
# 					</li>
# 					{/if}
# 				{/for}
# 			</script>
# </ul>
# </div>
# <a class="btn_more NPI=a:more" href="#" onclick="goRegionNews();return false">더보기</a>
# </div>
# </div>
# </div><!-- footer -->
# <script language="javascript" src="https://ssl.pstatic.net/static/common/js/cs_ops_webncc.js" type="text/javascript"></script>
# <div id="footer">
# <div class="footwrap NE=a:fot">
# <fieldset>
# <legend class="blind">검색</legend>
# <div class="sta_search_box NE=a:lsc">
# <input accesskey="s" class="sta_search_text" id="queryInputFooter" onfocus="searchInputBoxFocus(this);" onkeyup="serviceInternalSearchEnterCheck(event,1);" query="" searchareaclicked="false" searchtype="Promotion" title="검색" type="text" value=""/>
# <a class="btn_search NPI=a:search" href="#" onclick="serviceInternalSearchFooter();return false;">검색</a>
# <a class="btn_search2 NPI=a:nx" href="#" onclick="serviceInternalTotalSearchFooter();return false;" title="새창 열림">통합검색</a>
# </div>
# </fieldset>
# <ul class="NE=a:fot">
# <li class="first"><a class="NPI=a:service" href="http://www.naver.com/policy/service.html">이용약관</a></li>
# <li><a href="/index/declaredArticlePolicy.nhn">매물신고운영</a></li>
# <li><a class="NPI=a:privacy" href="http://www.naver.com/rules/privacy.html" target="_blank" title="새창 열림"><strong>개인정보처리방침 </strong></a></li>
# <li><a class="NPI=a:help" href="#" onclick="OPS.viewOPS('ops', {url : 'https://help.naver.com/support/alias/land/landmain.naver'}); return false;" title="새창 열림">부동산 고객센터</a></li>
# </ul>
# <p class="info" tabindex="0">네이버부동산에서 제공하는 부동산 정보는 각 콘텐츠 제공업체로부터 받는 정보로 참고용입니다.<br/>
#                                          정보의 정확성이나 신뢰성을 보증하지 않으며, 서비스 이용의 결과에 대해서 어떠한 법적인 책임을 지지 않습니다. 게시된 정보는 무단으로 배포할 수 없습니다.</p>
# <address>
# <a class="logo N=a:fot.nbpcorp" href="http://www.navercorp.com/ko/index.nhn" target="_blank"><span class="blind">NAVER</span></a>
# <em>Copyright ⓒ</em> <a href="http://www.navercorp.com/ko/index.nhn" target="_blank">NAVER Corp.</a> <span>All Rights Reserved.</span>
# </address>
# </div>
# </div>
# <!-- //footer --></div>
# </body>
# <script src="https://ssl.pstatic.net/static.land/static/service/js/202011051426/min/news/news.jindo.js" type="text/javascript"></script><script src="https://ssl.pstatic.net/static.land/static/service/js/202011051426/min/news/news.util.js" type="text/javascript"></script><script src="https://ssl.pstatic.net/static.land/static/service/js/202011051426/min/news/news.js" type="text/javascript"></script><script type="text/javascript">
# var oDatePickerdate1,
# oDatePickerdate2;
#
# //뉴스홈 우측하단 rolling 부분
# if(typeof(rolling) == "function"){
# 	rolling();
# }
#
# //이벤트 Listener 함수 호출
# nclk_do();
#
#
#
# // 전문가칼럼 등록기간
# if ($('writer_sel') != null){
# 	var writerSel = new ISelectBox($("writer_sel"),{ width : "172", height : false, bUseDefaultOption : false });
# 	dateShow_date1();dateShow_date2();
# }
#
# // 실시간 속보 뉴스 검색
# if ($('searchForm') != null){
# 	var sdate1 = $("date1");
# 	var sdate2 = $("date2");
# }
#
# if ($('issue_sel') != null){
# 	new ISelectBox($('issue_sel'),{ width : "229", height : false, bUseDefaultOption : false });
# }
# </script>
# </html>
