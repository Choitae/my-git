# %% [markdown]
# # NVIDIA - GPU로 Tensorflow 동작 시키기
#   - GPU의 연산 속도에 맞는 Tensorflow, Cuda, cuDNN을 다운 받기

# %% [markdown]
# ## 1. GPU에 알맞는 드라이브 설치하기
#   - 아래 사이트에서 GPU에 알맞는 드라이브 설치하기
#   - https://www.nvidia.co.kr/Download/Find.aspx?lang=kr

# %% [markdown]
#   - 내 PC GPU는?
#     - window 키 -> '장치 관리자' 검색 -> 디스플레이 어뎁터를 누르면 아래 사진과 같이 나온다.
#     - 또는, 제어판 -> '장치 관리자' 검색 -> 디스플레이 어뎁터
#     ![image.png](attachment:image.png)

# %% [markdown]
# ## 2. GPU의 연산능력 버전 확인 하기
#   - 아래 있는 위키백과에서 자신의 GPU의 연산 속도가 어느정도인지 확인하기.
#   - GTX 1050 Ti의 경우, 6.1의 연산능력 버전, 마이크로-아키텍처는 파스칼이다.
#   - ![image.png](attachment:image.png)
#   - https://ko.wikipedia.org/wiki/CUDA

# %% [markdown]
# ## 3. GPU 연산능력 버전을 지원하는 CUDA 버전 확인하기
#   - 아래 있는 영문 위키백과 사이트에서 GPU 연산능력 버전와 연동되는 CUDA 버전을 확인 할 수 있다
#   - GTX 1050 Ti의 마이크로-아키텍처는 파스칼로, 8.0에서 11.0까지의 버전을 지원 하는 것을 알 수 있다.
#   - ![image.png](attachment:image.png)
#   - https://en.wikipedia.org/wiki/CUDA

# %% [markdown]
# ## 4. GPU 연산능력 버전과 CUDA 버전에 맞는 Tensorflow 버전 찾기
#   - tensorflow_gpu 버전과 그와 연동되는 cuDNN, Cuda 버전을 받아야 한다.
#   - 나는 Cuda가 11 버전까지 지원하며, 이 중에서 Cuda 10.1 / cuDNN 7.6 / tensorflow-gpu 2.3.0 버전을 설치하기로 하였다.
#   - ![image.png](attachment:image.png)
#   - https://www.tensorflow.org/install/source_windows#tested_build_configurations

# %% [markdown]
# ## 5. Cuda 다운 받기
#   - 아래 홈페이지에서 설치하고자 하는 Cuda 버전을 다운 받으면 된다.
#   - 나는 Cuda 10.1 버전을 다운받고, 설치하였다.
#   - ![image-2.png](attachment:image-2.png)
#   - https://developer.nvidia.com/cuda-toolkit-archive

# %% [markdown]
# ## 6. cuDNN 다운 받기
#   - nvidai 개발자 홈페이지에 들어가서 회원 가입 후, Dowonload cuDNN을 클릭하면, 간단한 설문 조사 후 cuDNN을 다운 받을 수 있다.
#   - ![image.png](attachment:image.png)
#   - 동의란 클릭 후 Archived cuDNN Releases를 클릭하면, 원하는 버전을 찾을 수 있다.
#   - ![image-2.png](attachment:image-2.png)
#   - 나는 CUDA 10.1 버전에 연동되는 cuDNN v7.6.0 for window를 다운 받았다.
#   - ![image-3.png](attachment:image-3.png)
#   - https://developer.nvidia.com/cudnn

# %% [markdown]
# ## 7. cuDNN을 CUDA 폴더에 덮어쓰기.
#   - cuDNN을 다운받아서 압축 풀면, 아래와 같은 파일들을 볼 수 가 있다. 이를 복사해서, 'C:\Program Files\NVIDIA GPU Computing Toolkit\CUDA\버전'에 있는 파일들에 덮어쓰기 해주면 된다. 나는 cuda v10.1을 설치하였으니, 'C:\Program Files\NVIDIA GPU Computing Toolkit\CUDA\v10.1'에 cuDNN 파일들을 가져와 덮어쓰기 하였다.
#   - cuDNN 압축 파일 : ![image.png](attachment:image.png)
#   - CUDA\V10.1 폴더 (파일 덮어쓰기 후) : ![image-2.png](attachment:image-2.png)

# %% [markdown]
# ## 8. 가상환경에서 tensorflow-gpu 설치하고 Cuda 버전, Gpu 작동 여부 확인하기.
#   - 아나콘다나 Powershell 등에서 tensorflow를 사용할 가상환경에 접속한다.
#   - 명령어 conda list를 입력하여 tensorflow가 설치되어 있으면, 명령어 conda remove tensorflow 입력해 지워준다.
#   - 그리고 conda install tensorflow-gpu를 실행하면, conda 명령어에 의해 알맞는 tensorflow-gpu를 설치해준다.
#   - CUDA를 확인해보자
#     - 명령어 nvcc --version 를 입력하여 아래와 같이 설치한 버전이 뜨면, 정상적으로 설치가 된 것이다.
#     - ![image-5.png](attachment:image-5.png)
#   - 이제 Gpu 작동이 정상적으로 되는지 확인해보자.
#     - 명령어 python를 입력, 명령어 import tensorflow as tf를 입력, tensorflow를 import 해주어 아래와 같은 그림이 뜨면, tensorflow에서
#       cuda를 정상적으로 이끌어 올려준 것이다.
#     - ![image.png](attachment:image.png)
#
# # 만약에 , cuda와 cuDNN, 그리고 tensorflow를 정상적으로 설치했는데, 위의 그림과 같이 작동되지 않는다면??
#   - 나는 2가지 방법을 통해 조치하였다.
#
#
#   - 1. 필수 라이브러리 Visual C++ 설치
#     - 아래 홈페이지에 들어가서, 아래와 같이 vc_redist.x64.exe를 설치해주었다. 컴퓨터 사양에 맞는 버전을 깔아주면 된다.
#     - ![image-2.png](attachment:image-2.png)
#     - https://support.microsoft.com/en-us/topic/the-latest-supported-visual-c-downloads-2647da03-1eea-4433-9aff-95f26a218cc0
#
#
#   - 2. pip install tensorflow-gpu==2.3.0
#     - conda를 사용하다보면, 캐시가 남아, 파일을 새로 받는 것이 아닌, 캐시에 남은 파일을 그대로 이용한다고 한다.
#     - 때문에 pip install tensorflow-gpu=='버전'을 통해 원하는 파일을 그대로 다운받아서 작동시켰으며,
#     - 명령어 conda  clean -all 을 통해 캐시를 지우면 된다.
#
#
#   - Tensorflow 명령어로 설치 상태 확인하기.
#     - tensorflow 버전 확인하기 print(tf.__version__)
#     - cuda로 빌드 되는지 확인하기 : tf.test.is_built_with_cuda()
#     - cuda와 같은 GPU로 빌드 되는지 확인하기 : tf.test.is_built_with_gpu_support()
#     - 사용가능한 GPU 기기들 출력 : tf.test.gpu_device_name()
#     - ![image-3.png](attachment:image-3.png)

# %% [markdown]
# ## 9. 정상 작동 확인하기.
#   - 수업 중 오토 인코더 파일을 실행시키고, 작업 관리자 창을 통해 GPU 작동 상태를 확인해보았다.
#   - ![image.png](attachment:image.png)
#   - Gpu가 정상적으로 돌아가며, 연산 속도도 확연이 감소한 것을 볼 수 있었다. 40s /step $\to$ 5s 9~11ms/step
#   - ![image-2.png](attachment:image-2.png)
#   - 작동이 끝나도, GPU 일정 부분이 작동되는 것을 볼 수 있는데, 이는 tensorflow에서 연산을 위해 잡는 것이며,
#     jupyter-notebook을 닫으면, 정상적으로 돌아오는 것을 볼 수 있다.
#   - note-book 종료 전 :
#   ![image-3.png](attachment:image-3.png)
#   - note-book 종료 후 :
#   ![image-4.png](attachment:image-4.png)

# %% [markdown]
# ## ※ 오류 (cuDNN 초기화 오류)
#   - 하나의 note-book의 코드를 돌린 후, 초기화 하지않고, 다음 note-book을 돌리게 되면, 다음과 같은 오류가 발생한다.
#   - Failed to get convolution algorithm. This is probably because cuDNN failed to initialize, so try looking to see if a warning log message was printed above.
#   - ![image.png](attachment:image.png)
#   - ![image-2.png](attachment:image-2.png)
#   - error를 보면, cuDNN이 초기화되지 않아서 overflow가 일어나기 때문이라고 한다.
#   - 조치방법은 2가지이며, 필요한 만큼 메모리를 런타임에 할당하는 방법, 그리고 GPU에 할당되는 전체 메로리 크기를 제한하는 방법이 있다.
#   - 아래 홈페이지를 참조하여 조치할 수 있으며, 나의 경우는 GPU에 할당되는 전체 메모리 크기를 제한하는 방법에도 overflow가 발생하여,
#     필요한 만큼 메모리를 런타임에 할당하는 방법을 사용하였다.
#   - https://inpages.tistory.com/155

# %% [markdown]
# ### 필요한 만큼 메모리를 런타임에 할당하는 방법
#   - 작동시킬 notebook 상단에 아래의 코드를 입력하고, 작동시키면 overflow 없이 정상적으로 작동시킬 수 있다.

# %%
import tensorflow as tf

gpus = tf.config.experimental.list_physical_devices('GPU')
if gpus:
  try:
    # Currently, memory growth needs to be the same across GPUs
    for gpu in gpus:
      tf.config.experimental.set_memory_growth(gpu, True)
    logical_gpus = tf.config.experimental.list_logical_devices('GPU')
    print(len(gpus), "Physical GPUs,", len(logical_gpus), "Logical GPUs")
  except RuntimeError as e:
    # Memory growth must be set before GPUs have been initialized
    print(e)
# Out:
# 1 Physical GPUs, 1 Logical GPUs

# %% [markdown]
# ## 참조 사이트
#   - cuda, cuDNN 설치
#     - https://data-newbie.tistory.com/492
#     - https://coding-groot.tistory.com/87,
#     - https://blog.naver.com/harold_crick/222177797814,
#     - https://coding-groot.tistory.com/87
#
#
#   - 아나콘다 명령어
#     - https://m.blog.naver.com/PostView.nhn?blogId=ey2y&logNo=221541157096&proxyReferer=https:%2F%2Fwww.google.com%2F
